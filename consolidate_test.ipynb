# %%
from utils import generate_csv

base_folder = "/Users/ramiibrahimi/Documents/testingaiexplain/base_folder/"
input_csv = "csv/my_corpus.csv"
generate_csv(base_folder, input_csv)
output_csv = "csv/"
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 15 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)

# %%
import pandas as pd

data_url = input_csv
data_df = pd.read_csv(data_url)

# %%
from chunking import chunk_free_form


def handle_free_form(content, similarity_threshold=0.6, max_tokens=300):
    sents = chunk_free_form.split_into_sentences(content)
    embeddings = chunk_free_form.embed_sentences(sents)
    similarity_threshold = similarity_threshold
    max_tokens = max_tokens
    merged_sents = chunk_free_form.merge_sentences_leiden(
        sents,
        embeddings,
        max_token_limit=max_tokens,
        similarity_threshold=similarity_threshold,
    )
    return merged_sents

# %%
from chunking import chunk_sections
from chunking.chunk_merge import merge_line_chunks
from chunking.extract_sections import parse_resume_sections


def handle_resume(content):
    lines = chunk_sections.parse_into_lines(content)
    table1 = chunk_sections.generate_line_features(lines)
    merged_lines = merge_line_chunks(table1)
    table2 = chunk_sections.generate_line_features(merged_lines)
    parsed_resume = parse_resume_sections(table2)
    return parsed_resume
# Out:
# Device set to use mps:0
# Some weights of the model checkpoint at xlm-roberta-large-finetuned-conll03-english were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 17:20:02 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 17:20:02 INFO: Downloading default packages for language: en (English) ...
# 2025-04-04 17:20:03 INFO: File exists: /Users/ramiibrahimi/stanza_resources/en/default.zip
# 2025-04-04 17:20:04 INFO: Finished downloading models and saved to /Users/ramiibrahimi/stanza_resources
# 2025-04-04 17:20:04 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 17:20:04 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 17:20:04 WARNING: Language en package default expects mwt, which has been added
# 2025-04-04 17:20:05 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# ======================================
#
# 2025-04-04 17:20:05 INFO: Using device: cpu
# 2025-04-04 17:20:05 INFO: Loading: tokenize
# 2025-04-04 17:20:05 INFO: Loading: mwt
# 2025-04-04 17:20:05 INFO: Loading: pos
# 2025-04-04 17:20:06 INFO: Loading: lemma
# 2025-04-04 17:20:06 INFO: Loading: constituency
# 2025-04-04 17:20:07 INFO: Loading: depparse
# 2025-04-04 17:20:07 INFO: Done loading processors!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 17:20:07 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 17:20:07 INFO: Downloading default packages for language: en (English) ...
# 2025-04-04 17:20:08 INFO: File exists: /Users/ramiibrahimi/stanza_resources/en/default.zip
# 2025-04-04 17:20:09 INFO: Finished downloading models and saved to /Users/ramiibrahimi/stanza_resources
# 2025-04-04 17:20:09 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 17:20:09 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 17:20:09 WARNING: Language en package default expects mwt, which has been added
# 2025-04-04 17:20:10 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# ======================================
#
# 2025-04-04 17:20:10 INFO: Using device: cpu
# 2025-04-04 17:20:10 INFO: Loading: tokenize
# 2025-04-04 17:20:10 INFO: Loading: mwt
# 2025-04-04 17:20:10 INFO: Loading: pos
# 2025-04-04 17:20:11 INFO: Loading: lemma
# 2025-04-04 17:20:11 INFO: Loading: constituency
# 2025-04-04 17:20:11 INFO: Loading: depparse
# 2025-04-04 17:20:11 INFO: Done loading processors!

# %%
def process_dataframe(data_df):
    parsed_resumes = {}
    parsed_essays = {}
    for index, row in data_df.iterrows():
        content = row["content"]
        doc_id = row["id"]
        if row["doc_type"] == "Resumes":
            # Assuming handle_resume returns a dictionary with key/value pairs
            parsed_resume = handle_resume(content=content)
            parsed_resumes[doc_id] = parsed_resume
        else:
            # Assuming handle_free_form returns a list of sentences/contents
            sents = handle_free_form(content=content)
            parsed_essays[doc_id] = sents
    return parsed_resumes, parsed_essays

# %%
import csv
import os


def create_resumes_csv(parsed_resumes, directory):
    # Ensure the target directory exists
    os.makedirs(directory, exist_ok=True)
    csv_file_path = os.path.join(directory, "resumes.csv")

    # Build a list of rows. For each resume, add the id as a new key.
    rows = []
    all_keys = set()
    for resume_id, resume_data in parsed_resumes.items():
        # Create a new dictionary that includes the resume id as "id"
        row_dict = {"id": resume_id}
        row_dict.update(resume_data)
        rows.append(row_dict)
        all_keys.update(row_dict.keys())

    # Ensure "id" is the first column
    all_keys = list(all_keys)
    if "id" in all_keys:
        all_keys.remove("id")
        all_keys = ["id"] + sorted(all_keys)
    else:
        all_keys = sorted(all_keys)

    with open(csv_file_path, mode="w", newline="", encoding="utf-8") as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=all_keys)
        writer.writeheader()
        for row in rows:
            writer.writerow(row)

# %%
import csv
import os


def create_essays_csv(parsed_essays, directory):
    # Ensure the target directory exists
    os.makedirs(directory, exist_ok=True)
    csv_file_path = os.path.join(directory, "essays.csv")

    # Write the data to the CSV file with header "id" and "content"
    with open(csv_file_path, mode="w", newline="", encoding="utf-8") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["id", "content"])
        for essay_id, contents in parsed_essays.items():
            for content in contents:
                writer.writerow([essay_id, content])

# %%
import csv
import os


def create_combined_csv(parsed_resumes, parsed_essays, directory):
    # Ensure the target directory exists
    os.makedirs(directory, exist_ok=True)
    csv_file_path = os.path.join(directory, "combined.csv")

    # Open the file and write the header and rows
    with open(csv_file_path, mode="w", newline="", encoding="utf-8") as csvfile:
        fieldnames = ["id", "category", "content"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        # Process resumes: each key/value pair becomes a separate row.
        for doc_id, resume_data in parsed_resumes.items():
            for key, value in resume_data.items():
                category = f"resume-{key}"
                writer.writerow({"id": doc_id, "category": category, "content": value})

        # Process essays: each item in the list becomes a separate row with category "free-form".
        for doc_id, essay_contents in parsed_essays.items():
            for content in essay_contents:
                writer.writerow(
                    {"id": doc_id, "category": "free-form", "content": content}
                )

# %%
parsed_resumes, parsed_essays = process_dataframe(data_df)
create_combined_csv(parsed_resumes, parsed_essays, output_csv)
# Out:
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.3680
# Clamped    : 0.3680
# =======================================
#
# total similarity: 0.29072049260139465
# === compute_dynamic_resolution Debug ===
# n         : 26
# T         : 643
# S_avg     : 0.2907
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9371
# R (clamped): 0.9371
# ========================================
# resolution: 0.9370742328512713
# NODE REFERENCE:
# [0] Shortly after my transition to the process engineer position with Philip Morris, I was charged with leading a make-shift team composed of machine operators, senior maintenance engineers and technicians for the purpose of improving one of our underperforming key performance indicators; tobacco waste.
#
#
# [1] I began by working on identifying the major loss contributors and areas for improvement and creating an action plan with targets for the next three months.
#
# [2] Over the course of the subsequent weekly team meetings I started perceiving that some of the team members were more concerned about their routine tasks and not fully invested in the project and were not completing their assigned tasks.
#
# [3] To address this shortcoming, I redistributed the tasks across the team members who were more active participants and myself.
#
# [4] We struggled to keep up, especially given technical knowledge gaps in some areas.
#
#
# [5] At the end of the month after lots of hard work the new results came in, to my disappointment there was no significant improvement.
#
# [6] Shortly thereafter, my supervisor called me for a meeting to discuss the progress and results.
#
# [7] He asked about the latest updates and commended all the extra efforts and commitment we have been putting in.
#
# [8] He then proceeded to criticize of my leadership approach.
#
# [9] Hi highlighted my inability to get all the team members fully engaged in the project as a major weakness.
#
# [10] He said that my career progress thus far was due to my analytical rigor and hard skills and what he perceived to be as a potential for growth and explained that in order to progress further I have to address this inadequacy.
#
# [11] Finally he noted his expectation for better results for the following month and offered to coach me throughout.
#
#
# [12] As I received the first negative feedback in my career, I battled feelings of hopelessness and ineptitude.
#
# [13] And for the rest of the day, I just sat at my desk to reflect on what had transpired.
#
#
# [14] The following morning, I woke up determined to change my mind set.
#
# [15] After difficult challenge of fully accepting an embracing the criticism, it just seemed clear to me what I needed to do.
#
# [16] I set weekly meeting with my manager for coaching and performance review.
#
# [17] I subsequently signed up for a couple of internal trainings on leadership and assertiveness.
#
#
# [18] I held individual meetings with each for the project team members, I thanked them for their contributions and discussed the unsatisfactory results with them.
#
# [19] After I asked them for individual feedback, I made sure to covey my respect and appreciation for their immense experience and sonority and politely shared my concern over their lack of engagement.
#
# [20] I then proceeded to explain the financial implications of our increased tobacco waste in order to convey a more relatable picture of the gravity of the situation.
#
# [21] On the following team meeting I threw my originally individually developed action plan and worked with the team to create a new one with individual targets for each member.
#
#
# [22] After slightly improved results in the following month I made sure to recognize individual achievements in the presence of senior management.
#
# [23] As we all picked up the pace we were finally able to hit an all-time affiliate record for tobacco yield.
#
#
# [24] I can hardly articulate the sense of pride and accomplishment I felt after having overcome my first serious professional obstacle.
#
# [25] This experience was in fact what first triggered for my interest to pursue MBA education.
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.3715
# Clamped    : 0.3715
# =======================================
#
# total similarity: 0.2768072187900543
# === compute_dynamic_resolution Debug ===
# n         : 34
# T         : 900
# S_avg     : 0.2768
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9499
# R (clamped): 0.9499
# ========================================
# resolution: 0.9498549521206497
# NODE REFERENCE:
# [0] Given my somewhat unusual personal and professional background, I believe that I will be able
# to bring a unique perspective and value to the diverse Fuqua culture.
#
#
#
# [1] My earliest encounter with entrepreneurship came at a young age.
#
# [2] I was 9 when a kindergarten
# my parents founded opened its doors to preschoolers from around the neighborhood.
#
# [3] Under my
# mother’s management, it grew rapidly into a full-fledged school that provides high quality
# education at affordable costs to around 500 students.
#
# [4] A true team project, the whole family
# contributed in one way or another to its rapid growth and success.
#
# [5] Tutoring there during college,
# working there briefly after graduation, and as a member of the decision making circle
# throughout, I received valuable knowledge about business dynamics at medium to small sized
# businesses, and about entrepreneurship in Jordan.
#
#
#
# [6] I hope to share and build upon my experiences by starting a Fuqua club focused on
# entrepreneurship and business in the Middle East.
#
# [7] I believe this would provide distinctive insight
# for my prospective colleagues into an area that, although distinct in many respects, is somewhat
# less explored than markets like Asia or Latin America.
#
# [8] I am also excited about the prospect of
# organizing a trek for my prospective Fuqua colleagues to Jordan, which is at the center of the
# Arab World technology start-up revolution and witnessing a unique technological transformation.
#
#
# [9] A visit to one of the world’s new seven wonders, Petra, would just be the cherry on top.
#
#
#
# [10] Since childhood, I was always very passionate about the technology industry, assembling my
# first personal computer at 7, developing android applications, and studying mechatronics
# engineering.
#
# [11] Anxiously following all news about a new device or innovation, over the years I was
# able to develop instincts about technology trends.
#
# [12] I found myself on many occasions able to
# predict the success or lack thereof of new tech ventures.
#
# [13] A passionate techie, I hope to enrich
# my knowledge at, and suggest topics for, the High Tech 101 & 201 Sessions and advocate for
# my viewpoints through the weekly “tech talks” at the High Technology club.
#
#
#
# [14] Professionally, I was fortunate to join the Jordanian Philip Morris International affiliate shortly
# after it was acquired from an aging local manufacturer.
#
# [15] I was part of the “new blood” tasked with
# elevating the previously local company to the required corporate standard, no easy task.
#
# [16] As part
# of a small team in a rapidly changing environment my limits were constantly expanding.
#
# [17] My
# learning curve was astronomical across diverse areas from operations and projects
# management to cross-functional projects involving sales, marketing and finance.
#
# [18] It was a
# chaotic scene in which everyone was involved in everything
#
# [19] and I loved it.
#
# [20] I guess in many ways
# it resembled a start-up.
#
# [21] I intend to utilize my cross-functional experience to help my fellow study
# group partners integrate knowledge gained from different areas into one big picture.
#
#
# [22] Furthermore, I plan to leverage my cross-cultural communication skill set to enhance the
# harmony among my diverse section.
#
#
#
# [23] Through the years, I have cultivated diverse global experience.
#
# [24] I grew up in the UAE and have
# lived there again as an adult, travelled across the Middle East, Europe and to the United States.
#
#
# [25] Most recently, I started a one-year work assignment in Izmir, Turkey within an international
# Fortune 500 company.
#
# [26] I am particularly looking forward to taking a leadership role within the
# Fuqua international business club.
#
# [27] Through my exposure to the organizational challenges and
# dynamics at one of the largest and most diverse Philip Morris International affiliates I will be able
# to share, with my fellow future business leaders at Fuqua, my firsthand account of the
# challenges and opportunities of working in a truly international business and what I have
# perceived to be the best ways to overcome all cultural and linguistic barriers.
#
# [28] I am also looking
# forward to participating in the GATE program to acquire additional exposure into new areas,
# particularly Latin America and South East Asia.
#
#
#
# [29] Fuqua is the perfect fit for me, in terms of both professional and personal growth.
#
# [30] I am eager to
# utilize the plethora of gateways and opportunities that Fuqua offers to contribute to the
# community.
#
# [31] Whether through the initial community service projects, the world renowned Net
# Impact Club or Habitat for Humanity of Durham, I am brimming with excitement at the prospect
# of contributing substantially to Fuqua’s social entrepreneurship efforts.
#
#
#
# [32] Finally, I am keen to bring my football (soccer) and fencing skills to the MBA games and to
# introducing my home country’s traditional dish, Mansaf at one of the around the world dinners.
#
# [33] A
# voracious reader and news-junkie I am also interested in revamping the weekly newsletter.
#
#
#
#
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.2654
# Clamped    : 0.3000
# =======================================
#
# total similarity: 0.1870245784521103
# === compute_dynamic_resolution Debug ===
# n         : 53
# T         : 1025
# S_avg     : 0.1870
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9721
# R (clamped): 0.9721
# ========================================
# resolution: 0.972108783267322
# Token indices sequence length is longer than the specified maximum sequence length for this model (455 > 384). Running this sequence through the model will result in indexing errors
# NODE REFERENCE:
# [0]  1- I was born in Jordan and raised in Jordan and the UAE in a family of doctors.
#
# [1] My parents
#   strongly supported science and education.
#
#
# [2] 2- I have itchy feet; I love to travel.
#
# [3] I particularly enjoy embedding myself in a new culture
#   among new people for a considerable period of time.
#
# [4] One of my favorite destinations is
#   Beirut, Lebanon where you can be sunbathing in wonderful weather on a beautiful beach
#   and 30 minutes later you can be in skiing on the Mazaar slopes.
#
# [5] It is indeed a chaotic city
#   but that’s what I love about it.
#
#
# [6] 3- I am a huge wildlife fanatic, next on my bucket list is a safari to Tanzania-Kenya.
#
#
# [7] 4- I am an avid gamer.
#
# [8] One of my most recent achievements is becoming a Level 100 colonel
#   on Battlefield 4.
#
#
# [9] 5- I am an aviation enthusiast, particularly up to date with the latest technologies from the
#   likes of Lockheed Martin’s Skunk Works, the division responsible for their cutting-edge
#   technologies such as the F35 Program.
#
#
# [10] 6- I am a news junkie.
#
# [11] From Politico and the Atlantic to Engadget and Gizmodo, I never miss
#   my daily dose of the latest.
#
# [12] My favorite nighttime activity is debating the latest political
#   developments with a group of my childhood friends in one of the cafes in Amman.
#
#
# [13] 7- I once won the bronze medal at a junior national fencing championship when I was 11 after
#   training for only 6 weeks.
#
# [14] Today, I practice once or twice every month.
#
#
# [15] 8- I am a foodie and casual cook and the current owner of the world’s best pancake recipe, a
#   claim based purely on my subjective opinion.
#
#
# [16] 9- I love mountain biking and trail hiking.
#
# [17] My current favorite locations include the beautiful
#   Dead Sea plains and the vast Ajloun forest.
#
# [18] I have an insatiable appetite for discovery and
#   adventure.
#
#
# [19] 10- I am a football (soccer) enthusiast, intermediate right mid-fielder and avid Bayern München
#   fan.
#
#
# [20] 11- I am an absolute tech-head.
#
# [21] Constantly on the lookout for the next TechCrunch Disrupt,
#   Apple and Google I/O. I predicted the unusual upcoming mid-generation game console
#   refresh (PS4 Pro and Xbox Scorpio) 4 years ago and I can prove it!
#
#
# [22] 12- I am a movie addict, always waiting for the next Christopher Nolan or Wes Anderson
#   masterpiece, or anything scored by Hans Zimmer.
#
# [23] My favorite movie is the Grand Budapest
# Hotel.
#
# [24] The brilliant script, cinematography, score and uplifting narrative make it my go-to
# movie whenever I’m looking for an extra moral push.
#
#
# [25] 13- I am a devoted AC/DC and Led Zeppelin fan.
#
# [26] One of their few fans in the Middle East, I’ve
# had a life-long dream of attending a live concert for both.
#
#
# [27] 14- A comic book geek, I see myself as Bruce Wayne meets Tony Stark.
#
# [28] My friends say I’m more
# like Brain, the cartoon mouse.
#
#
# [29] 15- I am a small talk professional, I can literally strike up a conversation with anyone about
# anything.
#
# [30] Perhaps a side effect of the next point.
#
#
# [31] 16- I am a Wikipedia Addict; I am prone to spending hours jumping between Wikipedia articles
# until I eventually end up reading about the Mongol horde or the exploration of Venus.
#
#
# [32] 17- I am an off-roading enthusiast.
#
# [33] My favorite weekend activity used to involve going on a
# camping trip with my close friends in the Wadi Rum desert in my old Land Rover Defender.
#
#
# [34] 18- I am a voracious reader and history buff and a true believer in the “history repeats itself”
# statement.
#
#
# [35] 19- I am a satirical comedy aficionado, and a big fan of SNL, Jon Stewart and The Onion
# publication.
#
#
# [36] 20-
#
# [37] In my adolescence, I developed an extreme interest in Arab poetry which still persists.
#
# [38] The
# rich vocabulary of ancient Arabic makes for uniquely descriptive and articulate poetry.
#
#
# [39] 21- I am a hobbyist software developer and the go-to guy at work for extreme excel VBA based
# solutions.
#
#
# [40] 22- I am a Ferrari & Ducati enthusiast.
#
# [41] I do not like the extravagance, but I appreciate the
# technology.
#
#
# [42] 23-
#
# [43] My favorite TV show is Silicon Valley.
#
# [44] It’s about a group of geeks establishing a start-up who
# face every imaginable obstacle.
#
# [45] I particularly love the attention to detail.
#
# [46] Every piece of
# code, formula or business technique casually mentioned or in the background is real.
#
#
# [47] Whenever I describe the show, which ridiculously fits with my character and interests, I end
# my description with “I swear I’m not making that up.”
#
#
# [48] 24-
#
# [49] My current idol is Elon Musk.
#
# [50] His ability to mix technical skills with business acumen to
# continuously innovate is for me a source of inspiration.
#
#
# [51] 25-  I am an obsessive investigator; whenever I find a new area of extreme interest I delve into a
# ridiculous level of detail.
#
# [52] For example, I know that on my first day at Fuqua, I will get my
# coffee at Bon Appetit Café from Irene at the coffee bar!
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.3147
# Clamped    : 0.3147
# =======================================
#
# total similarity: 0.24256058037281036
# === compute_dynamic_resolution Debug ===
# n         : 23
# T         : 663
# S_avg     : 0.2426
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9475
# R (clamped): 0.9475
# ========================================
# resolution: 0.9474579126921083
# NODE REFERENCE:
# [0] What is your short-term, post-MBA career goal and why?
#
# [1] (150 words)
#
#
# [2] My post-MBA career objective is to pivot into the technology industry and become a product manager within the hardware division at a major technology company such as Samsung, Apple, Alphabet, Microsoft, or Nintendo.
#
# [3] I will leverage my technical background and my extensive experience in diverse areas including operations, finance and new product launches in a small dynamic post-acquisition environment.
#
# [4] My subsequent exposure to the organizational dynamics and global challenges at a large affiliate with 2000 employees has further refined my skills and prepared me for my desired career.
#
#
# [5] Since childhood, I have been passionate about technology, assembling my first personal computer at 7, developing android applications, and studying mechatronics engineering.
#
# [6] Anxiously interested in news about a new device or innovation, I always wanted to be part of the teams bringing such great products to the world.
#
# [7] In order to pursue my true passion, I have to transition into technology.
#
#
# [8] College Extracurriculars and Employment – 200
# -Co-founder and member of the support community for the exchange for supplemental academic material and organization of student-led support lectures/
#
# [9] Aug 2009 - Jan 2013
# -Volunteer lecturing for Assembly Language & Microprocessors and Design of Embedded Systems support classes at the University of Jordan/ Jan 2012 – Jul-2012
# -Part time tutor at the family founded school - Scientific Reyada School/Jan 2008 - Jul 2011
# -Delegate at model united nations organized by Princess Sumayya University of Technology/ Summer 2012
# List up to three hobbies or interests you enjoy in your free time.
#
#
# [10] Video Games – Level 100 colonel on Battlefield 3
# Reading – passionate about the areas of world history and technology
# Soccer – Intermediate right mid-fielder
# Charlottesville has a renowned film festival, book festival and vibrant music scene.
#
# [11] What is your favorite film, book or song?
#
# [12] (15 words)
# Grand Budapest Hotel – I just love the script
#
#
# [13] Please list the professional associations and community activities (clubs, faith-based, civic, etc.) in which you have participated since graduation from university.
#
# [14] If you graduated from university more than ten (10) years ago, please simply list your activities for the past five (5) years.
#
# [15] It would be helpful to include:
# •	The organization name
# •	Your role
# •	Dates of participation
# •	Description of your involvement
# -Jordan 4x4 Off-road Club
# Member
# In addition to the usual off-roading trip.
#
# [16] We responded to emergency situations in coordination with the Jordanian civil defense directorate during snowy conditions
# -Middle East Political Debate Club
# Every weekend, I would meet-up with a group of close friends from school and college in one of the small coffee shops in downtown Amman.
#
# [17] We would discuss and juxtapose our different political views about the latest developments in the region and what each of us thought is the best way to move forward.
#
#
# [18] -Philip Morris Wind Surfing Club
# Beginner wind surfing training at the wonderful Alacati coast In Izmir, Turkey
#
#
# [19] Tell us what you would want your learning team to know about you - personal, professional or both.
#
# [20] (100 words)
# If you could go anywhere in the world with Darden, where would you go and why?
#
# [21] (50 words)
#
#
# [22] If there is further information you believe would be helpful to the Admission Committee, please provide it: - 250
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.3228
# Clamped    : 0.3228
# =======================================
#
# total similarity: 0.2254609316587448
# === compute_dynamic_resolution Debug ===
# n         : 13
# T         : 334
# S_avg     : 0.2255
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9305
# R (clamped): 0.9305
# ========================================
# resolution: 0.9304738880614852
# NODE REFERENCE:
# [0] College Extracurriculars and Employment – 200
# -Co-founder and member of the support community for the exchage for supplemental academic material and organisation of student-led support lectures/
#
# [1] Aug 2009 - Jan 2013
# -Volunteer lecturing for Assembly Language & Microprocessors and Design of Embedded Systems support classes at the University of Jordan/ Jan 2012
# -Part time tutor at the family founded school - Scientific Reyada School/Jan 2008 - Jul 2011
# -Delegate at model united nations organized by Princess Sumayya University of Technology/ Summer 2012
# What is your short-term, post-MBA career goal and why?
#
# [2] (150 words)
# Please list the professional associations and community activities (clubs, faith-based, civic, etc.) in which you have participated since graduation from university.
#
# [3] If you graduated from university more than ten (10) years ago, please simply list your activities for the past five (5) years.
#
# [4] It would be helpful to include:
# The organization name
# Your role
# Dates of participation
# Description of your involvement
# Tell us what you would want your learning team to know about you - personal, professional or both.
#
# [5] (100 words)
# I am a … tech head, geek obsessed with jet aircraft and history …etc.
#
#
# [6] If you could go anywhere in the world with Darden, where would you go and why?
#
# [7] (50 words)
#
#
# [8] Charlottesville has a renowned film festival, book festival and vibrant music scene.
#
# [9] What is your favorite film, book or song?
#
# [10] (15 words)
#
#
# [11] List up to three hobbies or interests you enjoy in your free time.
#
#
# [12] If there is further information you believe would be helpful to the Admission Committee, please provide it: - 250
# Colleague
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.2899
# Clamped    : 0.3000
# =======================================
#
# total similarity: 0.20293468236923218
# === compute_dynamic_resolution Debug ===
# n         : 29
# T         : 615
# S_avg     : 0.2029
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9535
# R (clamped): 0.9535
# ========================================
# resolution: 0.9534905730300267
# NODE REFERENCE:
# [0] College was without doubt the roughest time in my life.
#
# [1] I grew up in an academically oriented family.
#
# [2] My
# parents were adamant about education and strove to provide the best quality of education their means
# allowed.
#
# [3] Against my parents’ advice, who wanted me to study medicine, I elected to pursue my passion
# for technology and earn a degree in Mechatronics Engineering.
#
#
#
# [4] Shortly after beginning college at the University of Jordan I realized that the school was in a state of rapid
# decline.
#
# [5] Classes were extremely overcrowded, the aging infrastructure was crumbling, and the previously
# Western educated faculty was being replaced by a locally educated, less-qualified cohort.
#
# [6] Despite being
# the most selective school in the country and thereby having some of the most highly qualified students,
# class failure rates were upwards of 60%.
#
# [7] Students often repeated courses five or six times.
#
#
#
# [8] I began searching for opportunities to transfer to a university abroad.
#
# [9] Unfortunately, I could not financially
# afford it.
#
# [10] Meanwhile, as I felt consumed by the stigma of failure, I did not want to go back to my family and
# disappoint them.
#
# [11] I felt increasingly isolated and I did not know where to turn for guidance.
#
#
#
# [12] Looking back, I should have asked my loved ones for help and put in the extra effort to adapt and do
# whatever was necessary to overcome this challenge.
#
# [13] Instead, when life threw me my first serious curve
# ball, it knocked me out.
#
# [14] I lost all motivation, I stopped going to classes, my self-esteem took a big hit, and
# I descended towards rock bottom.
#
# [15] My former academic success was all but forgotten and I slowly settled
# for doing the bare minimum and becoming an average student, quite literally; I finished one semester late
# and around the fiftieth percentile of my class.
#
#
#
# [16] Fortunately, things improved after I started at Philip Morris International.
#
# [17] Working life was a fresh start,
# and I was determined to never again settle for anything less than exceptional.
#
# [18] With every new success I
# regained confidence and returned to the person I once was.
#
# [19] I have progressed rapidly, and in May I was
# assigned to one of the largest affiliates, in Izmir, Turkey.
#
# [20] Such assignments are indicative of an
# accelerated career path and an investment by the company into their top talent.
#
#
#
# [21] Furthermore, I have tried to demonstrate my ability to handle the curriculum, despite my poor
# undergraduate record.
#
# [22] In addition to doing my best to get a good score on the GMAT, I am taking
# Calculus 1 and Introduction to Financial accounting through Berkeley extension.
#
# [23] I have 100% in Calculus
# and 96% in Financial Accounting.
#
# [24] Only the final exams are remaining, and they are scheduled for mid-
# October.
#
#
#
# [25] For my recommenders, I chose the people who know me best.
#
# [26] I refrained from approaching my current
# supervisor, due to our relatively short relationship.
#
#
#
# [27] Also, I included fixed per-diems, travel and hardship allowances and accommodation payments as bonus
# compensation when reporting my salary on the application.
#
#
#
# [28] I truly hope for a second chance to re-immerse myself in academics and succeed at Fuqua, and to
# pursue my goals and achieve my full potential.
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.2559
# Clamped    : 0.3000
# =======================================
#
# total similarity: 0.17424005270004272
# === compute_dynamic_resolution Debug ===
# n         : 22
# T         : 483
# S_avg     : 0.1742
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9519
# R (clamped): 0.9519
# ========================================
# resolution: 0.9519480895386153
# NODE REFERENCE:
# [0] Shortly after beginning my undergraduate study at the University of Jordan I realized that the school was in a state of rapid decline.
#
# [1] The classes were extremely overcrowded, the aging infrastructure was crumbling, and the previously Western educated faculty was gradually being replaced by a locally educated, less-qualified cohort.
#
# [2] Despite being the most selective school in the country and thereby having some of the most highly qualified students, class failure rates on numerous courses were reaching upwards of 60%.
#
# [3] It was not uncommon for students to repeat courses five or six times.
#
#
# [4] As I felt consumed by the stigma of failure, I did not want to go back to my family and disappoint them.
#
# [5] I felt increasingly isolated and I did not know where to turn for guidance.
#
#
# [6] Fortunately, things took a turn for the better after I started at Philip Morris International.
#
# [7] I thought of working life as a fresh start.
#
# [8] I was determined to never again settle for anything less than exceptional.
#
# [9] With every new success, I began to regain my confidence and I saw myself return to the person I once was.
#
# [10] I have progressed rapidly, and in May I was moved to a one-year assignment at one of the largest affiliates, located in Izmir, Turkey.
#
# [11] Such assignments are internally viewed as an accelerated career path and an investment by the company into their top talent.
#
#
# [12] Furthermore, I have tried to demonstrate my ability to handle the curriculum, despite my poor undergraduate record.
#
# [13] In addition to doing my best to get a good score on the GMAT, I am taking Calculus 1 and Introduction to Financial accounting through Berkeley extension.
#
# [14] I am glad to say that I have an accumulated score of 100% in Calculus and 99% in Financial Accounting.
#
# [15] Only the final exams are remaining, and they are scheduled for mid-October.
#
# [16] I will share the final results with the admissions committee subsequently.
#
#
# [17] For my recommenders, I chose the people who know me best.
#
# [18] I refrained from approaching my current supervisor, due to our relatively short relationship.
#
#
# [19] Also, I included per-diems, travel and hardship allowances, and accommodation payments which are fixed, as bonus compensation when reporting my salary on the application.
#
#
# [20] I truly hope for a second chance to re-immerse myself in academics and succeed at Ross.
#
# [21] I remain optimistic that a misstep during a low point in my life will not bar me from pursuing my goals and achieving what I believe to be my full potential.
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.4987
# Clamped    : 0.4987
# =======================================
#
# total similarity: 0.3879474699497223
# === compute_dynamic_resolution Debug ===
# n         : 19
# T         : 607
# S_avg     : 0.3879
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9156
# R (clamped): 0.9156
# ========================================
# resolution: 0.9156389022290432
# NODE REFERENCE:
# [0] Dear Hiring Team at Mastercard,
#
# I am thrilled to apply for the Manager, Product Management – Security Solutions – AI
# (R-237371) position at Mastercard.
#
# [1] With a diverse background in engineering, strategy, and
# operations across Jordan, the UAE, Turkey, and the United States, I bring a global perspective
# that aligns with Mastercard’s mission to advance secure and innovative payment solutions.
#
#
#
# [2] Over the past 18 months, I have immersed myself in artiﬁcial intelligence and software
# engineering, driven by the realization that generative AI will transform the global economy.
#
#
# [3] Recognizing this as a critical moment, I made the deliberate decision to upskill and reskill, not
# just to adapt, but to actively contribute to shaping this shift.
#
# [4] Through an AI and Machine
# Learning Bootcamp at Columbia Engineering, I gained hands-on experience with tools like
# TensorFlow and PyTorch.
#
# [5] I also pursued self-driven projects, such as developing an AI-
# powered interface that integrates multiple models and APIs, deepening my expertise in
# delivering secure, scalable, and innovative solutions.
#
#
#
# [6] My career has consistently operated at the intersection of technology and strategy.
#
# [7] At Google, I
# led machine-learning-driven initiatives across Asia and North America, achieving signiﬁcant
# operational cost savings.
#
# [8] At Philip Morris International, I spearheaded supply chain
# transformations, including launching the company’s ﬁrst product export from Jordan to Africa.
#
#
# [9] These roles honed my ability to align technical goals with strategic objectives while navigating
# complex cultural and regulatory landscapes.
#
#
#
# [10] Growing up in a family business and later gaining experience across the CPG and tech
# industries, I developed a profound appreciation for the role of high-quality data in driving both
# security and innovation.
#
# [11] Mastercard’s commitment to delivering secure, cutting-edge AI
# solutions resonates with me because I see its transformative potential—not just across
# industries, but within every facet of business operations.
#
# [12] I am drawn to the opportunity to
# tackle complex challenges as unique puzzles, leveraging my technical and strategic expertise
# to design solutions that not only address immediate needs but also enable sustainable, long-
# term growth.
#
#
#
# [13] This role excites me because it oﬀers the chance to work at the cutting edge of AI and security,
# tackling challenges that have tangible, far-reaching impacts.
#
# [14] Mastercard’s focus on developing
# innovative solutions to protect businesses and individuals aligns with my passion for solving
# complex, high-stakes problems.
#
# [15] I’m motivated by the opportunity to collaborate with diverse
# teams, bring ideas to life, and contribute to building technology that not only drives progress
# but also instills trust and security in a rapidly evolving world.
#
#
#
# [16] Thank you for considering my application.
#
# [17] I look forward to the opportunity to discuss how my
# background, skills, and passion for secure AI solutions align with Mastercard’s mission and the
# goals of your team.
#
#
#
# [18] Sincerely,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.5616
# Clamped    : 0.5616
# =======================================
#
# total similarity: 0.4141662120819092
# === compute_dynamic_resolution Debug ===
# n         : 18
# T         : 546
# S_avg     : 0.4142
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9073
# R (clamped): 0.9073
# ========================================
# resolution: 0.9072715295180114
# NODE REFERENCE:
# [0] Dear Hiring Team,
#
# I’m excited to apply for the Principal Program Manager role on Microsoft’s AI Red Team.
#
# [1] The
# opportunity to work on PyRIT and contribute to securing AI systems at the scale of Microsoft’s
# portfolio is exactly the kind of challenge I’ve been preparing for throughout my career.
#
#
#
# [2] Over the past 18 months, I decided to transition into a more technical role in AI and machine
# learning, driven by a deep belief in the transformative potential of AI—a revolution that I see as
# reshaping industries and lives faster than any before it.
#
# [3] During this time, I completed a
# bootcamp at Columbia Engineering, worked on self-driven projects like an AI-powered
# transcription tool with 20% improved accuracy, and advanced my expertise in frameworks
# such as TensorFlow, PyTorch, and adversarial ML techniques.
#
# [4] This focused period of growth
# reﬂects my ongoing commitment to mastering the skills required to contribute meaningfully in
# this space, a journey I intend to deepen as my passion for this ﬁeld continues to evolve
#
# My career bridges technical expertise and program management.
#
# [5] At Google, I led cross-
# functional teams to deploy machine-learning models that reduced costs by millions and
# optimized manufacturing processes.
#
# [6] These experiences taught me how to deliver results in
# complex, fast-paced environments while coordinating eﬀorts across technical and operational
# domains.
#
# [7] Beyond corporate roles, I’ve built full-stack AI applications, integrated APIs like
# OpenAI’s GPT, and contributed to real-world AI tools.
#
# [8] These projects reinforced my ability to
# translate abstract ideas into impactful solutions.
#
#
#
# [9] What excites me most about this role is the chance to shape and scale open-source tools like
# PyRIT, empowering a broader community to adopt AI red-teaming practices.
#
# [10] The intersection
# of innovation, security, and collaboration is where I thrive, and I’m eager to contribute my
# technical and program management expertise to help drive Microsoft’s mission of building
# safer AI systems.
#
#
#
# [11] The AI Red Team’s interdisciplinary approach—combining researchers, developers, and
# security experts—resonates deeply with me.
#
# [12] I’ve worked in cross-functional environments
# throughout my career, and I know how to foster clarity and alignment while navigating
# ambiguity.
#
# [13] Joining a team that proactively pushes boundaries to secure cutting-edge AI
# systems feels like a natural progression in my career.
#
#
#
# [14] Thank you for considering my application.
#
# [15] I look forward to the opportunity to discuss how my
# skills, experiences, and passion align with your team’s vision.
#
#
#
# [16] Best regards,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc.
#
# [17] in Mechatronics Engineering, Class of 2013
# University of Jordan
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.5458
# Clamped    : 0.5458
# =======================================
#
# total similarity: 0.41839542984962463
# === compute_dynamic_resolution Debug ===
# n         : 19
# T         : 558
# S_avg     : 0.4184
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9071
# R (clamped): 0.9071
# ========================================
# resolution: 0.9071081300902464
# NODE REFERENCE:
# [0] Dear Hiring Team,
#
# I am excited to apply for the GenAI/Machine Learning Technical Project Manager position
# within Deloitte’s Human Capital Oﬀering Portfolio.
#
# [1] The opportunity to spearhead generative AI
# initiatives that enhance organizational performance and engagement aligns closely with my
# technical expertise, leadership experience, and passion for leveraging AI to solve real-world
# challenges.
#
#
#
# [2] Over the past 18 months, I have transitioned into a more technical role in AI and machine
# learning, recognizing the transformative potential of this ﬁeld.
#
# [3] During this time, I completed a
# certiﬁcation in AI and machine learning at Columbia Engineering, where I gained hands-on
# experience with frameworks like TensorFlow, PyTorch, and OpenAI’s GPT models.
#
# [4] I have led
# self-driven projects, such as an AI-powered transcription tool with 20% improved accuracy
# and a full-stack AI-powered application integrating GPT models.
#
# [5] These experiences reﬂect my
# ability to bridge technical and strategic domains to deliver impactful AI solutions.
#
#
#
# [6] At Google, I managed cross-functional teams to deploy machine-learning models, achieving
# operational cost savings of over $10 million and optimizing processes at scale.
#
# [7] These projects
# honed my skills in coordinating diverse teams, managing complex timelines, and delivering
# results in fast-paced environments.
#
# [8] My recent experience includes leveraging Agile and Scrum
# methodologies to guide teams through every phase of project development, ensuring
# alignment with both technical roadmaps and business goals.
#
#
#
# [9] What excites me most about this role is the opportunity to deliver cutting-edge generative AI
# projects while collaborating with cross-functional teams to align technical capabilities with
# tangible business value.
#
# [10] My experience managing large-scale initiatives, and knowledge of
# cloud technologies (AWS, GCP, Azure), positions me to excel in this role.
#
# [11] I am particularly
# drawn to Deloitte’s emphasis on creating people-centric solutions, as it resonates with my own
# approach to building tools that enhance user experience and deliver measurable impact.
#
#
#
# [12] Beyond my technical and program management experience, I thrive in environments that
# demand adaptability, collaboration, and continuous improvement.
#
# [13] Whether coaching junior
# team members, guiding teams through Agile transformations, or managing risks to ensure
# project success, I bring a results-oriented mindset and a commitment to fostering healthy,
# high-performing teams.
#
#
#
# [14] Thank you for considering my application.
#
# [15] I look forward to the opportunity to contribute to
# Deloitte’s mission of delivering innovative, human-centered AI solutions.
#
# [16] I would welcome the
# chance to discuss how my skills and experiences align with your team’s needs.
#
#
#
# [17] Best regards,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc.
#
# [18] in Mechatronics Engineering, Class of 2013
# University of Jordan
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.5370
# Clamped    : 0.5370
# =======================================
#
# total similarity: 0.3967958688735962
# === compute_dynamic_resolution Debug ===
# n         : 18
# T         : 558
# S_avg     : 0.3968
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9114
# R (clamped): 0.9114
# ========================================
# resolution: 0.9113760942205238
# NODE REFERENCE:
# [0] Dear Hiring Team at Roblox,
#
# I am excited to apply for the Senior Product Manager role in the Creator organization at
# Roblox.
#
# [1] With a multidisciplinary background in AI, machine learning, and platform
# development, combined with a passion for empowering creators and reimagining digital
# experiences, I am eager to contribute my expertise to your mission of connecting people
# through immersive 3D experiences.
#
#
#
# [2] Recognizing the transformative potential of generative AI, I transitioned my career toward this
# ﬁeld, completing an AI and Machine Learning Bootcamp at Columbia Engineering.
#
# [3] My journey
# has involved developing technical skills through hands-on projects, including:
#
# •Generative AI Interfaces: Built tools integrating multiple AI models and APIs, reﬁning my
# understanding of system interoperability and enabling seamless user interactions.
#
#
#
# [4] •Custom ML Models: Designed a speech-to-text transcription system that improved baseline
# accuracy by 20%, leveraging ﬁne-tuning and domain-speciﬁc data.
#
#
#
# [5] •AI for Content Creation: Explored the use of AI in automating the creation and enhancement
# of digital assets, bridging technical innovation with user-centric design.
#
#
#
# [6] My admiration for Roblox stems from your commitment to fostering creativity and innovation
# through an open, scalable platform.
#
# [7] The Creator tools you oﬀer, combined with the integration
# of generative AI, set the stage for revolutionizing digital expression.
#
# [8] I am particularly inspired by
# the vision of enabling “creation of anything, anywhere, by anyone”—a goal that resonates
# deeply with my work in democratizing AI-powered technologies for creators and developers
# alike.
#
#
#
# [9] Throughout my career, I have cultivated the skills needed to thrive in dynamic, multi-sided
# platforms.
#
# [10] At Google, I led cross-regional machine learning initiatives, achieving measurable
# operational eﬃciencies while collaborating with engineering teams to deliver impactful
# solutions.
#
# [11] At Philip Morris International, I managed complex projects that demanded strategic
# problem-solving and a user-ﬁrst mindset.
#
# [12] These experiences have prepared me to shape and
# execute innovative product strategies aligned with Roblox’s goals.
#
#
#
# [13] I am excited about the opportunity to lead the vision and roadmap for AI/ML-driven tools within
# the Creator organization.
#
# [14] Collaborating with talented engineers, designers, and analysts to
# deliver tools that empower users and advance the platform’s capabilities would be an
# incredible challenge that I am ready to embrace.
#
#
#
# [15] Thank you for considering my application.
#
# [16] I look forward to the opportunity to discuss how my
# background and passion align with Roblox’s mission to redeﬁne human interaction in digital
# spaces.
#
#
#
# [17] Sincerely,
# Rami Ibrahimi
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.4822
# Clamped    : 0.4822
# =======================================
#
# total similarity: 0.384650319814682
# === compute_dynamic_resolution Debug ===
# n         : 21
# T         : 663
# S_avg     : 0.3847
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9190
# R (clamped): 0.9190
# ========================================
# resolution: 0.9189525011849303
# NODE REFERENCE:
# [0]        RAMI I. IBRAHIMI
#    2101 Arlington Blvd.#433 •                                                                                                                                         Charlottesville, VA 22903 •                                                                                    (405) 404-
#
# [1] 6614•
#        IbrahimiR19@darden.virginia.edu
#
#
# September 16, 2018
#
# McKinsey&Company Recruiting Team
# McKinsey&Company
# Gate Precinct 4, Level 4
# Dubai, United Arab Emirates
#
#
#
# [2] Dear McKinsey&Company Recruiting Team         ,
#
# My name is Rami Ibrahimi, and I am currently a first                                                            -year student at the Darden Graduate School of
# Business.
#
# [3] I am writin         g to express my interest In the full-time associate position at McKinsey       .
#
# [4] Having lived
# and worked in                                diverse functions in                                 Jordan, the UAE,           Turkey and the United States        ,I believe I would bring
# a uniquely                              modern, international perspective to the global team at McKinsey&Co.
#
#
#
# [5] I have thoroughly enjoyed learning about McKinsey&Co                                                                throughout the recruiting process this fall           and
# prior.
#
# [6] I was particularly impressed with the c                   ulture and community of exceptional people at the firm         .
#
#
# [7] Fu rther more, the exposure to broad strategic decisionmaking within i                                                                                              ndustry transformational projects
# would allow me to enhance my strategic perspective while utilizing                                my experience in manufacturing and
# operations.
#
# [8] Additionally, the strong focus on           training, development                                                                                     and innovation,and the plethora of
# opportunities for internal mobility within the firm         make it the ideal place whereI                                                                         can have a very well                                                                     -
# rounded and long term career through which I can have an impact on the industries I am most passionate
# about.
#
#
#
# [9] Progressing rapidly through different roles and locations, my work experience at Philip Morris
# International includes joining                     the freshly acquired affiliate in Jordan as a member of a small team tasked
# with restructuring the new acquisition from the groundup                                                                                                                                                   .
#
# [10] I have experienced rapid personal and
# professional growththroughout                               ,given the necessity to                    work in diverse areas.
#
# [11] These experiences include
# leading a global                                        team for the                     launch           of the           first ever product export          at the Jordanian affiliate, and         building
# complex excel models for the long-                                                                         term budget cycle at the Turkish affiliate - the largest affiliate and the
# biggest CPG in Turkey.
#
# [12] These aresome                                                   of the experiences that have provided me withthe global
# leadership, project management, technical, and other versatile skills          that would be essential                                                                        for a successful
# career in consulting and strategy.
#
# [13] Most recently, I have completed                     my summer internship at Google in
# Mountain View, CA.
#
# [14] where I got to work within the hardware operations team                                                             on live projects with the
# internal team and the co                            ntract manufacturer in support of next generation                                            Pixel phone launch.
#
#
#
# [15] Outside of work, I strove to further developmy skills                                                                        .
#
# [16] Learning how to code VB, Java, SQL, XML and
# other languages, pursuing training in project management, and ultimately electing to pursue an MBA, I
# have eventually identified that through a role in consulting, I can most utilize my skill                                                                                  -set and have the
# greatest impact.
#
# [17] Generally                    , being part of the strategic planni                    ng process and leading transformational
# initiatives across cross         -functional teams is work that I would very excited about doing on a daily basis.
#
#
#
# [18] I a m very excited at the possibility of interviewing for the        McKinsey&Co Associate          program.
#
#
#
# [19] Thank you for your time and consideration, and I look forward to speaking with you in the future.
#
#
#
# [20] Sincerely,
#
# Rami Ibrahimi
# MBA Candidate, Class of 2019
# Darden Graduate School of Business
#
#
# === compute_dynamic_threshold Debug ===
# Percentile : 75
# Raw        : 0.4850
# Clamped    : 0.4850
# =======================================
#
# total similarity: 0.38640096783638
# === compute_dynamic_resolution Debug ===
# n         : 18
# T         : 537
# S_avg     : 0.3864
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9123
# R (clamped): 0.9123
# ...
# word the
# pos DET
# word Supervised
# pos VERB
# word •
# pos PUNCT
# word indicators
# pos NOUN
# count 1
# word performance
# pos NOUN
# count 2
# word key
# pos ADJ
# word two
# pos NUM
# word for
# pos ADP
# word recognition
# pos NOUN
# count 1
# word achieving
# pos VERB
# word and
# pos CCONJ
# word records
# pos NOUN
# count 1
# word time
# pos NOUN
# count 2
# word -
# pos PUNCT
# word all
# pos DET
# word new
# pos ADJ
# word four
# pos NUM
# word setting
# pos VERB
# word projects
# pos NOUN
# count 0
# word improvement
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word facility
# pos NOUN
# count 3
# word production
# pos NOUN
# count 4
# word two
# pos NUM
# word on
# pos ADP
# word teams
# pos NOUN
# count 1
# word person
# pos NOUN
# count 2
# word -
# pos PUNCT
# word five
# pos NUM
# word two
# pos NUM
# word Led
# pos VERB
# word •
# pos PUNCT
# word award
# pos NOUN
# count 1
# word Duty
# pos NOUN
# count 2
# word of
# pos ADP
# word Call
# pos NOUN
# count 1
# word the
# pos DET
# word Beyond
# pos ADP
# word and
# pos CCONJ
# word Above
# pos ADP
# word International
# pos ADJ
# word Morris
# pos PROPN
# count 1
# word Philip
# pos PROPN
# count 2
# word received
# pos VERB
# word ;
# pos PUNCT
# word inventory
# pos NOUN
# count 1
# word total
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 40
# pos NUM
# word representing
# pos VERB
# word million
# pos NUM
# word 1
# pos NUM
# word $
# pos SYM
# word by
# pos ADP
# word inventory
# pos NOUN
# count 1
# word parts
# pos NOUN
# count 2
# word spare
# pos NOUN
# count 3
# word local
# pos ADJ
# word reduction
# pos NOUN
# count 4
# word the
# pos DET
# word in
# pos ADP
# word resulting
# pos VERB
# word materials
# pos NOUN
# count 0
# word raw
# pos ADJ
# word and
# pos CCONJ
# word parts
# pos NOUN
# count 1
# word spare
# pos NOUN
# count 2
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word categorization
# pos NOUN
# count 2
# word and
# pos CCONJ
# word management
# pos NOUN
# count 1
# word inventory
# pos NOUN
# count 2
# word factory
# pos NOUN
# count 3
# word Initiated
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word engineering
# pos NOUN
# count 1
# word and
# pos CCONJ
# word operations
# pos NOUN
# count 1
# word learning
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word to
# pos ADP
# word operations
# pos NOUN
# count 1
# word product
# pos NOUN
# count 2
# word from
# pos ADP
# word transitioning
# pos VERB
# word ,
# pos PUNCT
# word MBA
# pos NOUN
# count 1
# word an
# pos DET
# word and
# pos CCONJ
# word background
# pos NOUN
# count 1
# word engineering
# pos NOUN
# count 2
# word an
# pos DET
# word with
# pos ADP
# word professional
# pos ADJ
# word AI
# pos PROPN
# count 1
# word Certified
# pos VERB
# word teams
# pos NOUN
# count 1
# word cross-functional
# pos ADJ
# word managing
# pos VERB
# word and
# pos CCONJ
# word ,
# pos PUNCT
# word manipulation
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word big
# pos ADJ
# word ,
# pos PUNCT
# word models
# pos NOUN
# count 1
# word predictive
# pos ADJ
# word building
# pos VERB
# word in
# pos SCONJ
# word experience
# pos NOUN
# count 1
# word on
# pos ADP
# word -
# pos PUNCT
# word Hands
# pos NOUN
# count 1
# word respectively
# pos ADV
# word 2021
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word and
# pos CCONJ
# word 2020
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word for
# pos ADP
# word savings
# pos NOUN
# count 1
# word in
# pos ADP
# word million
# pos NUM
# word 7
# pos NUM
# word $
# pos SYM
# word and
# pos CCONJ
# word million
# pos NUM
# word 3.5
# pos NUM
# word $
# pos SYM
# word in
# pos ADP
# word resulting
# pos VERB
# word team
# pos NOUN
# count 0
# word cross-regional
# pos ADJ
# word with
# pos ADP
# word tandem
# pos NOUN
# count 1
# word in
# pos ADP
# word costs
# pos NOUN
# count 1
# word product
# pos NOUN
# count 2
# word OpEx
# pos NOUN
# count 3
# word of
# pos ADP
# word management
# pos NOUN
# count 1
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word executed
# pos VERB
# word and
# pos CCONJ
# word Created
# pos VERB
# word •
# pos PUNCT
# word costs
# pos NOUN
# count 1
# word qualification
# pos NOUN
# count 2
# word in
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word of
# pos ADP
# word reduction
# pos NOUN
# count 1
# word in
# pos ADP
# word resulting
# pos VERB
# word qualification
# pos NOUN
# count 0
# word cell
# pos NOUN
# count 1
# word manufacturing
# pos NOUN
# count 2
# word &
# pos CCONJ
# word rates
# pos NOUN
# count 1
# word return
# pos NOUN
# count 2
# word for
# pos ADP
# word models
# pos NOUN
# count 1
# word predictive
# pos ADJ
# word learning
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word deliver
# pos VERB
# word to
# pos PART
# word scientists
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word of
# pos ADP
# word team
# pos NOUN
# count 1
# word overseas
# pos ADJ
# word Managed
# pos VERB
# word •
# pos PUNCT
# word load
# pos NOUN
# count 1
# word work
# pos NOUN
# count 2
# word in
# pos ADP
# word reduction
# pos NOUN
# count 1
# word %
# pos SYM
# word 80
# pos NUM
# word and
# pos CCONJ
# word process
# pos NOUN
# count 1
# word the
# pos DET
# word of
# pos ADP
# word automation
# pos NOUN
# count 1
# word complete
# pos ADJ
# word in
# pos ADP
# word resulting
# pos VERB
# word devices
# pos NOUN
# count 0
# word Pixel
# pos NOUN
# count 1
# word flagship
# pos NOUN
# count 2
# word gen
# pos NOUN
# count 3
# word -
# pos PUNCT
# word next
# pos ADJ
# word for
# pos ADP
# word Forum
# pos PROPN
# count 1
# word Management
# pos PROPN
# count 2
# word Inventory
# pos PROPN
# count 3
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word implemented
# pos VERB
# word and
# pos CCONJ
# word Designed
# pos VERB
# word •
# pos PUNCT
# word requirements
# pos NOUN
# count 1
# word timeline
# pos NOUN
# count 2
# word sales
# pos NOUN
# count 3
# word -
# pos PUNCT
# word market
# pos NOUN
# count 4
# word -
# pos PUNCT
# word in
# pos ADP
# word for
# pos ADP
# word rate
# pos NOUN
# count 1
# word hit
# pos NOUN
# count 2
# word %
# pos SYM
# word 100
# pos NUM
# word achieving
# pos VERB
# word brands
# pos NOUN
# count 0
# word L&M
# pos PROPN
# count 1
# word and
# pos CCONJ
# word Marlboro
# pos PROPN
# count 1
# word including
# pos VERB
# word products
# pos NOUN
# count 1
# word strategic
# pos ADJ
# word seven
# pos NUM
# word of
# pos ADP
# word revamp
# pos NOUN
# count 1
# word the
# pos DET
# word for
# pos ADP
# word team
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word the
# pos DET
# word Supervised
# pos VERB
# word •
# pos PUNCT
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word representing
# pos VERB
# word markets
# pos NOUN
# count 0
# word African
# pos ADJ
# word new
# pos ADJ
# word eight
# pos NUM
# word across
# pos ADP
# word products
# pos NOUN
# count 1
# word new
# pos ADJ
# word 23
# pos NUM
# word for
# pos ADP
# word project
# pos NOUN
# count 1
# word export
# pos NOUN
# count 2
# word first
# pos ADJ
# word the
# pos DET
# word launch
# pos VERB
# word successfully
# pos ADV
# word to
# pos PART
# word teams
# pos NOUN
# count 1
# word five
# pos NUM
# word across
# pos ADP
# word effort
# pos NOUN
# count 1
# word -functional
# pos ADJ
# word cross
# pos NOUN
# count 2
# word Led
# pos VERB
# word •
# pos SYM
# word sticks
# pos NOUN
# count 1
# word billion
# pos NUM
# word 70
# pos NUM
# word of
# pos ADP
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word representing
# pos VERB
# word operations
# pos NOUN
# count 1
# word line
# pos NOUN
# count 2
# word production
# pos NOUN
# count 3
# word 40
# pos NUM
# word of
# pos ADP
# word support
# pos NOUN
# count 1
# word in
# pos ADP
# word tool
# pos NOUN
# count 1
# word reporting
# pos NOUN
# count 2
# word and
# pos CCONJ
# word mining
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word wide
# pos ADJ
# word -
# pos PUNCT
# word company
# pos NOUN
# count 3
# word defective
# pos ADJ
# word a
# pos DET
# word of
# pos ADP
# word resolution
# pos NOUN
# count 1
# word successful
# pos ADJ
# word in
# pos ADP
# word team
# pos NOUN
# count 1
# word project
# pos NOUN
# count 2
# word international
# pos ADJ
# word and
# pos CCONJ
# word domestic
# pos ADJ
# word cross-functional
# pos ADJ
# word Directed
# pos VERB
# word •
# pos PUNCT
# word Turkey
# pos PROPN
# count 1
# word in
# pos ADP
# word CPG
# pos NOUN
# count 1
# word largest
# pos ADJ
# word the
# pos DET
# word and
# pos CCONJ
# word region
# pos NOUN
# count 1
# word EMEA
# pos PROPN
# count 2
# word for
# pos ADP
# word head
# pos NOUN
# count 1
# word cluster
# pos NOUN
# count 2
# word the
# pos DET
# word ,
# pos PUNCT
# word affiliate
# pos NOUN
# count 1
# word Turkish
# pos ADJ
# word the
# pos DET
# word to
# pos ADP
# word assignment
# pos NOUN
# count 1
# word development
# pos NOUN
# count 2
# word leadership
# pos NOUN
# count 3
# word for
# pos ADP
# word candidates
# pos NOUN
# count 1
# word 50
# pos NUM
# word of
# pos ADP
# word out
# pos ADP
# word Selected
# pos VERB
# word •
# pos PUNCT
# word award
# pos NOUN
# count 1
# word Duty
# pos NOUN
# count 2
# word of
# pos ADP
# word Call
# pos NOUN
# count 1
# word the
# pos DET
# word Beyond
# pos ADP
# word and
# pos CCONJ
# word Above
# pos ADP
# word International
# pos ADJ
# word Morris
# pos PROPN
# count 1
# word Philip
# pos PROPN
# count 2
# word received
# pos VERB
# word ;
# pos PUNCT
# word inventory
# pos NOUN
# count 1
# word total
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 40
# pos NUM
# word representing
# pos VERB
# word million
# pos NUM
# word 1
# pos NUM
# word $
# pos SYM
# word by
# pos ADP
# word inventory
# pos NOUN
# count 1
# word local
# pos ADJ
# word reduction
# pos NOUN
# count 2
# word the
# pos DET
# word in
# pos ADP
# word resulting
# pos VERB
# word materials
# pos NOUN
# count 0
# word raw
# pos ADJ
# word and
# pos CCONJ
# word parts
# pos NOUN
# count 1
# word spare
# pos NOUN
# count 2
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word categorization
# pos NOUN
# count 2
# word and
# pos CCONJ
# word management
# pos NOUN
# count 1
# word inventory
# pos NOUN
# count 2
# word factory
# pos NOUN
# count 3
# word Initiated
# pos VERB
# word •
# pos PUNCT
# word indicators
# pos NOUN
# count 1
# word performance
# pos NOUN
# count 2
# word key
# pos ADJ
# word two
# pos NUM
# word for
# pos ADP
# word recognition
# pos NOUN
# count 1
# word achieving
# pos VERB
# word and
# pos CCONJ
# word records
# pos NOUN
# count 1
# word time
# pos NOUN
# count 2
# word -
# pos PUNCT
# word all
# pos DET
# word new
# pos ADJ
# word four
# pos NUM
# word setting
# pos VERB
# word ,
# pos PUNCT
# word projects
# pos NOUN
# count 1
# word improvement
# pos NOUN
# count 2
# word operations
# pos NOUN
# count 3
# word facility
# pos NOUN
# count 4
# word production
# pos NOUN
# count 5
# word two
# pos NUM
# word on
# pos ADP
# word teams
# pos NOUN
# count 1
# word person
# pos NOUN
# count 2
# word -
# pos PUNCT
# word five
# pos NUM
# word two
# pos NUM
# word Led
# pos VERB
# word •
# pos PUNCT
# word contributors
# pos NOUN
# count 1
# word key
# pos ADJ
# word identify
# pos VERB
# word to
# pos PART
# word analysis
# pos NOUN
# count 1
# word multivariate
# pos ADJ
# word using
# pos VERB
# word data
# pos NOUN
# count 1
# word failure
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word analyzed
# pos VERB
# word ;
# pos PUNCT
# word classification
# pos NOUN
# count 1
# word image
# pos NOUN
# count 2
# word for
# pos ADP
# word network
# pos NOUN
# count 1
# word neural
# pos ADJ
# word convolutional
# pos ADJ
# word a
# pos DET
# word built
# pos VERB
# word ;
# pos PUNCT
# word techniques
# pos NOUN
# count 1
# word NLP
# pos NOUN
# count 2
# word using
# pos VERB
# word model
# pos NOUN
# count 2
# word analysis
# pos NOUN
# count 3
# word sentiment
# pos NOUN
# count 4
# word a
# pos DET
# word Developed
# pos VERB
# word :
# pos PUNCT
# word Projects
# pos NOUN
# count 1
# word •
# pos PUNCT
# word .
# pos PUNCT
# word models
# pos NOUN
# count 1
# word baseline
# pos NOUN
# count 2
# word over
# pos ADP
# word %
# pos SYM
# word 20
# pos NUM
# word by
# pos ADP
# word accuracy
# pos NOUN
# count 1
# word transcription
# pos NOUN
# count 2
# word improving
# pos VERB
# word ,
# pos PUNCT
# word %
# pos SYM
# word 5
# pos NUM
# word of
# pos ADP
# word )
# pos PUNCT
# word WER
# pos NOUN
# count 1
# word (
# pos PUNCT
# word Rate
# pos NOUN
# count 2
# word Error
# pos NOUN
# count 3
# word Word
# pos NOUN
# count 4
# word a
# pos DET
# word Achieved
# pos VERB
# word •
# pos PUNCT
# word language
# pos NOUN
# count 1
# word desired
# pos VERB
# word any
# pos DET
# word in
# pos ADP
# word subtitles
# pos NOUN
# count 1
# word written
# pos VERB
# word into
# pos ADP
# word videos
# pos NOUN
# count 1
# word in
# pos ADP
# word language
# pos NOUN
# count 1
# word spoken
# pos VERB
# word converting
# pos VERB
# word tool
# pos NOUN
# count 0
# word advanced
# pos ADJ
# word an
# pos DET
# word Developed
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word readability
# pos NOUN
# count 1
# word and
# pos CCONJ
# word clarity
# pos NOUN
# count 1
# word enhancing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 15
# pos NUM
# word by
# pos ADP
# word errors
# pos NOUN
# count 1
# word reducing
# pos VERB
# word ,
# pos PUNCT
# word transcriptions
# pos NOUN
# count 1
# word refine
# pos VERB
# word to
# pos PART
# word techniques
# pos NOUN
# count 1
# word prompting
# pos NOUN
# count 2
# word AI
# pos NOUN
# count 3
# word backend
# pos NOUN
# count 4
# word Implemented
# pos VERB
# word •
# pos PUNCT
# word consolidation
# pos NOUN
# count 1
# word and
# pos CCONJ
# word alignment
# pos NOUN
# count 1
# word subtitle
# pos NOUN
# count 2
# word effective
# pos ADJ
# word for
# pos ADP
# word )
# pos PUNCT
# word Warping
# pos PROPN
# count 1
# word Time
# pos PROPN
# count 2
# word Dynamic
# pos ADJ
# word (
# pos PUNCT
# word DTW
# pos NOUN
# count 3
# word implementing
# pos VERB
# word ,
# pos PUNCT
# word accuracy
# pos NOUN
# count 1
# word high
# pos ADJ
# word and
# pos CCONJ
# word coverage
# pos NOUN
# count 1
# word language
# pos NOUN
# count 2
# word broad
# pos ADJ
# word for
# pos ADP
# word Whisper
# pos NOUN
# count 1
# word ’s
# pos PART
# word OpenAI
# pos PROPN
# count 1
# word and
# pos CCONJ
# word models
# pos NOUN
# count 1
# word Chirp
# pos NOUN
# count 2
# word ’s
# pos PART
# word Google
# pos PROPN
# count 1
# word Leveraged
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word scalability
# pos NOUN
# count 1
# word and
# pos CCONJ
# word handling
# pos NOUN
# count 1
# word response
# pos NOUN
# count 2
# word model
# pos NOUN
# count 3
# word efficient
# pos ADJ
# word for
# pos ADP
# word %
# pos SYM
# word 30
# pos NUM
# word by
# pos ADP
# word load
# pos NOUN
# count 1
# word server
# pos NOUN
# count 2
# word decreasing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 40
# pos NUM
# word by
# pos ADP
# word latency
# pos NOUN
# count 1
# word response
# pos NOUN
# count 2
# word API
# pos NOUN
# count 3
# word reducing
# pos VERB
# word ,
# pos PUNCT
# word Redis
# pos PROPN
# count 1
# word with
# pos ADP
# word caching
# pos NOUN
# count 1
# word Implemented
# pos VERB
# word •
# pos PUNCT
# word )
# pos PUNCT
# word SQLAlchemy
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word FastAPI
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word Flask
# pos NOUN
# count 1
# word (
# pos PUNCT
# word backend
# pos VERB
# word to
# pos PART
# word )
# pos PUNCT
# word Vue.js
# pos PROPN
# count 1
# word (
# pos PUNCT
# word frontend
# pos NOUN
# count 2
# word from
# pos ADP
# word development
# pos NOUN
# count 1
# word end
# pos NOUN
# count 2
# word -
# pos PUNCT
# word to
# pos ADP
# word -
# pos PUNCT
# word end
# pos NOUN
# count 1
# word mastering
# pos VERB
# word ,
# pos PUNCT
# word development
# pos NOUN
# count 1
# word skill
# pos NOUN
# count 2
# word and
# pos CCONJ
# word education
# pos NOUN
# count 1
# word -
# pos PUNCT
# word self
# pos NOUN
# count 2
# word on
# pos ADP
# word Focused
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word %
# pos SYM
# word 25
# pos NUM
# word by
# pos ADP
# word imbalance
# pos NOUN
# count 1
# word cell
# pos NOUN
# count 2
# word reducing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 20
# pos NUM
# word by
# pos ADP
# word life
# pos NOUN
# count 1
# word battery
# pos NOUN
# count 2
# word increasing
# pos VERB
# word ,
# pos PUNCT
# word mechanisms
# pos NOUN
# count 1
# word protection
# pos NOUN
# count 2
# word advanced
# pos ADJ
# word and
# pos CCONJ
# word balancing
# pos NOUN
# count 1
# word cell
# pos NOUN
# count 2
# word active
# pos ADJ
# word with
# pos ADP
# word cells
# pos NOUN
# count 1
# word 21700
# pos NUM
# word Epoch
# pos NOUN
# count 1
# word utilizing
# pos VERB
# word pack
# pos NOUN
# count 1
# word battery
# pos NOUN
# count 2
# word P
# pos NOUN
# count 3
# word 10S3
# pos NUM
# word a
# pos DET
# word for
# pos ADP
# word BMS
# pos NOUN
# count 1
# word a
# pos DET
# word Designed
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word %
# pos SYM
# word 40
# pos NUM
# word by
# pos ADP
# word time
# pos NOUN
# count 1
# word maintenance
# pos NOUN
# count 2
# word reducing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 30
# pos NUM
# word by
# pos ADP
# word efficiency
# pos NOUN
# count 1
# word system
# pos NOUN
# count 2
# word overall
# pos ADJ
# word improving
# pos VERB
# word ,
# pos PUNCT
# word updates
# pos NOUN
# count 1
# word wireless
# pos ADJ
# word and
# pos CCONJ
# word ,
# pos PUNCT
# word protection
# pos NOUN
# count 1
# word cell
# pos NOUN
# count 2
# word advanced
# pos ADJ
# word ,
# pos PUNCT
# word handling
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word time
# pos NOUN
# count 3
# word -
# pos PUNCT
# word real
# pos ADJ
# word for
# pos ADP
# word system
# pos NOUN
# count 1
# word the
# pos DET
# word Optimized
# pos VERB
# word •
# pos PUNCT
# word servers
# pos NOUN
# count 1
# word cloud
# pos VERB
# word to
# pos PART
# word communication
# pos NOUN
# count 1
# word efficient
# pos ADJ
# word and
# pos CCONJ
# word logging
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word frequency
# pos NOUN
# count 3
# word -
# pos PUNCT
# word high
# pos ADJ
# word manage
# pos VERB
# word to
# pos PART
# word card
# pos NOUN
# count 1
# word SD
# pos NOUN
# count 2
# word an
# pos DET
# word and
# pos CCONJ
# word ,
# pos PUNCT
# word FRAM
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word flash
# pos NOUN
# count 1
# word MCU
# pos NOUN
# count 2
# word the
# pos DET
# word using
# pos VERB
# word system
# pos NOUN
# count 0
# word management
# pos NOUN
# count 1
# word memory
# pos NOUN
# count 2
# word hybrid
# pos ADJ
# word a
# pos DET
# word Developed
# pos VERB
# word •
# pos PUNCT
