# %%
import utils

table1a = utils.load_object_from_pickle("pkl/table1a2.pkl")
table1a
# Out:
# [{'line': 'RAMI I. IBRAHIMI',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3966},
#   'named_entity_recognition': [{'text': 'RAMI I. IBRAHIMI',
#     'label': 'PER',
#     'score': np.float32(0.9995)}],
#   'is_section_header': None},
#  {'line': 'San Francisco, CA 94158 • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': True,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.7311},
#   'named_entity_recognition': [{'text': 'San Francisco',
#     'label': 'LOC',
#     'score': np.float32(0.9999)},
#    {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9997)},
#    {'text': 'riibrahimi', 'label': 'PER', 'score': np.float32(0.9785)},
#    {'text': '.', 'label': 'PER', 'score': np.float32(0.9891)},
#    {'text': 'linkedin', 'label': 'ORG', 'score': np.float32(0.8725)},
#    {'text': 'rami-ibrahimi', 'label': 'PER', 'score': np.float32(0.9826)}],
#   'is_section_header': None},
#  {'line': 'EDUCATION',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7632},
#   'named_entity_recognition': [],
#   'is_section_header': 'EDUCATION'},
#  {'line': 'University of Virginia Darden School of Business Charlottesville, VA',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7668},
#   'named_entity_recognition': [{'text': 'University of Virginia Darden School of Business',
#     'label': 'ORG',
#     'score': np.float32(0.992)},
#    {'text': 'Charlottesville', 'label': 'LOC', 'score': np.float32(1.0)},
#    {'text': 'VA', 'label': 'LOC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': 'Candidate for Master of Business Administration, May 2019',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.4428},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• GMAT: 720',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3921},
#   'named_entity_recognition': [{'text': 'GMAT',
#     'label': 'MISC',
#     'score': np.float32(0.8596)}],
#   'is_section_header': None},
#  {'line': '• Darden Foundation Scholarship',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3708},
#   'named_entity_recognition': [{'text': 'Darden Foundation',
#     'label': 'ORG',
#     'score': np.float32(0.9972)},
#    {'text': 'Scho', 'label': 'MISC', 'score': np.float32(0.593)}],
#   'is_section_header': None},
#  {'line': '• Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3852},
#   'named_entity_recognition': [{'text': 'Consulting, Technology, Finance, Adam Smith Society',
#     'label': 'ORG',
#     'score': np.float32(1.0)},
#    {'text': 'Soccer', 'label': 'ORG', 'score': np.float32(0.968)}],
#   'is_section_header': None},
#  {'line': 'University of Jordan Amman, Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.6379},
#   'named_entity_recognition': [{'text': 'University of Jordan',
#     'label': 'ORG',
#     'score': np.float32(1.0)},
#    {'text': 'Amman', 'label': 'LOC', 'score': np.float32(0.9707)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Bachelor of Science in Mechatronics Engineering, Jan 2013',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3386},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Volunteer lecturer for Assembly & Microprocessors and Design of Embedded Systems classes',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'TECHNICAL SKILLS', 'score': 0.4172},
#   'named_entity_recognition': [{'text': 'Assembly',
#     'label': 'MISC',
#     'score': np.float32(0.9093)},
#    {'text': 'Microprocessors', 'label': 'MISC', 'score': np.float32(0.9848)},
#    {'text': 'Em', 'label': 'MISC', 'score': np.float32(0.9213)},
#    {'text': 'Systems', 'label': 'MISC', 'score': np.float32(0.9668)}],
#   'is_section_header': None},
#  {'line': 'EXPERIENCE',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.448},
#   'named_entity_recognition': [],
#   'is_section_header': 'PROFESSIONAL EXPERIENCE'},
#  {'line': '2018-Present Google LLC',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.4244},
#   'named_entity_recognition': [{'text': 'Google LLC',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Product Operations T/ Program Manager – Phones (2019-Present) Mountain View, CA',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3846},
#   'named_entity_recognition': [{'text': 'Mountain View',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'CA', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Managed oversees third party team of data scientists to deliver machine learning predictive models',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3503},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'for return rates & manufacturing cell qualification resulting in reduction of 15% in qualification costs',
#   'is_visually_separated': False,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': True,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3895},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Created and executed new process for management of OpEx product costs in tandem with cross-',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.5413},
#   'named_entity_recognition': [{'text': 'OpEx',
#     'label': 'ORG',
#     'score': np.float32(0.9998)}],
#   'is_section_header': None},
#  {'line': 'regional team resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021',
#   'is_visually_separated': False,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3786},
#   'named_entity_recognition': [{'text': 'Pixel 2020',
#     'label': 'MISC',
#     'score': np.float32(0.9999)},
#    {'text': 'Pixel 2021', 'label': 'MISC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': '• Drove product headcount resource management for 8 Pixel devices from concept through end of life',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3993},
#   'named_entity_recognition': [{'text': '8 Pixel',
#     'label': 'MISC',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Managed non-device costs for Wearables business unit totaling $150 million annually',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4793},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Led early engagement Product investigation and feature definition for a new segment Pixel device',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.438},
#   'named_entity_recognition': [{'text': 'Pixel',
#     'label': 'MISC',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3947},
#   'named_entity_recognition': [{'text': 'Mountain View',
#     'label': 'LOC',
#     'score': np.float32(0.9999)},
#    {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': '• Designed and implemented new process for Inventory Management Forum for next-gen flagship',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4389},
#   'named_entity_recognition': [{'text': 'Inventory Management Forum',
#     'label': 'MISC',
#     'score': np.float32(0.8832)}],
#   'is_section_header': None},
#  {'line': 'Pixel phones resulting in complete automation of the process and 80% reduction in work load',
#   'is_visually_separated': False,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.4013},
#   'named_entity_recognition': [{'text': 'Pixel',
#     'label': 'MISC',
#     'score': np.float32(0.7755)}],
#   'is_section_header': None},
#  {'line': '• Established standard Key Part Release and Master Production Schedule model and input templates',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3831},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Completely revamped Clear to Build management process leading to strategic SKU-level visibility',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.445},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '2013-2017 Philip Morris International',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.3999},
#   'named_entity_recognition': [{'text': 'Philip Morris International',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Operations Planning Analyst (2015-2017) Izmir, Turkey',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.5042},
#   'named_entity_recognition': [{'text': 'Izmir',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3969},
#   'named_entity_recognition': [{'text': 'Turkish',
#     'label': 'MISC',
#     'score': np.float32(0.9987)}],
#   'is_section_header': None},
#  {'line': 'cluster head for EEMA region and the largest CPG in Turkey',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3973},
#   'named_entity_recognition': [{'text': 'EEMA',
#     'label': 'ORG',
#     'score': np.float32(0.9288)},
#    {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Directed cross-functional domestic and international project team in successful resolution of a',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.474},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'defective company-wide data mining and reporting tool in support of 40 production line operations',
#   'is_visually_separated': False,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3516},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'representing annual volume of 70 billion sticks',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3188},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Led cross functional effort across five teams to successfully launch the first product export project',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4995},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'for 23 new products across eight new African markets representing 15% of annual volume',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': True,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3579},
#   'named_entity_recognition': [{'text': 'African',
#     'label': 'MISC',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Supervised the operations team for the revamp of seven strategic products including Marlboro and',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': True,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4255},
#   'named_entity_recognition': [{'text': 'Marlboro',
#     'label': 'ORG',
#     'score': np.float32(0.998)}],
#   'is_section_header': None},
#  {'line': 'L&M brands achieving 100% hit rate for in-market-sales timeline requirements',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3791},
#   'named_entity_recognition': [{'text': 'L&M',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Process Engineer (2014-2015) Amman, Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4476},
#   'named_entity_recognition': [{'text': 'Amman',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Led two five-person teams on two production facility operations improvement projects setting four',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.459},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'new all-time records and achieving recognition for two key performance indicators',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.6301},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Initiated factory inventory management and categorization process for spare parts and raw materials',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4541},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'resulting in the reduction local spare parts inventory by $1 million representing 40% of total',
#   'is_visually_separated': False,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.348},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'inventory; received Philip Morris International Above and Beyond the Call of Duty award',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.395},
#   'named_entity_recognition': [{'text': 'Philip Morris',
#     'label': 'ORG',
#     'score': np.float32(0.9554)},
#    {'text': 'International Above and Beyond',
#     'label': 'MISC',
#     'score': np.float32(0.9812)},
#    {'text': 'Call of Duty', 'label': 'MISC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Electrical Maintenance Engineer (2013-2014) Amman, Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3849},
#   'named_entity_recognition': [{'text': 'Amman',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Designed and installed of track and trace weight measurement system',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4127},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'ADDITIONAL INFORMATION',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3345},
#   'named_entity_recognition': [],
#   'is_section_header': 'ADDITIONAL INFORMATION & PROFESSIONAL DEVELOPMENT'},
#  {'line': '• Dual Citizenship: United States & Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.3184},
#   'named_entity_recognition': [{'text': 'United States',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Bilingual proficiency in English and Arabic, and basic proficiency in Turkish',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3306},
#   'named_entity_recognition': [{'text': 'English',
#     'label': 'MISC',
#     'score': np.float32(0.9998)},
#    {'text': 'Arabic', 'label': 'MISC', 'score': np.float32(0.9997)},
#    {'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9934)}],
#   'is_section_header': None},
#  {'line': '• Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3198},
#   'named_entity_recognition': [{'text': 'Oxford Union',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• PEARSON certified Smartphone developer',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.2806},
#   'named_entity_recognition': [{'text': 'PEARSON',
#     'label': 'ORG',
#     'score': np.float32(0.502)}],
#   'is_section_header': None},
#  {'line': '• Accidentally appeared in the background of a romantic scene of a Turkish Soap Opera',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.4323},
#   'named_entity_recognition': [{'text': 'Turkish',
#     'label': 'MISC',
#     'score': np.float32(0.9987)}],
#   'is_section_header': None}]

# %%
from chunking.chunk_merge import merge_line_chunks

merged_lines1 = merge_line_chunks(table1a)
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 14:15:25 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 14:15:25 INFO: Downloading default packages for language: en (English) ...
# 2025-04-04 14:15:26 INFO: File exists: /Users/ramiibrahimi/stanza_resources/en/default.zip
# 2025-04-04 14:15:27 INFO: Finished downloading models and saved to /Users/ramiibrahimi/stanza_resources
# 2025-04-04 14:15:27 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 14:15:27 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 14:15:27 WARNING: Language en package default expects mwt, which has been added
# 2025-04-04 14:15:28 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# ======================================
#
# 2025-04-04 14:15:28 INFO: Using device: cpu
# 2025-04-04 14:15:28 INFO: Loading: tokenize
# 2025-04-04 14:15:28 INFO: Loading: mwt
# 2025-04-04 14:15:28 INFO: Loading: pos
# 2025-04-04 14:15:29 INFO: Loading: lemma
# 2025-04-04 14:15:29 INFO: Loading: constituency
# 2025-04-04 14:15:30 INFO: Loading: depparse
# 2025-04-04 14:15:30 INFO: Done loading processors!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 14:15:30 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 14:15:30 INFO: Downloading default packages for language: en (English) ...
# 2025-04-04 14:15:31 INFO: File exists: /Users/ramiibrahimi/stanza_resources/en/default.zip
# 2025-04-04 14:15:32 INFO: Finished downloading models and saved to /Users/ramiibrahimi/stanza_resources
# 2025-04-04 14:15:32 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-04 14:15:32 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-04 14:15:32 WARNING: Language en package default expects mwt, which has been added
# 2025-04-04 14:15:33 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# ======================================
#
# 2025-04-04 14:15:33 INFO: Using device: cpu
# 2025-04-04 14:15:33 INFO: Loading: tokenize
# 2025-04-04 14:15:33 INFO: Loading: mwt
# 2025-04-04 14:15:33 INFO: Loading: pos
# 2025-04-04 14:15:34 INFO: Loading: lemma
# 2025-04-04 14:15:34 INFO: Loading: constituency
# 2025-04-04 14:15:34 INFO: Loading: depparse
# 2025-04-04 14:15:34 INFO: Done loading processors!
# i is 0
# prev. line {'line': 'RAMI I. IBRAHIMI', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3966}, 'named_entity_recognition': [{'text': 'RAMI I. IBRAHIMI', 'label': 'PER', 'score': np.float32(0.9995)}], 'is_section_header': None}
# next line {'line': 'San Francisco, CA 94158 • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': True, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.7311}, 'named_entity_recognition': [{'text': 'San Francisco', 'label': 'LOC', 'score': np.float32(0.9999)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9997)}, {'text': 'riibrahimi', 'label': 'PER', 'score': np.float32(0.9785)}, {'text': '.', 'label': 'PER', 'score': np.float32(0.9891)}, {'text': 'linkedin', 'label': 'ORG', 'score': np.float32(0.8725)}, {'text': 'rami-ibrahimi', 'label': 'PER', 'score': np.float32(0.9826)}], 'is_section_header': None}
# current chunk ['RAMI I. IBRAHIMI']
# i is 1
# prev. line {'line': 'San Francisco, CA 94158 • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': True, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.7311}, 'named_entity_recognition': [{'text': 'San Francisco', 'label': 'LOC', 'score': np.float32(0.9999)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9997)}, {'text': 'riibrahimi', 'label': 'PER', 'score': np.float32(0.9785)}, {'text': '.', 'label': 'PER', 'score': np.float32(0.9891)}, {'text': 'linkedin', 'label': 'ORG', 'score': np.float32(0.8725)}, {'text': 'rami-ibrahimi', 'label': 'PER', 'score': np.float32(0.9826)}], 'is_section_header': None}
# next line {'line': 'EDUCATION', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7632}, 'named_entity_recognition': [], 'is_section_header': 'EDUCATION'}
# current chunk ['San Francisco, CA 94158 • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi']
# i is 2
# prev. line {'line': 'EDUCATION', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7632}, 'named_entity_recognition': [], 'is_section_header': 'EDUCATION'}
# next line {'line': 'University of Virginia Darden School of Business Charlottesville, VA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7668}, 'named_entity_recognition': [{'text': 'University of Virginia Darden School of Business', 'label': 'ORG', 'score': np.float32(0.992)}, {'text': 'Charlottesville', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'VA', 'label': 'LOC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# current chunk ['EDUCATION']
# i is 3
# prev. line {'line': 'University of Virginia Darden School of Business Charlottesville, VA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7668}, 'named_entity_recognition': [{'text': 'University of Virginia Darden School of Business', 'label': 'ORG', 'score': np.float32(0.992)}, {'text': 'Charlottesville', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'VA', 'label': 'LOC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# next line {'line': 'Candidate for Master of Business Administration, May 2019', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.4428}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['University of Virginia Darden School of Business Charlottesville, VA']
# i is 4
# prev. line {'line': 'Candidate for Master of Business Administration, May 2019', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.4428}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• GMAT: 720', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3921}, 'named_entity_recognition': [{'text': 'GMAT', 'label': 'MISC', 'score': np.float32(0.8596)}], 'is_section_header': None}
# current chunk ['Candidate for Master of Business Administration, May 2019']
# i is 5
# prev. line {'line': '• GMAT: 720', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3921}, 'named_entity_recognition': [{'text': 'GMAT', 'label': 'MISC', 'score': np.float32(0.8596)}], 'is_section_header': None}
# next line {'line': '• Darden Foundation Scholarship', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3708}, 'named_entity_recognition': [{'text': 'Darden Foundation', 'label': 'ORG', 'score': np.float32(0.9972)}, {'text': 'Scho', 'label': 'MISC', 'score': np.float32(0.593)}], 'is_section_header': None}
# current chunk ['• GMAT: 720']
# i is 6
# prev. line {'line': '• Darden Foundation Scholarship', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3708}, 'named_entity_recognition': [{'text': 'Darden Foundation', 'label': 'ORG', 'score': np.float32(0.9972)}, {'text': 'Scho', 'label': 'MISC', 'score': np.float32(0.593)}], 'is_section_header': None}
# next line {'line': '• Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3852}, 'named_entity_recognition': [{'text': 'Consulting, Technology, Finance, Adam Smith Society', 'label': 'ORG', 'score': np.float32(1.0)}, {'text': 'Soccer', 'label': 'ORG', 'score': np.float32(0.968)}], 'is_section_header': None}
# current chunk ['• Darden Foundation Scholarship']
# i is 7
# prev. line {'line': '• Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3852}, 'named_entity_recognition': [{'text': 'Consulting, Technology, Finance, Adam Smith Society', 'label': 'ORG', 'score': np.float32(1.0)}, {'text': 'Soccer', 'label': 'ORG', 'score': np.float32(0.968)}], 'is_section_header': None}
# next line {'line': 'University of Jordan Amman, Jordan', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.6379}, 'named_entity_recognition': [{'text': 'University of Jordan', 'label': 'ORG', 'score': np.float32(1.0)}, {'text': 'Amman', 'label': 'LOC', 'score': np.float32(0.9707)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer']
# i is 8
# prev. line {'line': 'University of Jordan Amman, Jordan', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.6379}, 'named_entity_recognition': [{'text': 'University of Jordan', 'label': 'ORG', 'score': np.float32(1.0)}, {'text': 'Amman', 'label': 'LOC', 'score': np.float32(0.9707)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': 'Bachelor of Science in Mechatronics Engineering, Jan 2013', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3386}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['University of Jordan Amman, Jordan']
# i is 9
# prev. line {'line': 'Bachelor of Science in Mechatronics Engineering, Jan 2013', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3386}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• Volunteer lecturer for Assembly & Microprocessors and Design of Embedded Systems classes', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'TECHNICAL SKILLS', 'score': 0.4172}, 'named_entity_recognition': [{'text': 'Assembly', 'label': 'MISC', 'score': np.float32(0.9093)}, {'text': 'Microprocessors', 'label': 'MISC', 'score': np.float32(0.9848)}, {'text': 'Em', 'label': 'MISC', 'score': np.float32(0.9213)}, {'text': 'Systems', 'label': 'MISC', 'score': np.float32(0.9668)}], 'is_section_header': None}
# current chunk ['Bachelor of Science in Mechatronics Engineering, Jan 2013']
# i is 10
# prev. line {'line': '• Volunteer lecturer for Assembly & Microprocessors and Design of Embedded Systems classes', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'TECHNICAL SKILLS', 'score': 0.4172}, 'named_entity_recognition': [{'text': 'Assembly', 'label': 'MISC', 'score': np.float32(0.9093)}, {'text': 'Microprocessors', 'label': 'MISC', 'score': np.float32(0.9848)}, {'text': 'Em', 'label': 'MISC', 'score': np.float32(0.9213)}, {'text': 'Systems', 'label': 'MISC', 'score': np.float32(0.9668)}], 'is_section_header': None}
# next line {'line': 'EXPERIENCE', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.448}, 'named_entity_recognition': [], 'is_section_header': 'PROFESSIONAL EXPERIENCE'}
# current chunk ['• Volunteer lecturer for Assembly & Microprocessors and Design of Embedded Systems classes']
# i is 11
# prev. line {'line': 'EXPERIENCE', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.448}, 'named_entity_recognition': [], 'is_section_header': 'PROFESSIONAL EXPERIENCE'}
# next line {'line': '2018-Present Google LLC', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.4244}, 'named_entity_recognition': [{'text': 'Google LLC', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['EXPERIENCE']
# i is 12
# prev. line {'line': '2018-Present Google LLC', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.4244}, 'named_entity_recognition': [{'text': 'Google LLC', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': 'Product Operations T/ Program Manager – Phones (2019-Present) Mountain View, CA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3846}, 'named_entity_recognition': [{'text': 'Mountain View', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['2018-Present Google LLC']
# i is 13
# prev. line {'line': 'Product Operations T/ Program Manager – Phones (2019-Present) Mountain View, CA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3846}, 'named_entity_recognition': [{'text': 'Mountain View', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Managed oversees third party team of data scientists to deliver machine learning predictive models', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3503}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['Product Operations T/ Program Manager – Phones (2019-Present) Mountain View, CA']
# i is 14
# prev. line {'line': '• Managed oversees third party team of data scientists to deliver machine learning predictive models', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3503}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'for return rates & manufacturing cell qualification resulting in reduction of 15% in qualification costs', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': True, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3895}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Managed oversees third party team of data scientists to deliver machine learning predictive models']
# i is 14
# prev. line {'line': 'for return rates & manufacturing cell qualification resulting in reduction of 15% in qualification costs', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': True, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3895}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• Created and executed new process for management of OpEx product costs in tandem with cross-', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.5413}, 'named_entity_recognition': [{'text': 'OpEx', 'label': 'ORG', 'score': np.float32(0.9998)}], 'is_section_header': None}
# current chunk ['• Managed oversees third party team of data scientists to deliver machine learning predictive models', 'for return rates & manufacturing cell qualification resulting in reduction of 15% in qualification costs']
# word costs
# pos NOUN
# count 1
# word qualification
# pos NOUN
# count 2
# word in
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word of
# pos ADP
# word reduction
# pos NOUN
# count 1
# word in
# pos ADP
# word resulting
# pos VERB
# word qualification
# pos NOUN
# count 0
# word cell
# pos NOUN
# count 1
# word manufacturing
# pos NOUN
# count 2
# word &
# pos CCONJ
# word rates
# pos NOUN
# count 1
# word return
# pos NOUN
# count 2
# word for
# pos ADP
# word models
# pos NOUN
# count 1
# word predictive
# pos ADJ
# word learning
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word deliver
# pos VERB
# word to
# pos PART
# word scientists
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word of
# pos ADP
# word team
# pos NOUN
# count 1
# word party
# pos NOUN
# count 2
# word third
# pos ADJ
# word oversees
# pos VERB
# word Managed
# pos VERB
# word •
# pos PUNCT
# i is 16
# prev. line {'line': '• Created and executed new process for management of OpEx product costs in tandem with cross-', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.5413}, 'named_entity_recognition': [{'text': 'OpEx', 'label': 'ORG', 'score': np.float32(0.9998)}], 'is_section_header': None}
# next line {'line': 'regional team resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3786}, 'named_entity_recognition': [{'text': 'Pixel 2020', 'label': 'MISC', 'score': np.float32(0.9999)}, {'text': 'Pixel 2021', 'label': 'MISC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# current chunk ['• Created and executed new process for management of OpEx product costs in tandem with cross-']
# i is 16
# prev. line {'line': 'regional team resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3786}, 'named_entity_recognition': [{'text': 'Pixel 2020', 'label': 'MISC', 'score': np.float32(0.9999)}, {'text': 'Pixel 2021', 'label': 'MISC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# next line {'line': '• Drove product headcount resource management for 8 Pixel devices from concept through end of life', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3993}, 'named_entity_recognition': [{'text': '8 Pixel', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Created and executed new process for management of OpEx product costs in tandem with cross-', 'regional team resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021']
# word 2021
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word and
# pos CCONJ
# word 2020
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word for
# pos ADP
# word savings
# pos NOUN
# count 1
# word in
# pos ADP
# word million
# pos NUM
# word 7
# pos NUM
# word $
# pos SYM
# word and
# pos CCONJ
# word million
# pos NUM
# word 3.5
# pos NUM
# word $
# pos SYM
# word in
# pos ADP
# word resulting
# pos VERB
# word team
# pos NOUN
# count 0
# word regional
# pos ADJ
# word cross-
# pos ADJ
# word with
# pos ADP
# word tandem
# pos NOUN
# count 1
# word in
# pos ADP
# word costs
# pos NOUN
# count 1
# word product
# pos NOUN
# count 2
# word OpEx
# pos NOUN
# count 3
# word of
# pos ADP
# word management
# pos NOUN
# count 1
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word executed
# pos VERB
# word and
# pos CCONJ
# word Created
# pos VERB
# word •
# pos PUNCT
# i is 18
# prev. line {'line': '• Drove product headcount resource management for 8 Pixel devices from concept through end of life', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3993}, 'named_entity_recognition': [{'text': '8 Pixel', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Managed non-device costs for Wearables business unit totaling $150 million annually', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4793}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Drove product headcount resource management for 8 Pixel devices from concept through end of life']
# i is 19
# prev. line {'line': '• Managed non-device costs for Wearables business unit totaling $150 million annually', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4793}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• Led early engagement Product investigation and feature definition for a new segment Pixel device', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.438}, 'named_entity_recognition': [{'text': 'Pixel', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Managed non-device costs for Wearables business unit totaling $150 million annually']
# i is 20
# prev. line {'line': '• Led early engagement Product investigation and feature definition for a new segment Pixel device', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.438}, 'named_entity_recognition': [{'text': 'Pixel', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3947}, 'named_entity_recognition': [{'text': 'Mountain View', 'label': 'LOC', 'score': np.float32(0.9999)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# current chunk ['• Led early engagement Product investigation and feature definition for a new segment Pixel device']
# i is 20
# prev. line {'line': 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3947}, 'named_entity_recognition': [{'text': 'Mountain View', 'label': 'LOC', 'score': np.float32(0.9999)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# next line {'line': '• Designed and implemented new process for Inventory Management Forum for next-gen flagship', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4389}, 'named_entity_recognition': [{'text': 'Inventory Management Forum', 'label': 'MISC', 'score': np.float32(0.8832)}], 'is_section_header': None}
# current chunk ['• Led early engagement Product investigation and feature definition for a new segment Pixel device', 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA']
# word CA
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word View
# pos PROPN
# count 1
# word Mountain
# pos PROPN
# count 2
# word )
# pos PUNCT
# word 2018
# pos NUM
# count 3
# word Summer
# pos NOUN
# count 4
# word (
# pos PUNCT
# word Phones
# pos NOUN
# count 5
# word –
# pos PUNCT
# word Intern
# pos NOUN
# count 6
# is not grammatical ......['• Led early engagement Product investigation and feature definition for a new segment Pixel device', 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA']
# i is 21
# prev. line {'line': 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3947}, 'named_entity_recognition': [{'text': 'Mountain View', 'label': 'LOC', 'score': np.float32(0.9999)}, {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9999)}], 'is_section_header': None}
# next line {'line': '• Designed and implemented new process for Inventory Management Forum for next-gen flagship', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4389}, 'named_entity_recognition': [{'text': 'Inventory Management Forum', 'label': 'MISC', 'score': np.float32(0.8832)}], 'is_section_header': None}
# current chunk ['Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA']
# i is 22
# prev. line {'line': '• Designed and implemented new process for Inventory Management Forum for next-gen flagship', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4389}, 'named_entity_recognition': [{'text': 'Inventory Management Forum', 'label': 'MISC', 'score': np.float32(0.8832)}], 'is_section_header': None}
# next line {'line': 'Pixel phones resulting in complete automation of the process and 80% reduction in work load', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.4013}, 'named_entity_recognition': [{'text': 'Pixel', 'label': 'MISC', 'score': np.float32(0.7755)}], 'is_section_header': None}
# current chunk ['• Designed and implemented new process for Inventory Management Forum for next-gen flagship']
# i is 22
# prev. line {'line': 'Pixel phones resulting in complete automation of the process and 80% reduction in work load', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.4013}, 'named_entity_recognition': [{'text': 'Pixel', 'label': 'MISC', 'score': np.float32(0.7755)}], 'is_section_header': None}
# next line {'line': '• Established standard Key Part Release and Master Production Schedule model and input templates', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3831}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Designed and implemented new process for Inventory Management Forum for next-gen flagship', 'Pixel phones resulting in complete automation of the process and 80% reduction in work load']
# word load
# pos NOUN
# count 1
# word work
# pos NOUN
# count 2
# word in
# pos ADP
# word reduction
# pos NOUN
# count 1
# word %
# pos SYM
# word 80
# pos NUM
# word and
# pos CCONJ
# word process
# pos NOUN
# count 1
# word the
# pos DET
# word of
# pos ADP
# word automation
# pos NOUN
# count 1
# word complete
# pos ADJ
# word in
# pos ADP
# word resulting
# pos VERB
# word phones
# pos NOUN
# count 0
# word Pixel
# pos NOUN
# count 1
# word flagship
# pos NOUN
# count 2
# word gen
# pos NOUN
# count 3
# word -
# pos PUNCT
# word next
# pos ADJ
# word for
# pos ADP
# word Forum
# pos PROPN
# count 1
# word Management
# pos PROPN
# count 2
# word Inventory
# pos PROPN
# count 3
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word implemented
# pos VERB
# word and
# pos CCONJ
# word Designed
# pos VERB
# word •
# pos PUNCT
# i is 24
# prev. line {'line': '• Established standard Key Part Release and Master Production Schedule model and input templates', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3831}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• Completely revamped Clear to Build management process leading to strategic SKU-level visibility', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.445}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Established standard Key Part Release and Master Production Schedule model and input templates']
# i is 25
# prev. line {'line': '• Completely revamped Clear to Build management process leading to strategic SKU-level visibility', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.445}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '2013-2017 Philip Morris International', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.3999}, 'named_entity_recognition': [{'text': 'Philip Morris International', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Completely revamped Clear to Build management process leading to strategic SKU-level visibility']
# i is 26
# prev. line {'line': '2013-2017 Philip Morris International', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.3999}, 'named_entity_recognition': [{'text': 'Philip Morris International', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': 'Operations Planning Analyst (2015-2017) Izmir, Turkey', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.5042}, 'named_entity_recognition': [{'text': 'Izmir', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['2013-2017 Philip Morris International']
# i is 27
# prev. line {'line': 'Operations Planning Analyst (2015-2017) Izmir, Turkey', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.5042}, 'named_entity_recognition': [{'text': 'Izmir', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3969}, 'named_entity_recognition': [{'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9987)}], 'is_section_header': None}
# current chunk ['Operations Planning Analyst (2015-2017) Izmir, Turkey']
# i is 28
# prev. line {'line': '• Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3969}, 'named_entity_recognition': [{'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9987)}], 'is_section_header': None}
# next line {'line': 'cluster head for EEMA region and the largest CPG in Turkey', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3973}, 'named_entity_recognition': [{'text': 'EEMA', 'label': 'ORG', 'score': np.float32(0.9288)}, {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the']
# i is 28
# prev. line {'line': 'cluster head for EEMA region and the largest CPG in Turkey', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3973}, 'named_entity_recognition': [{'text': 'EEMA', 'label': 'ORG', 'score': np.float32(0.9288)}, {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Directed cross-functional domestic and international project team in successful resolution of a', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.474}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the', 'cluster head for EEMA region and the largest CPG in Turkey']
# word Turkey
# pos PROPN
# count 1
# word in
# pos ADP
# word CPG
# pos NOUN
# count 1
# word largest
# pos ADJ
# word the
# pos DET
# word and
# pos CCONJ
# word region
# pos NOUN
# count 1
# word EEMA
# pos PROPN
# count 2
# word for
# pos ADP
# word head
# pos NOUN
# count 1
# word cluster
# pos NOUN
# count 2
# word the
# pos DET
# word ,
# pos PUNCT
# word affiliate
# pos NOUN
# count 1
# word Turkish
# pos ADJ
# word the
# pos DET
# word to
# pos ADP
# word assignment
# pos NOUN
# count 1
# word development
# pos NOUN
# count 2
# word leadership
# pos NOUN
# count 3
# word for
# pos ADP
# word candidates
# pos NOUN
# count 1
# word 50
# pos NUM
# word of
# pos ADP
# word out
# pos ADP
# word Selected
# pos VERB
# word •
# pos PUNCT
# i is 30
# prev. line {'line': '• Directed cross-functional domestic and international project team in successful resolution of a', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.474}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'defective company-wide data mining and reporting tool in support of 40 production line operations', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3516}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Directed cross-functional domestic and international project team in successful resolution of a']
# i is 30
# prev. line {'line': 'defective company-wide data mining and reporting tool in support of 40 production line operations', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3516}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'representing annual volume of 70 billion sticks', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3188}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Directed cross-functional domestic and international project team in successful resolution of a', 'defective company-wide data mining and reporting tool in support of 40 production line operations']
# i is 30
# prev. line {'line': 'representing annual volume of 70 billion sticks', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3188}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• Led cross functional effort across five teams to successfully launch the first product export project', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4995}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Directed cross-functional domestic and international project team in successful resolution of a', 'defective company-wide data mining and reporting tool in support of 40 production line operations', 'representing annual volume of 70 billion sticks']
# word sticks
# pos NOUN
# count 1
# word billion
# pos NUM
# word 70
# pos NUM
# word of
# pos ADP
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word representing
# pos VERB
# word operations
# pos NOUN
# count 1
# word line
# pos NOUN
# count 2
# word production
# pos NOUN
# count 3
# word 40
# pos NUM
# word of
# pos ADP
# word support
# pos NOUN
# count 1
# word in
# pos ADP
# word tool
# pos NOUN
# count 1
# word reporting
# pos NOUN
# count 2
# word and
# pos CCONJ
# word mining
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word wide
# pos ADJ
# word -
# pos PUNCT
# word company
# pos NOUN
# count 3
# word defective
# pos ADJ
# word a
# pos DET
# word of
# pos ADP
# word resolution
# pos NOUN
# count 1
# word successful
# pos ADJ
# word in
# pos ADP
# word team
# pos NOUN
# count 1
# word project
# pos NOUN
# count 2
# word international
# pos ADJ
# word and
# pos CCONJ
# word domestic
# pos ADJ
# word -functional
# pos ADJ
# word cross
# pos NOUN
# count 1
# word Directed
# pos VERB
# word •
# pos PUNCT
# i is 33
# prev. line {'line': '• Led cross functional effort across five teams to successfully launch the first product export project', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4995}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'for 23 new products across eight new African markets representing 15% of annual volume', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': True, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3579}, 'named_entity_recognition': [{'text': 'African', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Led cross functional effort across five teams to successfully launch the first product export project']
# i is 33
# prev. line {'line': 'for 23 new products across eight new African markets representing 15% of annual volume', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': True, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3579}, 'named_entity_recognition': [{'text': 'African', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Supervised the operations team for the revamp of seven strategic products including Marlboro and', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': True, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4255}, 'named_entity_recognition': [{'text': 'Marlboro', 'label': 'ORG', 'score': np.float32(0.998)}], 'is_section_header': None}
# current chunk ['• Led cross functional effort across five teams to successfully launch the first product export project', 'for 23 new products across eight new African markets representing 15% of annual volume']
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word representing
# pos VERB
# word markets
# pos NOUN
# count 0
# word African
# pos ADJ
# word new
# pos ADJ
# word eight
# pos NUM
# word across
# pos ADP
# word products
# pos NOUN
# count 1
# word new
# pos ADJ
# word 23
# pos NUM
# word for
# pos ADP
# word project
# pos NOUN
# count 1
# word export
# pos NOUN
# count 2
# word product
# pos NOUN
# count 3
# word first
# pos ADJ
# word the
# pos DET
# word launch
# pos VERB
# word successfully
# pos ADV
# word to
# pos PART
# word teams
# pos NOUN
# count 1
# word five
# pos NUM
# word across
# pos ADP
# word effort
# pos NOUN
# count 1
# word functional
# pos ADJ
# word cross
# pos NOUN
# count 2
# word Led
# pos VERB
# word •
# pos PUNCT
# i is 35
# prev. line {'line': '• Supervised the operations team for the revamp of seven strategic products including Marlboro and', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': True, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4255}, 'named_entity_recognition': [{'text': 'Marlboro', 'label': 'ORG', 'score': np.float32(0.998)}], 'is_section_header': None}
# next line {'line': 'L&M brands achieving 100% hit rate for in-market-sales timeline requirements', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3791}, 'named_entity_recognition': [{'text': 'L&M', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Supervised the operations team for the revamp of seven strategic products including Marlboro and']
# i is 35
# ...
# pos NOUN
# count 4
# word -
# pos PUNCT
# word in
# pos ADP
# word for
# pos ADP
# word rate
# pos NOUN
# count 1
# word hit
# pos NOUN
# count 2
# word %
# pos SYM
# word 100
# pos NUM
# word achieving
# pos VERB
# word brands
# pos NOUN
# count 0
# word L&M
# pos PROPN
# count 1
# word and
# pos CCONJ
# word Marlboro
# pos PROPN
# count 1
# word including
# pos VERB
# word products
# pos NOUN
# count 1
# word strategic
# pos ADJ
# word seven
# pos NUM
# word of
# pos ADP
# word revamp
# pos NOUN
# count 1
# word the
# pos DET
# word for
# pos ADP
# word team
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word the
# pos DET
# word Supervised
# pos VERB
# word •
# pos PUNCT
# i is 37
# prev. line {'line': 'Process Engineer (2014-2015) Amman, Jordan', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4476}, 'named_entity_recognition': [{'text': 'Amman', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Led two five-person teams on two production facility operations improvement projects setting four', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.459}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['Process Engineer (2014-2015) Amman, Jordan']
# i is 38
# prev. line {'line': '• Led two five-person teams on two production facility operations improvement projects setting four', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.459}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'new all-time records and achieving recognition for two key performance indicators', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.6301}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Led two five-person teams on two production facility operations improvement projects setting four']
# i is 38
# prev. line {'line': 'new all-time records and achieving recognition for two key performance indicators', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.6301}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': '• Initiated factory inventory management and categorization process for spare parts and raw materials', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4541}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Led two five-person teams on two production facility operations improvement projects setting four', 'new all-time records and achieving recognition for two key performance indicators']
# word indicators
# pos NOUN
# count 1
# word performance
# pos NOUN
# count 2
# word key
# pos ADJ
# word two
# pos NUM
# word for
# pos ADP
# word recognition
# pos NOUN
# count 1
# word achieving
# pos VERB
# word and
# pos CCONJ
# word records
# pos NOUN
# count 1
# word time
# pos NOUN
# count 2
# word -
# pos PUNCT
# word all
# pos DET
# word new
# pos ADJ
# word four
# pos NUM
# word setting
# pos VERB
# word projects
# pos NOUN
# count 0
# word improvement
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word facility
# pos NOUN
# count 3
# word production
# pos NOUN
# count 4
# word two
# pos NUM
# word on
# pos ADP
# word teams
# pos NOUN
# count 1
# word person
# pos NOUN
# count 2
# word -
# pos PUNCT
# word five
# pos NUM
# word two
# pos NUM
# word Led
# pos VERB
# word •
# pos PUNCT
# i is 40
# prev. line {'line': '• Initiated factory inventory management and categorization process for spare parts and raw materials', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4541}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'resulting in the reduction local spare parts inventory by $1 million representing 40% of total', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.348}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['• Initiated factory inventory management and categorization process for spare parts and raw materials']
# i is 40
# prev. line {'line': 'resulting in the reduction local spare parts inventory by $1 million representing 40% of total', 'is_visually_separated': False, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.348}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'inventory; received Philip Morris International Above and Beyond the Call of Duty award', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.395}, 'named_entity_recognition': [{'text': 'Philip Morris', 'label': 'ORG', 'score': np.float32(0.9554)}, {'text': 'International Above and Beyond', 'label': 'MISC', 'score': np.float32(0.9812)}, {'text': 'Call of Duty', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Initiated factory inventory management and categorization process for spare parts and raw materials', 'resulting in the reduction local spare parts inventory by $1 million representing 40% of total']
# i is 40
# prev. line {'line': 'inventory; received Philip Morris International Above and Beyond the Call of Duty award', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.395}, 'named_entity_recognition': [{'text': 'Philip Morris', 'label': 'ORG', 'score': np.float32(0.9554)}, {'text': 'International Above and Beyond', 'label': 'MISC', 'score': np.float32(0.9812)}, {'text': 'Call of Duty', 'label': 'MISC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': 'Electrical Maintenance Engineer (2013-2014) Amman, Jordan', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3849}, 'named_entity_recognition': [{'text': 'Amman', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Initiated factory inventory management and categorization process for spare parts and raw materials', 'resulting in the reduction local spare parts inventory by $1 million representing 40% of total', 'inventory; received Philip Morris International Above and Beyond the Call of Duty award']
# word award
# pos NOUN
# count 1
# word Duty
# pos NOUN
# count 2
# word of
# pos ADP
# word Call
# pos NOUN
# count 1
# word the
# pos DET
# word Beyond
# pos ADP
# word and
# pos CCONJ
# word Above
# pos ADP
# word International
# pos ADJ
# word Morris
# pos PROPN
# count 1
# word Philip
# pos PROPN
# count 2
# word received
# pos VERB
# word ;
# pos PUNCT
# word inventory
# pos NOUN
# count 1
# word total
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 40
# pos NUM
# word representing
# pos VERB
# word million
# pos NUM
# word 1
# pos NUM
# word $
# pos SYM
# word by
# pos ADP
# word inventory
# pos NOUN
# count 1
# word parts
# pos NOUN
# count 2
# word spare
# pos NOUN
# count 3
# word local
# pos ADJ
# word reduction
# pos NOUN
# count 4
# word the
# pos DET
# word in
# pos ADP
# word resulting
# pos VERB
# word materials
# pos NOUN
# count 0
# word raw
# pos ADJ
# word and
# pos CCONJ
# word parts
# pos NOUN
# count 1
# word spare
# pos NOUN
# count 2
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word categorization
# pos NOUN
# count 2
# word and
# pos CCONJ
# word management
# pos NOUN
# count 1
# word inventory
# pos NOUN
# count 2
# word factory
# pos NOUN
# count 3
# word Initiated
# pos VERB
# word •
# pos PUNCT
# i is 43
# prev. line {'line': 'Electrical Maintenance Engineer (2013-2014) Amman, Jordan', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3849}, 'named_entity_recognition': [{'text': 'Amman', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Designed and installed of track and trace weight measurement system', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4127}, 'named_entity_recognition': [], 'is_section_header': None}
# current chunk ['Electrical Maintenance Engineer (2013-2014) Amman, Jordan']
# i is 44
# prev. line {'line': '• Designed and installed of track and trace weight measurement system', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.4127}, 'named_entity_recognition': [], 'is_section_header': None}
# next line {'line': 'ADDITIONAL INFORMATION', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3345}, 'named_entity_recognition': [], 'is_section_header': 'ADDITIONAL INFORMATION & PROFESSIONAL DEVELOPMENT'}
# current chunk ['• Designed and installed of track and trace weight measurement system']
# i is 45
# prev. line {'line': 'ADDITIONAL INFORMATION', 'is_visually_separated': True, 'contains_bullet': False, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3345}, 'named_entity_recognition': [], 'is_section_header': 'ADDITIONAL INFORMATION & PROFESSIONAL DEVELOPMENT'}
# next line {'line': '• Dual Citizenship: United States & Jordan', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.3184}, 'named_entity_recognition': [{'text': 'United States', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['ADDITIONAL INFORMATION']
# i is 46
# prev. line {'line': '• Dual Citizenship: United States & Jordan', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.3184}, 'named_entity_recognition': [{'text': 'United States', 'label': 'LOC', 'score': np.float32(1.0)}, {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• Bilingual proficiency in English and Arabic, and basic proficiency in Turkish', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3306}, 'named_entity_recognition': [{'text': 'English', 'label': 'MISC', 'score': np.float32(0.9998)}, {'text': 'Arabic', 'label': 'MISC', 'score': np.float32(0.9997)}, {'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9934)}], 'is_section_header': None}
# current chunk ['• Dual Citizenship: United States & Jordan']
# i is 47
# prev. line {'line': '• Bilingual proficiency in English and Arabic, and basic proficiency in Turkish', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3306}, 'named_entity_recognition': [{'text': 'English', 'label': 'MISC', 'score': np.float32(0.9998)}, {'text': 'Arabic', 'label': 'MISC', 'score': np.float32(0.9997)}, {'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9934)}], 'is_section_header': None}
# next line {'line': '• Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3198}, 'named_entity_recognition': [{'text': 'Oxford Union', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# current chunk ['• Bilingual proficiency in English and Arabic, and basic proficiency in Turkish']
# i is 48
# prev. line {'line': '• Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates', 'is_visually_separated': False, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.3198}, 'named_entity_recognition': [{'text': 'Oxford Union', 'label': 'ORG', 'score': np.float32(1.0)}], 'is_section_header': None}
# next line {'line': '• PEARSON certified Smartphone developer', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.2806}, 'named_entity_recognition': [{'text': 'PEARSON', 'label': 'ORG', 'score': np.float32(0.502)}], 'is_section_header': None}
# current chunk ['• Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates']
# i is 49
# prev. line {'line': '• PEARSON certified Smartphone developer', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE', 'score': 0.2806}, 'named_entity_recognition': [{'text': 'PEARSON', 'label': 'ORG', 'score': np.float32(0.502)}], 'is_section_header': None}
# next line {'line': '• Accidentally appeared in the background of a romantic scene of a Turkish Soap Opera', 'is_visually_separated': True, 'contains_bullet': True, 'contains_contact_info': False, 'ends_with_conjunction': False, 'starts_with_conjunction': False, 'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.4323}, 'named_entity_recognition': [{'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9987)}], 'is_section_header': None}
# current chunk ['• PEARSON certified Smartphone developer']

# %%
for i, line in enumerate(merged_lines1):
    print(f"{i}: {line}")
# Out:
# 0: RAMI I. IBRAHIMI
# 1: San Francisco, CA 94158 • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi
# 2: EDUCATION
# 3: University of Virginia Darden School of Business Charlottesville, VA
# 4: Candidate for Master of Business Administration, May 2019
# 5: • GMAT: 720
# 6: • Darden Foundation Scholarship
# 7: • Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer
# 8: University of Jordan Amman, Jordan
# 9: Bachelor of Science in Mechatronics Engineering, Jan 2013
# 10: • Volunteer lecturer for Assembly & Microprocessors and Design of Embedded Systems classes
# 11: EXPERIENCE
# 12: 2018-Present Google LLC
# 13: Product Operations T/ Program Manager – Phones (2019-Present) Mountain View, CA
# 14: • Managed oversees third party team of data scientists to deliver machine learning predictive models for return rates & manufacturing cell qualification resulting in reduction of 15% in qualification costs
# 15: • Created and executed new process for management of OpEx product costs in tandem with cross- regional team resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021
# 16: • Drove product headcount resource management for 8 Pixel devices from concept through end of life
# 17: • Managed non-device costs for Wearables business unit totaling $150 million annually
# 18: • Led early engagement Product investigation and feature definition for a new segment Pixel device
# 19: Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA
# 20: • Designed and implemented new process for Inventory Management Forum for next-gen flagship Pixel phones resulting in complete automation of the process and 80% reduction in work load
# 21: • Established standard Key Part Release and Master Production Schedule model and input templates
# 22: • Completely revamped Clear to Build management process leading to strategic SKU-level visibility
# 23: 2013-2017 Philip Morris International
# 24: Operations Planning Analyst (2015-2017) Izmir, Turkey
# 25: • Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the cluster head for EEMA region and the largest CPG in Turkey
# 26: • Directed cross-functional domestic and international project team in successful resolution of a defective company-wide data mining and reporting tool in support of 40 production line operations representing annual volume of 70 billion sticks
# 27: • Led cross functional effort across five teams to successfully launch the first product export project for 23 new products across eight new African markets representing 15% of annual volume
# 28: • Supervised the operations team for the revamp of seven strategic products including Marlboro and L&M brands achieving 100% hit rate for in-market-sales timeline requirements
# 29: Process Engineer (2014-2015) Amman, Jordan
# 30: • Led two five-person teams on two production facility operations improvement projects setting four new all-time records and achieving recognition for two key performance indicators
# 31: • Initiated factory inventory management and categorization process for spare parts and raw materials resulting in the reduction local spare parts inventory by $1 million representing 40% of total inventory; received Philip Morris International Above and Beyond the Call of Duty award
# 32: Electrical Maintenance Engineer (2013-2014) Amman, Jordan
# 33: • Designed and installed of track and trace weight measurement system
# 34: ADDITIONAL INFORMATION
# 35: • Dual Citizenship: United States & Jordan
# 36: • Bilingual proficiency in English and Arabic, and basic proficiency in Turkish
# 37: • Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates
# 38: • PEARSON certified Smartphone developer
# 39: • Accidentally appeared in the background of a romantic scene of a Turkish Soap Opera

# %%
utils.save_object_to_pickle(merged_lines1, f"pkl/merged_lines1.pkl")
# Out:
# pickle file saved

# %%
from chunking import chunk_sections

table1b = chunk_sections.generate_line_features(merged_lines1)
table1b
# Out:
# Device set to use mps:0
# Some weights of the model checkpoint at xlm-roberta-large-finetuned-conll03-english were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0
# [{'line': 'RAMI I. IBRAHIMI',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3966},
#   'named_entity_recognition': [{'text': 'RAMI I. IBRAHIMI',
#     'label': 'PER',
#     'score': np.float32(0.9995)}],
#   'is_section_header': None},
#  {'line': 'San Francisco, CA 94158 • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': True,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.7311},
#   'named_entity_recognition': [{'text': 'San Francisco',
#     'label': 'LOC',
#     'score': np.float32(0.9999)},
#    {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9997)},
#    {'text': 'riibrahimi', 'label': 'PER', 'score': np.float32(0.9785)},
#    {'text': '.', 'label': 'PER', 'score': np.float32(0.9891)},
#    {'text': 'linkedin', 'label': 'ORG', 'score': np.float32(0.8725)},
#    {'text': 'rami-ibrahimi', 'label': 'PER', 'score': np.float32(0.9826)}],
#   'is_section_header': None},
#  {'line': 'EDUCATION',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7632},
#   'named_entity_recognition': [],
#   'is_section_header': 'EDUCATION'},
#  {'line': 'University of Virginia Darden School of Business Charlottesville, VA',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.7668},
#   'named_entity_recognition': [{'text': 'University of Virginia Darden School of Business',
#     'label': 'ORG',
#     'score': np.float32(0.992)},
#    {'text': 'Charlottesville', 'label': 'LOC', 'score': np.float32(1.0)},
#    {'text': 'VA', 'label': 'LOC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': 'Candidate for Master of Business Administration, May 2019',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.4428},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• GMAT: 720',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3921},
#   'named_entity_recognition': [{'text': 'GMAT',
#     'label': 'MISC',
#     'score': np.float32(0.8596)}],
#   'is_section_header': None},
#  {'line': '• Darden Foundation Scholarship',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3708},
#   'named_entity_recognition': [{'text': 'Darden Foundation',
#     'label': 'ORG',
#     'score': np.float32(0.9972)},
#    {'text': 'Scho', 'label': 'MISC', 'score': np.float32(0.593)}],
#   'is_section_header': None},
#  {'line': '• Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3852},
#   'named_entity_recognition': [{'text': 'Consulting, Technology, Finance, Adam Smith Society',
#     'label': 'ORG',
#     'score': np.float32(1.0)},
#    {'text': 'Soccer', 'label': 'ORG', 'score': np.float32(0.968)}],
#   'is_section_header': None},
#  {'line': 'University of Jordan Amman, Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.6379},
#   'named_entity_recognition': [{'text': 'University of Jordan',
#     'label': 'ORG',
#     'score': np.float32(1.0)},
#    {'text': 'Amman', 'label': 'LOC', 'score': np.float32(0.9707)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Bachelor of Science in Mechatronics Engineering, Jan 2013',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'EDUCATION', 'score': 0.3386},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Volunteer lecturer for Assembly & Microprocessors and Design of Embedded Systems classes',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'TECHNICAL SKILLS', 'score': 0.4172},
#   'named_entity_recognition': [{'text': 'Assembly',
#     'label': 'MISC',
#     'score': np.float32(0.9093)},
#    {'text': 'Microprocessors', 'label': 'MISC', 'score': np.float32(0.9848)},
#    {'text': 'Em', 'label': 'MISC', 'score': np.float32(0.9213)},
#    {'text': 'Systems', 'label': 'MISC', 'score': np.float32(0.9668)}],
#   'is_section_header': None},
#  {'line': 'EXPERIENCE',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.448},
#   'named_entity_recognition': [],
#   'is_section_header': 'PROFESSIONAL EXPERIENCE'},
#  {'line': '2018-Present Google LLC',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.4244},
#   'named_entity_recognition': [{'text': 'Google LLC',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Product Operations T/ Program Manager – Phones (2019-Present) Mountain View, CA',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3846},
#   'named_entity_recognition': [{'text': 'Mountain View',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'CA', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Managed oversees third party team of data scientists to deliver machine learning predictive models for return rates & manufacturing cell qualification resulting in reduction of 15% in qualification costs',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4838},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Created and executed new process for management of OpEx product costs in tandem with cross- regional team resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.5456},
#   'named_entity_recognition': [{'text': 'OpEx',
#     'label': 'ORG',
#     'score': np.float32(0.9761)},
#    {'text': 'Pixel 2020', 'label': 'MISC', 'score': np.float32(0.9999)},
#    {'text': 'Pixel 2021', 'label': 'MISC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': '• Drove product headcount resource management for 8 Pixel devices from concept through end of life',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3993},
#   'named_entity_recognition': [{'text': '8 Pixel',
#     'label': 'MISC',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Managed non-device costs for Wearables business unit totaling $150 million annually',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4793},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Led early engagement Product investigation and feature definition for a new segment Pixel device',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.438},
#   'named_entity_recognition': [{'text': 'Pixel',
#     'label': 'MISC',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3947},
#   'named_entity_recognition': [{'text': 'Mountain View',
#     'label': 'LOC',
#     'score': np.float32(0.9999)},
#    {'text': 'CA', 'label': 'LOC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': '• Designed and implemented new process for Inventory Management Forum for next-gen flagship Pixel phones resulting in complete automation of the process and 80% reduction in work load',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4025},
#   'named_entity_recognition': [{'text': 'Inventory Management Forum',
#     'label': 'ORG',
#     'score': np.float32(0.7874)},
#    {'text': 'Pixel', 'label': 'MISC', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': '• Established standard Key Part Release and Master Production Schedule model and input templates',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3831},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Completely revamped Clear to Build management process leading to strategic SKU-level visibility',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.445},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '2013-2017 Philip Morris International',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'COMPANY LINE', 'score': 0.3999},
#   'named_entity_recognition': [{'text': 'Philip Morris International',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': 'Operations Planning Analyst (2015-2017) Izmir, Turkey',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.5042},
#   'named_entity_recognition': [{'text': 'Izmir',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the cluster head for EEMA region and the largest CPG in Turkey',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4206},
#   'named_entity_recognition': [{'text': 'Turki',
#     'label': 'MISC',
#     'score': np.float32(1.0)},
#    {'text': 'EEMA', 'label': 'ORG', 'score': np.float32(0.9987)},
#    {'text': 'Turkey', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Directed cross-functional domestic and international project team in successful resolution of a defective company-wide data mining and reporting tool in support of 40 production line operations representing annual volume of 70 billion sticks',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4391},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Led cross functional effort across five teams to successfully launch the first product export project for 23 new products across eight new African markets representing 15% of annual volume',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.5147},
#   'named_entity_recognition': [{'text': 'African',
#     'label': 'MISC',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Supervised the operations team for the revamp of seven strategic products including Marlboro and L&M brands achieving 100% hit rate for in-market-sales timeline requirements',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4772},
#   'named_entity_recognition': [{'text': 'Marlboro',
#     'label': 'ORG',
#     'score': np.float32(0.9983)},
#    {'text': 'L&M', 'label': 'ORG', 'score': np.float32(0.9999)}],
#   'is_section_header': None},
#  {'line': 'Process Engineer (2014-2015) Amman, Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4476},
#   'named_entity_recognition': [{'text': 'Amman',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Led two five-person teams on two production facility operations improvement projects setting four new all-time records and achieving recognition for two key performance indicators',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.5165},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': '• Initiated factory inventory management and categorization process for spare parts and raw materials resulting in the reduction local spare parts inventory by $1 million representing 40% of total inventory; received Philip Morris International Above and Beyond the Call of Duty award',
#   'is_visually_separated': False,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4681},
#   'named_entity_recognition': [{'text': 'Philip Morris International',
#     'label': 'ORG',
#     'score': np.float32(0.9367)},
#    {'text': 'Above and Beyond the Call of Duty',
#     'label': 'MISC',
#     'score': np.float32(0.9885)}],
#   'is_section_header': None},
#  {'line': 'Electrical Maintenance Engineer (2013-2014) Amman, Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3849},
#   'named_entity_recognition': [{'text': 'Amman',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Designed and installed of track and trace weight measurement system',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.4127},
#   'named_entity_recognition': [],
#   'is_section_header': None},
#  {'line': 'ADDITIONAL INFORMATION',
#   'is_visually_separated': True,
#   'contains_bullet': False,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.3345},
#   'named_entity_recognition': [],
#   'is_section_header': 'ADDITIONAL INFORMATION & PROFESSIONAL DEVELOPMENT'},
#  {'line': '• Dual Citizenship: United States & Jordan',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'CONTACT INFO', 'score': 0.3184},
#   'named_entity_recognition': [{'text': 'United States',
#     'label': 'LOC',
#     'score': np.float32(1.0)},
#    {'text': 'Jordan', 'label': 'LOC', 'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• Bilingual proficiency in English and Arabic, and basic proficiency in Turkish',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3306},
#   'named_entity_recognition': [{'text': 'English',
#     'label': 'MISC',
#     'score': np.float32(0.9998)},
#    {'text': 'Arabic', 'label': 'MISC', 'score': np.float32(0.9997)},
#    {'text': 'Turkish', 'label': 'MISC', 'score': np.float32(0.9934)}],
#   'is_section_header': None},
#  {'line': '• Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.3198},
#   'named_entity_recognition': [{'text': 'Oxford Union',
#     'label': 'ORG',
#     'score': np.float32(1.0)}],
#   'is_section_header': None},
#  {'line': '• PEARSON certified Smartphone developer',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'PROFESSIONAL EXPERIENCE',
#    'score': 0.2806},
#   'named_entity_recognition': [{'text': 'PEARSON',
#     'label': 'ORG',
#     'score': np.float32(0.502)}],
#   'is_section_header': None},
#  {'line': '• Accidentally appeared in the background of a romantic scene of a Turkish Soap Opera',
#   'is_visually_separated': True,
#   'contains_bullet': True,
#   'contains_contact_info': False,
#   'ends_with_conjunction': False,
#   'starts_with_conjunction': False,
#   'zero_shot_classification': {'label': 'JOB TITLE', 'score': 0.4323},
#   'named_entity_recognition': [{'text': 'Turkish',
#     'label': 'MISC',
#     'score': np.float32(0.9987)}],
#   'is_section_header': None}]

# %%
utils.save_object_to_pickle(table1b, f"pkl/table1b2.pkl")
# Out:
# pickle file saved
