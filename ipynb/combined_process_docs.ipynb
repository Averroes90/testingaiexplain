# %%
from utils import generate_csv

base_folder = "/Users/ramiibrahimi/Documents/testingaiexplain/base_folder/"
input_csv = "csv/my_corpus.csv"
generate_csv(base_folder, input_csv)
output_csv = "csv/"
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 15 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)

# %%
import pandas as pd

data_url = input_csv
data_df = pd.read_csv(data_url)

# %%
from nlp.combine import (
    process_dataframe,
    create_combined_csv,
)
# Out:
# Device set to use mps:0
# Some weights of the model checkpoint at xlm-roberta-large-finetuned-conll03-english were not used when initializing XLMRobertaForTokenClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing XLMRobertaForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use mps:0
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-06 15:11:10 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-06 15:11:10 INFO: Downloading default packages for language: en (English) ...
# 2025-04-06 15:11:11 INFO: File exists: /Users/ramiibrahimi/stanza_resources/en/default.zip
# 2025-04-06 15:11:12 INFO: Finished downloading models and saved to /Users/ramiibrahimi/stanza_resources
# 2025-04-06 15:11:12 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-06 15:11:12 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-06 15:11:12 WARNING: Language en package default expects mwt, which has been added
# 2025-04-06 15:11:13 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# ======================================
#
# 2025-04-06 15:11:13 INFO: Using device: cpu
# 2025-04-06 15:11:13 INFO: Loading: tokenize
# 2025-04-06 15:11:13 INFO: Loading: mwt
# 2025-04-06 15:11:13 INFO: Loading: pos
# 2025-04-06 15:11:14 INFO: Loading: lemma
# 2025-04-06 15:11:14 INFO: Loading: constituency
# 2025-04-06 15:11:14 INFO: Loading: depparse
# 2025-04-06 15:11:14 INFO: Done loading processors!
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-06 15:11:15 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-06 15:11:15 INFO: Downloading default packages for language: en (English) ...
# 2025-04-06 15:11:15 INFO: File exists: /Users/ramiibrahimi/stanza_resources/en/default.zip
# 2025-04-06 15:11:17 INFO: Finished downloading models and saved to /Users/ramiibrahimi/stanza_resources
# 2025-04-06 15:11:17 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.10.0.json:   0%|  …
# 2025-04-06 15:11:17 INFO: Downloaded file to /Users/ramiibrahimi/stanza_resources/resources.json
# 2025-04-06 15:11:17 WARNING: Language en package default expects mwt, which has been added
# 2025-04-06 15:11:18 INFO: Loading these models for language: en (English):
# ======================================
# | Processor    | Package             |
# --------------------------------------
# | tokenize     | combined            |
# | mwt          | combined            |
# | pos          | combined_charlm     |
# | lemma        | combined_nocharlm   |
# | constituency | ptb3-revised_charlm |
# | depparse     | combined_charlm     |
# ======================================
#
# 2025-04-06 15:11:18 INFO: Using device: cpu
# 2025-04-06 15:11:18 INFO: Loading: tokenize
# 2025-04-06 15:11:18 INFO: Loading: mwt
# 2025-04-06 15:11:18 INFO: Loading: pos
# 2025-04-06 15:11:18 INFO: Loading: lemma
# 2025-04-06 15:11:19 INFO: Loading: constituency
# 2025-04-06 15:11:19 INFO: Loading: depparse
# 2025-04-06 15:11:19 INFO: Done loading processors!

# %%
parsed_resumes, parsed_essays = process_dataframe(data_df)
create_combined_csv(parsed_resumes, parsed_essays, output_csv)
# Out:
# total similarity: 0.29072049260139465
# === compute_dynamic_resolution Debug ===
# n         : 26
# T         : 643
# S_avg     : 0.2907
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9371
# R (clamped): 0.9371
# ========================================
# total similarity: 0.2768072187900543
# === compute_dynamic_resolution Debug ===
# n         : 34
# T         : 900
# S_avg     : 0.2768
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9499
# R (clamped): 0.9499
# ========================================
# total similarity: 0.1870245784521103
# === compute_dynamic_resolution Debug ===
# n         : 53
# T         : 1025
# S_avg     : 0.1870
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9721
# R (clamped): 0.9721
# ========================================
# total similarity: 0.24256058037281036
# === compute_dynamic_resolution Debug ===
# n         : 23
# T         : 663
# S_avg     : 0.2426
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9475
# R (clamped): 0.9475
# ========================================
# total similarity: 0.2254609316587448
# === compute_dynamic_resolution Debug ===
# n         : 13
# T         : 334
# S_avg     : 0.2255
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9305
# R (clamped): 0.9305
# ========================================
# total similarity: 0.20293468236923218
# === compute_dynamic_resolution Debug ===
# n         : 29
# T         : 615
# S_avg     : 0.2029
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9535
# R (clamped): 0.9535
# ========================================
# total similarity: 0.17424005270004272
# === compute_dynamic_resolution Debug ===
# n         : 22
# T         : 483
# S_avg     : 0.1742
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9519
# R (clamped): 0.9519
# ========================================
# total similarity: 0.3879474699497223
# === compute_dynamic_resolution Debug ===
# n         : 19
# T         : 607
# S_avg     : 0.3879
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9156
# R (clamped): 0.9156
# ========================================
# total similarity: 0.4141662120819092
# === compute_dynamic_resolution Debug ===
# n         : 18
# T         : 546
# S_avg     : 0.4142
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9073
# R (clamped): 0.9073
# ========================================
# total similarity: 0.41839542984962463
# === compute_dynamic_resolution Debug ===
# n         : 19
# T         : 558
# S_avg     : 0.4184
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9071
# R (clamped): 0.9071
# ========================================
# total similarity: 0.3967958688735962
# === compute_dynamic_resolution Debug ===
# n         : 18
# T         : 558
# S_avg     : 0.3968
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9114
# R (clamped): 0.9114
# ========================================
# total similarity: 0.384650319814682
# === compute_dynamic_resolution Debug ===
# n         : 21
# T         : 663
# S_avg     : 0.3847
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9190
# R (clamped): 0.9190
# ========================================
# total similarity: 0.38640096783638
# === compute_dynamic_resolution Debug ===
# n         : 18
# T         : 537
# S_avg     : 0.3864
# base_res  : 0.6
# k1        : 0.03
# k2        : 0.2
# R (raw)   : 0.9123
# R (clamped): 0.9123
# ========================================
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word representing
# pos VERB
# word markets
# pos NOUN
# count 0
# word African
# pos ADJ
# word new
# pos ADJ
# word eight
# pos NUM
# word across
# pos ADP
# word products
# pos NOUN
# count 1
# word new
# pos ADJ
# word 23
# pos NUM
# word for
# pos ADP
# word project
# pos NOUN
# count 1
# word export
# pos NOUN
# count 2
# word product
# pos NOUN
# count 3
# word first
# pos ADJ
# word the
# pos DET
# word launch
# pos VERB
# word successfully
# pos ADV
# word to
# pos PART
# word teams
# pos NOUN
# count 1
# word five
# pos NUM
# word across
# pos ADP
# word effort
# pos NOUN
# count 1
# word functional
# pos ADJ
# word cross
# pos NOUN
# count 2
# word Led
# pos VERB
# word sticks
# pos NOUN
# count 2
# word billion
# pos NUM
# word 70
# pos NUM
# word of
# pos ADP
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word representing
# pos VERB
# word operations
# pos NOUN
# count 1
# word line
# pos NOUN
# count 2
# word production
# pos NOUN
# count 3
# word 40
# pos NUM
# word of
# pos ADP
# word support
# pos NOUN
# count 1
# word in
# pos ADP
# word tool
# pos NOUN
# count 1
# word reporting
# pos NOUN
# count 2
# word and
# pos CCONJ
# word mining
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word wide
# pos ADJ
# word -
# pos PUNCT
# word company
# pos NOUN
# count 3
# word defective
# pos ADJ
# word a
# pos DET
# word of
# pos ADP
# word resolution
# pos NOUN
# count 1
# word successful
# pos ADJ
# word in
# pos ADP
# word team
# pos NOUN
# count 1
# word project
# pos NOUN
# count 2
# word international
# pos ADJ
# word and
# pos CCONJ
# word domestic
# pos ADJ
# word cross-functional
# pos ADJ
# word Directed
# pos VERB
# word Jordan
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word Amman
# pos PROPN
# count 1
# word )
# pos PUNCT
# word 2014
# pos NUM
# count 2
# word -
# pos SYM
# word 2013
# pos NUM
# count 3
# word (
# pos PUNCT
# word Engineer
# pos PROPN
# count 4
# word Maintenance
# pos PROPN
# count 5
# word Electrical
# pos ADJ
# word award
# pos NOUN
# count 6
# is not grammatical ......['Initiated factory inventory management and categorization process for spare parts and raw materials resulting in the reduction local spare parts inventory by $1 million representing 40% of total inventory; received Philip Morris International Above and Beyond the Call of Duty award', 'Electrical Maintenance Engineer (2013-2014) Amman, Jordan']
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word representing
# pos VERB
# word markets
# pos NOUN
# count 0
# word African
# pos ADJ
# word new
# pos ADJ
# word eight
# pos NUM
# word across
# pos ADP
# word products
# pos NOUN
# count 1
# word new
# pos ADJ
# word 23
# pos NUM
# word for
# pos ADP
# word project
# pos NOUN
# count 1
# word export
# pos NOUN
# count 2
# word first
# pos ADJ
# word the
# pos DET
# word launch
# pos VERB
# word successfully
# pos ADV
# word to
# pos PART
# word teams
# pos NOUN
# count 1
# word five
# pos NUM
# word across
# pos ADP
# word effort
# pos NOUN
# count 1
# word -functional
# pos ADJ
# word cross
# pos NOUN
# count 2
# word Led
# pos VERB
# word sticks
# pos NOUN
# count 2
# word billion
# pos NUM
# word 70
# pos NUM
# word of
# pos ADP
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word representing
# pos VERB
# word operations
# pos NOUN
# count 1
# word line
# pos NOUN
# count 2
# word production
# pos NOUN
# count 3
# word 40
# pos NUM
# word of
# pos ADP
# word support
# pos NOUN
# count 1
# word in
# pos ADP
# word tool
# pos NOUN
# count 1
# word reporting
# pos NOUN
# count 2
# word and
# pos CCONJ
# word mining
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word wide
# pos ADJ
# word -
# pos PUNCT
# word company
# pos NOUN
# count 3
# word defective
# pos ADJ
# word a
# pos DET
# word of
# pos ADP
# word resolution
# pos NOUN
# count 1
# word successful
# pos ADJ
# word in
# pos ADP
# word team
# pos NOUN
# count 1
# word project
# pos NOUN
# count 2
# word international
# pos ADJ
# word and
# pos CCONJ
# word domestic
# pos ADJ
# word cross-functional
# pos ADJ
# word Directed
# pos VERB
# word Jordan
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word Amman
# pos PROPN
# count 1
# word )
# pos PUNCT
# word 2014
# pos NUM
# count 2
# word -
# pos SYM
# word 2013
# pos NUM
# count 3
# word (
# pos PUNCT
# word Engineer
# pos PROPN
# count 4
# word Electrical
# pos ADJ
# word award
# pos NOUN
# count 5
# word Duty
# pos NOUN
# count 6
# is not grammatical ......['Initiated factory inventory management and categorization process for spare parts and raw materials resulting in the reduction local inventory by $1 million representing 40% of total inventory; received Philip Morris International Above and Beyond the Call of Duty award', 'Electrical Engineer (2013-2014) Amman, Jordan']
# word costs
# pos NOUN
# count 1
# word qualification
# pos NOUN
# count 2
# word in
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word of
# pos ADP
# word reduction
# pos NOUN
# count 1
# word in
# pos ADP
# word resulting
# pos VERB
# word qualification
# pos NOUN
# count 0
# word cell
# pos NOUN
# count 1
# word manufacturing
# pos NOUN
# count 2
# word &
# pos CCONJ
# word rates
# pos NOUN
# count 1
# word return
# pos NOUN
# count 2
# word for
# pos ADP
# word models
# pos NOUN
# count 1
# word predictive
# pos ADJ
# word learning
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word deliver
# pos VERB
# word to
# pos PART
# word scientists
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word of
# pos ADP
# word team
# pos NOUN
# count 1
# word party
# pos NOUN
# count 2
# word third
# pos ADJ
# word oversees
# pos VERB
# word Managed
# pos VERB
# word •
# pos PUNCT
# word 2021
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word and
# pos CCONJ
# word 2020
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word for
# pos ADP
# word savings
# pos NOUN
# count 1
# word in
# pos ADP
# word million
# pos NUM
# word 7
# pos NUM
# word $
# pos SYM
# word and
# pos CCONJ
# word million
# pos NUM
# word 3.5
# pos NUM
# word $
# pos SYM
# word in
# pos ADP
# word resulting
# pos VERB
# word team
# pos NOUN
# count 0
# word regional
# pos ADJ
# word cross-
# pos ADJ
# word with
# pos ADP
# word tandem
# pos NOUN
# count 1
# word in
# pos ADP
# word costs
# pos NOUN
# count 1
# word product
# pos NOUN
# count 2
# word OpEx
# pos NOUN
# count 3
# word of
# pos ADP
# word management
# pos NOUN
# count 1
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word executed
# pos VERB
# word and
# pos CCONJ
# word Created
# pos VERB
# word •
# pos PUNCT
# word CA
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word View
# pos PROPN
# count 1
# word Mountain
# pos PROPN
# count 2
# word )
# pos PUNCT
# word 2018
# pos NUM
# count 3
# word Summer
# pos NOUN
# count 4
# word (
# pos PUNCT
# word Phones
# pos NOUN
# count 5
# word –
# pos PUNCT
# word Intern
# pos NOUN
# count 6
# is not grammatical ......['• Led early engagement Product investigation and feature definition for a new segment Pixel device', 'Hardware, Product Operations MBA Intern – Phones (Summer 2018) Mountain View, CA']
# word load
# pos NOUN
# count 1
# word work
# pos NOUN
# count 2
# word in
# pos ADP
# word reduction
# pos NOUN
# count 1
# word %
# pos SYM
# word 80
# pos NUM
# word and
# pos CCONJ
# word process
# pos NOUN
# count 1
# word the
# pos DET
# word of
# pos ADP
# word automation
# pos NOUN
# count 1
# word complete
# pos ADJ
# word in
# pos ADP
# word resulting
# pos VERB
# word phones
# pos NOUN
# count 0
# word Pixel
# pos NOUN
# count 1
# word flagship
# pos NOUN
# count 2
# word gen
# pos NOUN
# count 3
# word -
# pos PUNCT
# word next
# pos ADJ
# word for
# pos ADP
# word Forum
# pos PROPN
# count 1
# word Management
# pos PROPN
# count 2
# word Inventory
# pos PROPN
# count 3
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word implemented
# pos VERB
# word and
# pos CCONJ
# word Designed
# pos VERB
# word •
# pos PUNCT
# word Turkey
# pos PROPN
# count 1
# word in
# pos ADP
# word CPG
# pos NOUN
# count 1
# word largest
# pos ADJ
# word the
# pos DET
# word and
# pos CCONJ
# word region
# pos NOUN
# count 1
# word EEMA
# pos PROPN
# count 2
# word for
# pos ADP
# word head
# pos NOUN
# count 1
# word cluster
# pos NOUN
# count 2
# word the
# pos DET
# word ,
# pos PUNCT
# word affiliate
# pos NOUN
# count 1
# word Turkish
# pos ADJ
# word the
# pos DET
# word to
# pos ADP
# word assignment
# pos NOUN
# count 1
# word development
# pos NOUN
# count 2
# word leadership
# pos NOUN
# count 3
# word for
# pos ADP
# word candidates
# pos NOUN
# count 1
# word 50
# pos NUM
# word of
# pos ADP
# word out
# pos ADP
# word Selected
# pos VERB
# word •
# pos PUNCT
# word sticks
# pos NOUN
# count 1
# word billion
# pos NUM
# word 70
# pos NUM
# word of
# pos ADP
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word representing
# pos VERB
# word operations
# pos NOUN
# count 1
# word line
# pos NOUN
# count 2
# word production
# pos NOUN
# count 3
# word 40
# pos NUM
# word of
# pos ADP
# word support
# pos NOUN
# count 1
# word in
# pos ADP
# word tool
# pos NOUN
# count 1
# word reporting
# pos NOUN
# count 2
# word and
# pos CCONJ
# word mining
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word wide
# pos ADJ
# word -
# pos PUNCT
# word company
# pos NOUN
# count 3
# word defective
# pos ADJ
# word a
# pos DET
# word of
# pos ADP
# word resolution
# pos NOUN
# count 1
# word successful
# pos ADJ
# word in
# pos ADP
# word team
# pos NOUN
# count 1
# word project
# pos NOUN
# count 2
# word international
# pos ADJ
# word and
# pos CCONJ
# word domestic
# pos ADJ
# word -functional
# pos ADJ
# word cross
# pos NOUN
# count 1
# word Directed
# pos VERB
# word •
# pos PUNCT
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word representing
# pos VERB
# word markets
# pos NOUN
# count 0
# word African
# pos ADJ
# word new
# pos ADJ
# word eight
# pos NUM
# word across
# pos ADP
# word products
# pos NOUN
# count 1
# word new
# pos ADJ
# word 23
# pos NUM
# word for
# pos ADP
# word project
# pos NOUN
# count 1
# word export
# pos NOUN
# count 2
# word product
# pos NOUN
# count 3
# word first
# pos ADJ
# word the
# pos DET
# word launch
# pos VERB
# word successfully
# pos ADV
# word to
# pos PART
# word teams
# pos NOUN
# count 1
# word five
# pos NUM
# word across
# pos ADP
# word effort
# pos NOUN
# count 1
# word functional
# pos ADJ
# word cross
# pos NOUN
# count 2
# word Led
# pos VERB
# word •
# pos PUNCT
# word requirements
# pos NOUN
# count 1
# word timeline
# pos NOUN
# count 2
# word sales
# pos NOUN
# count 3
# word -
# pos PUNCT
# word market
# pos NOUN
# count 4
# word -
# pos PUNCT
# word in
# pos ADP
# word for
# pos ADP
# word rate
# pos NOUN
# count 1
# word hit
# pos NOUN
# count 2
# word %
# pos SYM
# word 100
# pos NUM
# word achieving
# pos VERB
# word brands
# pos NOUN
# count 0
# word L&M
# pos PROPN
# count 1
# word and
# pos CCONJ
# word Marlboro
# pos PROPN
# count 1
# word including
# pos VERB
# word products
# pos NOUN
# count 1
# word strategic
# pos ADJ
# word seven
# pos NUM
# word of
# pos ADP
# word revamp
# pos NOUN
# count 1
# word the
# pos DET
# word for
# pos ADP
# word team
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word the
# pos DET
# word Supervised
# pos VERB
# word •
# pos PUNCT
# word indicators
# pos NOUN
# count 1
# word performance
# pos NOUN
# count 2
# word key
# pos ADJ
# word two
# pos NUM
# word for
# pos ADP
# word recognition
# pos NOUN
# count 1
# word achieving
# pos VERB
# word and
# pos CCONJ
# word records
# pos NOUN
# count 1
# word time
# pos NOUN
# count 2
# word -
# pos PUNCT
# word all
# pos DET
# word new
# pos ADJ
# word four
# pos NUM
# word setting
# pos VERB
# word projects
# pos NOUN
# count 0
# word improvement
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word facility
# pos NOUN
# count 3
# word production
# pos NOUN
# count 4
# word two
# pos NUM
# word on
# pos ADP
# word teams
# pos NOUN
# count 1
# word person
# pos NOUN
# count 2
# word -
# pos PUNCT
# word five
# pos NUM
# word two
# pos NUM
# word Led
# pos VERB
# word •
# pos PUNCT
# word award
# pos NOUN
# count 1
# word Duty
# pos NOUN
# count 2
# word of
# pos ADP
# word Call
# pos NOUN
# count 1
# word the
# pos DET
# word Beyond
# pos ADP
# word and
# pos CCONJ
# word Above
# pos ADP
# word International
# pos ADJ
# word Morris
# pos PROPN
# count 1
# word Philip
# pos PROPN
# count 2
# word received
# pos VERB
# word ;
# pos PUNCT
# word inventory
# pos NOUN
# count 1
# word total
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 40
# pos NUM
# word representing
# pos VERB
# word million
# pos NUM
# word 1
# pos NUM
# word $
# pos SYM
# word by
# pos ADP
# word inventory
# pos NOUN
# count 1
# word parts
# pos NOUN
# count 2
# word spare
# pos NOUN
# count 3
# word local
# pos ADJ
# word reduction
# pos NOUN
# count 4
# word the
# pos DET
# word in
# pos ADP
# word resulting
# pos VERB
# word materials
# pos NOUN
# count 0
# word raw
# pos ADJ
# word and
# pos CCONJ
# word parts
# pos NOUN
# count 1
# word spare
# pos NOUN
# count 2
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word categorization
# pos NOUN
# count 2
# word and
# pos CCONJ
# word management
# pos NOUN
# count 1
# word inventory
# pos NOUN
# count 2
# word factory
# pos NOUN
# count 3
# word Initiated
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word engineering
# pos NOUN
# count 1
# word and
# pos CCONJ
# word operations
# pos NOUN
# count 1
# word learning
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word to
# pos ADP
# word operations
# pos NOUN
# count 1
# word product
# pos NOUN
# count 2
# word from
# pos ADP
# word transitioning
# pos VERB
# word ,
# pos PUNCT
# word MBA
# pos NOUN
# count 1
# word an
# pos DET
# word and
# pos CCONJ
# word background
# pos NOUN
# count 1
# word engineering
# pos NOUN
# count 2
# word an
# pos DET
# word with
# pos ADP
# word professional
# pos ADJ
# word AI
# pos PROPN
# count 1
# word Certified
# pos VERB
# word teams
# pos NOUN
# count 1
# word cross-functional
# pos ADJ
# word managing
# pos VERB
# word and
# pos CCONJ
# word ,
# pos PUNCT
# word manipulation
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word big
# pos ADJ
# word ,
# pos PUNCT
# word models
# pos NOUN
# count 1
# word predictive
# pos ADJ
# word building
# pos VERB
# word in
# pos SCONJ
# word experience
# pos NOUN
# count 1
# word on
# pos ADP
# word -
# pos PUNCT
# word Hands
# pos NOUN
# count 1
# word respectively
# pos ADV
# word 2021
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word and
# pos CCONJ
# word 2020
# pos NUM
# count 1
# word Pixel
# pos PROPN
# count 2
# word for
# pos ADP
# word savings
# pos NOUN
# count 1
# word in
# pos ADP
# word million
# pos NUM
# word 7
# pos NUM
# word $
# pos SYM
# word and
# pos CCONJ
# word million
# pos NUM
# word 3.5
# pos NUM
# word $
# pos SYM
# word in
# pos ADP
# word resulting
# pos VERB
# word team
# pos NOUN
# count 0
# word cross-regional
# pos ADJ
# word with
# pos ADP
# word tandem
# pos NOUN
# count 1
# word in
# pos ADP
# word costs
# pos NOUN
# count 1
# word product
# pos NOUN
# count 2
# word OpEx
# pos NOUN
# count 3
# word of
# pos ADP
# word management
# pos NOUN
# count 1
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word executed
# pos VERB
# word and
# pos CCONJ
# word Created
# pos VERB
# word •
# pos PUNCT
# word costs
# pos NOUN
# count 1
# word qualification
# pos NOUN
# count 2
# word in
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word of
# pos ADP
# word reduction
# pos NOUN
# count 1
# word in
# pos ADP
# word resulting
# pos VERB
# word qualification
# pos NOUN
# count 0
# word cell
# pos NOUN
# count 1
# word manufacturing
# pos NOUN
# count 2
# word &
# pos CCONJ
# word rates
# pos NOUN
# count 1
# word return
# pos NOUN
# count 2
# word for
# pos ADP
# word models
# pos NOUN
# count 1
# word predictive
# pos ADJ
# word learning
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word deliver
# pos VERB
# word to
# pos PART
# word scientists
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word of
# pos ADP
# word team
# pos NOUN
# count 1
# word overseas
# pos ADJ
# word Managed
# pos VERB
# word •
# pos PUNCT
# word load
# pos NOUN
# count 1
# word work
# pos NOUN
# count 2
# word in
# pos ADP
# word reduction
# pos NOUN
# count 1
# word %
# pos SYM
# word 80
# pos NUM
# word and
# pos CCONJ
# word process
# pos NOUN
# count 1
# word the
# pos DET
# word of
# pos ADP
# word automation
# pos NOUN
# count 1
# word complete
# pos ADJ
# word in
# pos ADP
# word resulting
# pos VERB
# word devices
# pos NOUN
# count 0
# word Pixel
# pos NOUN
# count 1
# word flagship
# pos NOUN
# count 2
# word gen
# pos NOUN
# count 3
# word -
# pos PUNCT
# word next
# pos ADJ
# word for
# pos ADP
# word Forum
# pos PROPN
# count 1
# word Management
# pos PROPN
# count 2
# word Inventory
# pos PROPN
# count 3
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word new
# pos ADJ
# word implemented
# pos VERB
# word and
# pos CCONJ
# word Designed
# pos VERB
# word •
# pos PUNCT
# word requirements
# pos NOUN
# count 1
# word timeline
# pos NOUN
# count 2
# word sales
# pos NOUN
# count 3
# word -
# pos PUNCT
# word market
# pos NOUN
# count 4
# word -
# pos PUNCT
# word in
# pos ADP
# word for
# pos ADP
# word rate
# pos NOUN
# count 1
# word hit
# pos NOUN
# count 2
# word %
# pos SYM
# word 100
# pos NUM
# word achieving
# pos VERB
# word brands
# pos NOUN
# count 0
# word L&M
# pos PROPN
# count 1
# word and
# pos CCONJ
# word Marlboro
# pos PROPN
# count 1
# word including
# pos VERB
# word products
# pos NOUN
# count 1
# word strategic
# pos ADJ
# word seven
# pos NUM
# word of
# pos ADP
# word revamp
# pos NOUN
# count 1
# word the
# pos DET
# word for
# pos ADP
# word team
# pos NOUN
# count 1
# word operations
# pos NOUN
# count 2
# word the
# pos DET
# word Supervised
# pos VERB
# word •
# pos PUNCT
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 15
# pos NUM
# word representing
# pos VERB
# word markets
# pos NOUN
# count 0
# word African
# pos ADJ
# word new
# pos ADJ
# word eight
# pos NUM
# word across
# pos ADP
# word products
# pos NOUN
# count 1
# word new
# pos ADJ
# word 23
# pos NUM
# word for
# pos ADP
# word project
# pos NOUN
# count 1
# word export
# pos NOUN
# count 2
# word first
# pos ADJ
# word the
# pos DET
# word launch
# pos VERB
# word successfully
# pos ADV
# word to
# pos PART
# word teams
# pos NOUN
# count 1
# word five
# pos NUM
# word across
# pos ADP
# word effort
# pos NOUN
# count 1
# word -functional
# pos ADJ
# word cross
# pos NOUN
# count 2
# word Led
# pos VERB
# word •
# pos SYM
# word sticks
# pos NOUN
# count 1
# word billion
# pos NUM
# word 70
# pos NUM
# word of
# pos ADP
# word volume
# pos NOUN
# count 1
# word annual
# pos ADJ
# word representing
# pos VERB
# word operations
# pos NOUN
# count 1
# word line
# pos NOUN
# count 2
# word production
# pos NOUN
# count 3
# word 40
# pos NUM
# word of
# pos ADP
# word support
# pos NOUN
# count 1
# word in
# pos ADP
# word tool
# pos NOUN
# count 1
# word reporting
# pos NOUN
# count 2
# word and
# pos CCONJ
# word mining
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word wide
# pos ADJ
# word -
# pos PUNCT
# word company
# pos NOUN
# count 3
# word defective
# pos ADJ
# word a
# pos DET
# word of
# pos ADP
# word resolution
# pos NOUN
# count 1
# word successful
# pos ADJ
# word in
# pos ADP
# word team
# pos NOUN
# count 1
# word project
# pos NOUN
# count 2
# word international
# pos ADJ
# word and
# pos CCONJ
# word domestic
# pos ADJ
# word cross-functional
# pos ADJ
# word Directed
# pos VERB
# word •
# pos PUNCT
# word Turkey
# pos PROPN
# count 1
# word in
# pos ADP
# word CPG
# pos NOUN
# count 1
# word largest
# pos ADJ
# word the
# pos DET
# word and
# pos CCONJ
# word region
# pos NOUN
# count 1
# word EMEA
# pos PROPN
# count 2
# word for
# pos ADP
# word head
# pos NOUN
# count 1
# word cluster
# pos NOUN
# count 2
# word the
# pos DET
# word ,
# pos PUNCT
# word affiliate
# pos NOUN
# count 1
# word Turkish
# pos ADJ
# word the
# pos DET
# word to
# pos ADP
# word assignment
# pos NOUN
# count 1
# word development
# pos NOUN
# count 2
# word leadership
# pos NOUN
# count 3
# word for
# pos ADP
# word candidates
# pos NOUN
# count 1
# word 50
# pos NUM
# word of
# pos ADP
# word out
# pos ADP
# word Selected
# pos VERB
# word •
# pos PUNCT
# word award
# pos NOUN
# count 1
# word Duty
# pos NOUN
# count 2
# word of
# pos ADP
# word Call
# pos NOUN
# count 1
# word the
# pos DET
# word Beyond
# pos ADP
# word and
# pos CCONJ
# word Above
# pos ADP
# word International
# pos ADJ
# word Morris
# pos PROPN
# count 1
# word Philip
# pos PROPN
# count 2
# word received
# pos VERB
# word ;
# pos PUNCT
# word inventory
# pos NOUN
# count 1
# word total
# pos ADJ
# word of
# pos ADP
# word %
# pos SYM
# word 40
# pos NUM
# word representing
# pos VERB
# word million
# pos NUM
# word 1
# pos NUM
# word $
# pos SYM
# word by
# pos ADP
# word inventory
# pos NOUN
# count 1
# word local
# pos ADJ
# word reduction
# pos NOUN
# count 2
# word the
# pos DET
# word in
# pos ADP
# word resulting
# pos VERB
# word materials
# pos NOUN
# count 0
# word raw
# pos ADJ
# word and
# pos CCONJ
# word parts
# pos NOUN
# count 1
# word spare
# pos NOUN
# count 2
# word for
# pos ADP
# word process
# pos NOUN
# count 1
# word categorization
# pos NOUN
# count 2
# word and
# pos CCONJ
# word management
# pos NOUN
# count 1
# word inventory
# pos NOUN
# count 2
# word factory
# pos NOUN
# count 3
# word Initiated
# pos VERB
# word •
# pos PUNCT
# word indicators
# pos NOUN
# count 1
# word performance
# pos NOUN
# count 2
# word key
# pos ADJ
# word two
# pos NUM
# word for
# pos ADP
# word recognition
# pos NOUN
# count 1
# word achieving
# pos VERB
# word and
# pos CCONJ
# word records
# pos NOUN
# count 1
# word time
# pos NOUN
# count 2
# word -
# pos PUNCT
# word all
# pos DET
# word new
# pos ADJ
# word four
# pos NUM
# word setting
# pos VERB
# word ,
# pos PUNCT
# word projects
# pos NOUN
# count 1
# word improvement
# pos NOUN
# count 2
# word operations
# pos NOUN
# count 3
# word facility
# pos NOUN
# count 4
# word production
# pos NOUN
# count 5
# word two
# pos NUM
# word on
# pos ADP
# word teams
# pos NOUN
# count 1
# word person
# pos NOUN
# count 2
# word -
# pos PUNCT
# word five
# pos NUM
# word two
# pos NUM
# word Led
# pos VERB
# word •
# pos PUNCT
# word contributors
# pos NOUN
# count 1
# word key
# pos ADJ
# word identify
# pos VERB
# word to
# pos PART
# word analysis
# pos NOUN
# count 1
# word multivariate
# pos ADJ
# word using
# pos VERB
# word data
# pos NOUN
# count 1
# word failure
# pos NOUN
# count 2
# word machine
# pos NOUN
# count 3
# word analyzed
# pos VERB
# word ;
# pos PUNCT
# word classification
# pos NOUN
# count 1
# word image
# pos NOUN
# count 2
# word for
# pos ADP
# word network
# pos NOUN
# count 1
# word neural
# pos ADJ
# word convolutional
# pos ADJ
# word a
# pos DET
# word built
# pos VERB
# word ;
# pos PUNCT
# word techniques
# pos NOUN
# count 1
# word NLP
# pos NOUN
# count 2
# word using
# pos VERB
# word model
# pos NOUN
# count 2
# word analysis
# pos NOUN
# count 3
# word sentiment
# pos NOUN
# count 4
# word a
# pos DET
# word Developed
# pos VERB
# word :
# pos PUNCT
# word Projects
# pos NOUN
# count 1
# word •
# pos PUNCT
# word .
# pos PUNCT
# word models
# pos NOUN
# count 1
# word baseline
# pos NOUN
# count 2
# word over
# pos ADP
# word %
# pos SYM
# word 20
# pos NUM
# word by
# pos ADP
# word accuracy
# pos NOUN
# count 1
# word transcription
# pos NOUN
# count 2
# word improving
# pos VERB
# word ,
# pos PUNCT
# word %
# pos SYM
# word 5
# pos NUM
# word of
# pos ADP
# word )
# pos PUNCT
# word WER
# pos NOUN
# count 1
# word (
# pos PUNCT
# word Rate
# pos NOUN
# count 2
# word Error
# pos NOUN
# count 3
# word Word
# pos NOUN
# count 4
# word a
# pos DET
# word Achieved
# pos VERB
# word •
# pos PUNCT
# word language
# pos NOUN
# count 1
# word desired
# pos VERB
# word any
# pos DET
# word in
# pos ADP
# word subtitles
# pos NOUN
# count 1
# word written
# pos VERB
# word into
# pos ADP
# word videos
# pos NOUN
# count 1
# word in
# pos ADP
# word language
# pos NOUN
# count 1
# word spoken
# pos VERB
# word converting
# pos VERB
# word tool
# pos NOUN
# count 0
# word advanced
# pos ADJ
# word an
# pos DET
# word Developed
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word readability
# pos NOUN
# count 1
# word and
# pos CCONJ
# word clarity
# pos NOUN
# count 1
# word enhancing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 15
# pos NUM
# word by
# pos ADP
# word errors
# pos NOUN
# count 1
# word reducing
# pos VERB
# word ,
# pos PUNCT
# word transcriptions
# pos NOUN
# count 1
# word refine
# pos VERB
# word to
# pos PART
# word techniques
# pos NOUN
# count 1
# word prompting
# pos NOUN
# count 2
# word AI
# pos NOUN
# count 3
# word backend
# pos NOUN
# count 4
# word Implemented
# pos VERB
# word •
# pos PUNCT
# word consolidation
# pos NOUN
# count 1
# word and
# pos CCONJ
# word alignment
# pos NOUN
# count 1
# word subtitle
# pos NOUN
# count 2
# word effective
# pos ADJ
# word for
# pos ADP
# word )
# pos PUNCT
# word Warping
# pos PROPN
# count 1
# word Time
# pos PROPN
# count 2
# word Dynamic
# pos ADJ
# word (
# pos PUNCT
# word DTW
# pos NOUN
# count 3
# word implementing
# pos VERB
# word ,
# pos PUNCT
# word accuracy
# pos NOUN
# count 1
# word high
# pos ADJ
# word and
# pos CCONJ
# word coverage
# pos NOUN
# count 1
# word language
# pos NOUN
# count 2
# word broad
# pos ADJ
# word for
# pos ADP
# word Whisper
# pos NOUN
# count 1
# word ’s
# pos PART
# word OpenAI
# pos PROPN
# count 1
# word and
# pos CCONJ
# word models
# pos NOUN
# count 1
# word Chirp
# pos NOUN
# count 2
# word ’s
# pos PART
# word Google
# pos PROPN
# count 1
# word Leveraged
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word scalability
# pos NOUN
# count 1
# word and
# pos CCONJ
# word handling
# pos NOUN
# count 1
# word response
# pos NOUN
# count 2
# word model
# pos NOUN
# count 3
# word efficient
# pos ADJ
# word for
# pos ADP
# word %
# pos SYM
# word 30
# pos NUM
# word by
# pos ADP
# word load
# pos NOUN
# count 1
# word server
# pos NOUN
# count 2
# word decreasing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 40
# pos NUM
# word by
# pos ADP
# word latency
# pos NOUN
# count 1
# word response
# pos NOUN
# count 2
# word API
# pos NOUN
# count 3
# word reducing
# pos VERB
# word ,
# pos PUNCT
# word Redis
# pos PROPN
# count 1
# word with
# pos ADP
# word caching
# pos NOUN
# count 1
# word Implemented
# pos VERB
# word •
# pos PUNCT
# word )
# pos PUNCT
# word SQLAlchemy
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word FastAPI
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word Flask
# pos NOUN
# count 1
# word (
# pos PUNCT
# word backend
# pos VERB
# word to
# pos PART
# word )
# pos PUNCT
# word Vue.js
# pos PROPN
# count 1
# word (
# pos PUNCT
# word frontend
# pos NOUN
# count 2
# word from
# pos ADP
# word development
# pos NOUN
# count 1
# word end
# pos NOUN
# count 2
# word -
# pos PUNCT
# word to
# pos ADP
# word -
# pos PUNCT
# word end
# pos NOUN
# count 1
# word mastering
# pos VERB
# word ,
# pos PUNCT
# word development
# pos NOUN
# count 1
# word skill
# pos NOUN
# count 2
# word and
# pos CCONJ
# word education
# pos NOUN
# count 1
# word -
# pos PUNCT
# word self
# pos NOUN
# count 2
# word on
# pos ADP
# word Focused
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word %
# pos SYM
# word 25
# pos NUM
# word by
# pos ADP
# word imbalance
# pos NOUN
# count 1
# word cell
# pos NOUN
# count 2
# word reducing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 20
# pos NUM
# word by
# pos ADP
# word life
# pos NOUN
# count 1
# word battery
# pos NOUN
# count 2
# word increasing
# pos VERB
# word ,
# pos PUNCT
# word mechanisms
# pos NOUN
# count 1
# word protection
# pos NOUN
# count 2
# word advanced
# pos ADJ
# word and
# pos CCONJ
# word balancing
# pos NOUN
# count 1
# word cell
# pos NOUN
# count 2
# word active
# pos ADJ
# word with
# pos ADP
# word cells
# pos NOUN
# count 1
# word 21700
# pos NUM
# word Epoch
# pos NOUN
# count 1
# word utilizing
# pos VERB
# word pack
# pos NOUN
# count 1
# word battery
# pos NOUN
# count 2
# word P
# pos NOUN
# count 3
# word 10S3
# pos NUM
# word a
# pos DET
# word for
# pos ADP
# word BMS
# pos NOUN
# count 1
# word a
# pos DET
# word Designed
# pos VERB
# word •
# pos PUNCT
# word .
# pos PUNCT
# word %
# pos SYM
# word 40
# pos NUM
# word by
# pos ADP
# word time
# pos NOUN
# count 1
# word maintenance
# pos NOUN
# count 2
# word reducing
# pos VERB
# word and
# pos CCONJ
# word %
# pos SYM
# word 30
# pos NUM
# word by
# pos ADP
# word efficiency
# pos NOUN
# count 1
# word system
# pos NOUN
# count 2
# word overall
# pos ADJ
# word improving
# pos VERB
# word ,
# pos PUNCT
# word updates
# pos NOUN
# count 1
# word wireless
# pos ADJ
# word and
# pos CCONJ
# word ,
# pos PUNCT
# word protection
# pos NOUN
# count 1
# word cell
# pos NOUN
# count 2
# word advanced
# pos ADJ
# word ,
# pos PUNCT
# word handling
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word time
# pos NOUN
# count 3
# word -
# pos PUNCT
# word real
# pos ADJ
# word for
# pos ADP
# word system
# pos NOUN
# count 1
# word the
# pos DET
# word Optimized
# pos VERB
# word •
# pos PUNCT
# word servers
# pos NOUN
# count 1
# word cloud
# pos VERB
# word to
# pos PART
# word communication
# pos NOUN
# count 1
# word efficient
# pos ADJ
# word and
# pos CCONJ
# word logging
# pos NOUN
# count 1
# word data
# pos NOUN
# count 2
# word frequency
# pos NOUN
# count 3
# word -
# pos PUNCT
# word high
# pos ADJ
# word manage
# pos VERB
# word to
# pos PART
# word card
# pos NOUN
# count 1
# word SD
# pos NOUN
# count 2
# word an
# pos DET
# word and
# pos CCONJ
# word ,
# pos PUNCT
# word FRAM
# pos PROPN
# count 1
# word ,
# pos PUNCT
# word flash
# pos NOUN
# count 1
# word MCU
# pos NOUN
# count 2
# word the
# pos DET
# word using
# pos VERB
# word system
# pos NOUN
# count 0
# word management
# pos NOUN
# count 1
# word memory
# pos NOUN
# count 2
# word hybrid
# pos ADJ
# word a
# pos DET
# word Developed
# pos VERB
# word •
# pos PUNCT
