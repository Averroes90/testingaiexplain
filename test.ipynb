# %%
from main import run_agent
from utils import generate_csv

# Call the function with a sample query
query = "What's an AI agent?"
response = run_agent(query)

# Display the output
print("Agent Response:")
print(response)
# Out:
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/65c51c556eb563350f6e1bb1 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 65c51c556eb563350f6e1bb1 instantiated.
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/65c51c556eb563350f6e1bb1 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 65c51c556eb563350f6e1bb1 instantiated.
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/669a63646eb56306647e1091 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 669a63646eb56306647e1091 instantiated.
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/65c51c556eb563350f6e1bb1 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 65c51c556eb563350f6e1bb1 instantiated.
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/65c51c556eb563350f6e1bb1 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 65c51c556eb563350f6e1bb1 instantiated.
# INFO:root:Agent Run Async: Start service for model_process - https://platform-api.aixplain.com/sdk/agents/67c7d4c1ea5768ac1fa27c25/run - {"id": "67c7d4c1ea5768ac1fa27c25", "query": {"input": "What's an AI agent?"}, "sessionId": null, "history": null, "executionParams": {"maxTokens": 2048, "maxIterations": 10, "outputFormat": "text"}} - {'x-api-key': '2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Result of request for model_process - 201 - {'requestId': 'b0830359-f1e1-48a2-ba76-2661f6833e88', 'sessionId': '0fdadda1-3b12-485b-852b-0cfe55b7a1f5', 'data': 'https://platform-api.aixplain.com/sdk/agents/b0830359-f1e1-48a2-ba76-2661f6833e88/result'}
# INFO:root:Polling for Model: Start polling for model_process
# Agent Response:
# ModelResponse(status=SUCCESS, data='{'input': '{\'input\': "What\'s an AI agent?", \'chat_history\': [], \'outputFormat\': \'text\'}', 'output': 'An AI agent is a software program or system designed to perform tasks autonomously or semi-autonomously by perceiving its environment, making decisions based on data, and acting accordingly. AI agents can work alongside users or on their behalf, and they are used to achieve specific goals without human intervention.', 'session_id': '0fdadda1-3b12-485b-852b-0cfe55b7a1f5', 'intermediate_steps': [{'agent': 'Google Search agent', 'input': '{\'input\': "What\'s an AI agent?", \'chat_history\': [], \'outputFormat\': \'text\'}', 'output': 'An AI agent is a software program or system designed to perform tasks autonomously or semi-autonomously by perceiving its environment, making decisions based on data, and acting accordingly. AI agents can work alongside users or on their behalf, and they are used to achieve specific goals without human intervention.', 'tool_steps': [{'tool': 'utilities', 'input': "{'query': {'text': 'What is an AI agent?', 'options': {'group': {'id': '67c7d4c1ea5768ac1fa27c25', 'name': 'Google Search agent', 'type': 'agent', 'jobId': '0fdadda1-3b12-485b-852b-0cfe55b7a1f5'}}}}", 'output': "The output of the function 'utilities' to the input '{'text': 'What is an AI agent?'}' is: ['AI agents are autonomous intelligent systems performing specific tasks without human intervention. Organizations use AI agents to achieve specific goals and ...', 'An artificial intelligence (AI) agent refers to a system or program that is capable of autonomously performing tasks on behalf of a user or another system.', 'AI agents take the power of generative AI a step further by working alongside you or even on your behalf, and they can be built and used by ...', 'An AI agent is a software program or system designed to perform tasks autonomously or semi-autonomously by perceiving its environment, ...', 'AI agents are autonomous software tools that perform tasks, make decisions, and interact with their environment intelligently and rationally.', 'An agent is an AI with a job and the tools necessary to do that job.', 'An AI agent is an entity that can act autonomously in an environment. It can take information from its surroundings, make decisions based on that data, and act ...', 'AI agents are a type of artificial intelligence (AI) system that can understand and respond to customer inquiries without human intervention. They are created ...', 'AI agents are software systems that use AI to pursue goals and complete tasks on behalf of users. They show reasoning, planning, and memory and have a level ...']"}], 'thought': None, 'runTime': 5.208, 'usedCredits': 0.00026715, 'apiCalls': 2}], 'runTime': 5.208, 'usedCredits': 0.00026715, 'executionStats': {'status': 'SUCCESS', 'apiCalls': 2, 'credits': 0.00026715, 'runtime': 5.208, 'apiCallBreakdown': {'Google Search agent': 2}, 'runtimeBreakdown': {'Google Search agent': 5.208}, 'creditBreakdown': {'Google Search agent': 0.00026715}, 'sessionId': '0fdadda1-3b12-485b-852b-0cfe55b7a1f5', 'environment': 'prod', 'assetsUsed': ['agent:Google Search agent', 'tool:utilities'], 'timeStamp': '2025-03-05 04:36:23.160334', 'params': {'id': '67c7d4c1ea5768ac1fa27c25', 'sessionId': '0fdadda1-3b12-485b-852b-0cfe55b7a1f5'}}}', completed=True)

# %%
from utils import generate_csv

base_folder = "/Users/ramiibrahimi/Documents/testingaiexplain/base_folder/"
output_csv = "csv/my_corpus.csv"
generate_csv(base_folder, output_csv)
# Out:
# Ignoring wrong pointing object 6 0 (offset 0)
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Essays/Rami Ibrahimi Fuqua Essay 2.pdf
# page text Given my somewhat unusual personal and professional background, I believe that I will be able
# to bring a unique perspective and value to the diverse Fuqua culture.
#
# My earliest encounter with entrepreneurship came at a young age. I was 9 when a kindergarten
# my parents founded opened its doors to preschoolers from around the neighborhood. Under my
# mother’s management, it grew rapidly into a full-fledged school that provides high quality
# education at affordable costs to around 500 students. A true team project, the whole family
# contributed in one way or another to its rapid growth and success. Tutoring there during college,
# working there briefly after graduation, and as a member of the decision making circle
# throughout, I received valuable knowledge about business dynamics at medium to small sized
# businesses, and about entrepreneurship in Jordan.
#
# I hope to share and build upon my experiences by starting a Fuqua club focused on
# entrepreneurship and business in the Middle East. I believe this would provide distinctive insight
# for my prospective colleagues into an area that, although distinct in many respects, is somewhat
# less explored than markets like Asia or Latin America. I am also excited about the prospect of
# organizing a trek for my prospective Fuqua colleagues to Jordan, which is at the center of the
# Arab World technology start-up revolution and witnessing a unique technological transformation.
# A visit to one of the world’s new seven wonders, Petra, would just be the cherry on top.
#
# Since childhood, I was always very passionate about the technology industry, assembling my
# first personal computer at 7, developing android applications, and studying mechatronics
# engineering. Anxiously following all news about a new device or innovation, over the years I was
# able to develop instincts about technology trends. I found myself on many occasions able to
# predict the success or lack thereof of new tech ventures. A passionate techie, I hope to enrich
# my knowledge at, and suggest topics for, the High Tech 101 & 201 Sessions and advocate for
# my viewpoints through the weekly “tech talks” at the High Technology club.
#
# Professionally, I was fortunate to join the Jordanian Philip Morris International affiliate shortly
# after it was acquired from an aging local manufacturer. I was part of the “new blood” tasked with
# elevating the previously local company to the required corporate standard, no easy task. As part
# of a small team in a rapidly changing environment my limits were constantly expanding. My
# learning curve was astronomical across diverse areas from operations and projects
# management to cross-functional projects involving sales, marketing and finance. It was a
# chaotic scene in which everyone was involved in everything and I loved it. I guess in many ways
# it resembled a start-up. I intend to utilize my cross-functional experience to help my fellow study
# page text group partners integrate knowledge gained from different areas into one big picture.
# Furthermore, I plan to leverage my cross-cultural communication skill set to enhance the
# harmony among my diverse section.
#
# Through the years, I have cultivated diverse global experience. I grew up in the UAE and have
# lived there again as an adult, travelled across the Middle East, Europe and to the United States.
# Most recently, I started a one-year work assignment in Izmir, Turkey within an international
# Fortune 500 company. I am particularly looking forward to taking a leadership role within the
# Fuqua international business club. Through my exposure to the organizational challenges and
# dynamics at one of the largest and most diverse Philip Morris International affiliates I will be able
# to share, with my fellow future business leaders at Fuqua, my firsthand account of the
# challenges and opportunities of working in a truly international business and what I have
# perceived to be the best ways to overcome all cultural and linguistic barriers. I am also looking
# forward to participating in the GATE program to acquire additional exposure into new areas,
# particularly Latin America and South East Asia.
#
# Fuqua is the perfect fit for me, in terms of both professional and personal growth. I am eager to
# utilize the plethora of gateways and opportunities that Fuqua offers to contribute to the
# community. Whether through the initial community service projects, the world renowned Net
# Impact Club or Habitat for Humanity of Durham, I am brimming with excitement at the prospect
# of contributing substantially to Fuqua’s social entrepreneurship efforts.
#
# Finally, I am keen to bring my football (soccer) and fencing skills to the MBA games and to
# introducing my home country’s traditional dish, Mansaf at one of the around the world dinners. A
# voracious reader and news-junkie I am also interested in revamping the weekly newsletter.
#
#
#
#
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Essays/Rami Ibrahimi Fuqua25.pdf
# page text                      1-   I was born in Jordan and raised in Jordan and the UAE in a family of doctors. My parents
#                           strongly supported science and education.
#                      2-   I have itchy feet; I love to travel. I particularly enjoy embedding myself in a new culture
#                           among new people for a considerable period of time. One of my favorite destinations is
#                           Beirut, Lebanon where you can be sunbathing in wonderful weather on a beautiful beach
#                           and 30 minutes later you can be in skiing on the Mazaar slopes. It is indeed a chaotic city
#                           but that’s what I love about it.
#                      3-   I am a huge wildlife fanatic, next on my bucket list is a safari to Tanzania-Kenya.
#                      4-   I am an avid gamer. One of my most recent achievements is becoming a Level 100 colonel
#                           on Battlefield 4.
#                      5-   I am an aviation enthusiast, particularly up to date with the latest technologies from the
#                           likes of Lockheed Martin’s Skunk Works, the division responsible for their cutting-edge
#                           technologies such as the F35 Program.
#                      6-   I am a news junkie. From Politico and the Atlantic to Engadget and Gizmodo, I never miss
#                           my daily dose of the latest. My favorite nighttime activity is debating the latest political
#                           developments with a group of my childhood friends in one of the cafes in Amman.
#                      7-   I once won the bronze medal at a junior national fencing championship when I was 11 after
#                           training for only 6 weeks. Today, I practice once or twice every month.
#                      8-   I am a foodie and casual cook and the current owner of the world’s best pancake recipe, a
#                           claim based purely on my subjective opinion.
#                      9-   I love mountain biking and trail hiking. My current favorite locations include the beautiful
#                           Dead Sea plains and the vast Ajloun forest. I have an insatiable appetite for discovery and
#                           adventure.
#                      10- I am a football (soccer) enthusiast, intermediate right mid-fielder and avid Bayern München
#                           fan.
#                      11- I am an absolute tech-head. Constantly on the lookout for the next TechCrunch Disrupt,
#                           Apple and Google I/O. I predicted the unusual upcoming mid-generation game console
#                           refresh (PS4 Pro and Xbox Scorpio) 4 years ago and I can prove it!
#                      12- I am a movie addict, always waiting for the next Christopher Nolan or Wes Anderson
#                           masterpiece, or anything scored by Hans Zimmer. My favorite movie is the Grand Budapest
# page text       Hotel. The brilliant script, cinematography, score and uplifting narrative make it my go-to
#       movie whenever I’m looking for an extra moral push.
#  13- I am a devoted AC/DC and Led Zeppelin fan.  One of their few fans in the Middle East, I’ve
#       had a life-long dream of attending a live concert for both.
#  14- A comic book geek, I see myself as Bruce Wayne meets Tony Stark. My friends say I’m more
#       like Brain, the cartoon mouse.
#  15- I am a small talk professional, I can literally strike up a conversation with anyone about
#       anything. Perhaps a side effect of the next point.
#  16- I am a Wikipedia Addict; I am prone to spending hours jumping between Wikipedia articles
#       until I eventually end up reading about the Mongol horde or the exploration of Venus.
#  17- I am an off-roading enthusiast. My favorite weekend activity used to involve going on a
#       camping trip with my close friends in the Wadi Rum desert in my old Land Rover Defender.
#  18- I am a voracious reader and history buff and a true believer in the “history repeats itself”
#       statement.
#  19- I am a satirical comedy aficionado, and a big fan of SNL, Jon Stewart and The Onion
#       publication.
#  20- In my adolescence, I developed an extreme interest in Arab poetry which still persists. The
#       rich vocabulary of ancient Arabic makes for uniquely descriptive and articulate poetry.
#  21- I am a hobbyist software developer and the go-to guy at work for extreme excel VBA based
#       solutions.
#  22- I am a Ferrari & Ducati enthusiast. I do not like the extravagance, but I appreciate the
#       technology.
#  23- My favorite TV show is Silicon Valley. It’s about a group of geeks establishing a start-up who
#       face every imaginable obstacle. I particularly love the attention to detail. Every piece of
#       code, formula or business technique casually mentioned or in the background is real.
#       Whenever I describe the show, which ridiculously fits with my character and interests, I end
#       my description with “I swear I’m not making that up.”
#  24- My current idol is Elon Musk. His ability to mix technical skills with business acumen to
#       continuously innovate is for me a source of inspiration.
# 25-  I am an obsessive investigator; whenever I find a new area of extreme interest I delve into a
#      ridiculous level of detail. For example, I know that on my first day at Fuqua, I will get my
#      coffee at Bon Appetit Café from Irene at the coffee bar!
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Essays/Rami Ibrahimi Fuqua Optional Essay.pdf
# page text College was without doubt the roughest time in my life. I grew up in an academically oriented family. My
# parents were adamant about education and strove to provide the best quality of education their means
# allowed. Against my parents’ advice, who wanted me to study medicine, I elected to pursue my passion
# for technology and earn a degree in Mechatronics Engineering.
#
# Shortly after beginning college at the University of Jordan I realized that the school was in a state of rapid
# decline. Classes were extremely overcrowded, the aging infrastructure was crumbling, and the previously
# Western educated faculty was being replaced by a locally educated, less-qualified cohort. Despite being
# the most selective school in the country and thereby having some of the most highly qualified students,
# class failure rates were upwards of 60%. Students often repeated courses five or six times.
#
# I began searching for opportunities to transfer to a university abroad. Unfortunately, I could not financially
# afford it. Meanwhile, as I felt consumed by the stigma of failure, I did not want to go back to my family and
# disappoint them. I felt increasingly isolated and I did not know where to turn for guidance.
#
# Looking back, I should have asked my loved ones for help and put in the extra effort to adapt and do
# whatever was necessary to overcome this challenge. Instead, when life threw me my first serious curve
# ball, it knocked me out. I lost all motivation, I stopped going to classes, my self-esteem took a big hit, and
# I descended towards rock bottom. My former academic success was all but forgotten and I slowly settled
# for doing the bare minimum and becoming an average student, quite literally; I finished one semester late
# and around the fiftieth percentile of my class.
#
# Fortunately, things improved after I started at Philip Morris International. Working life was a fresh start,
# and I was determined to never again settle for anything less than exceptional.  With every new success I
# regained confidence and returned to the person I once was.  I have progressed rapidly, and in May I was
# assigned to one of the largest affiliates, in Izmir, Turkey. Such assignments are indicative of an
# accelerated career path and an investment by the company into their top talent.
#
# Furthermore, I have tried to demonstrate my ability to handle the curriculum, despite my poor
# undergraduate record. In addition to doing my best to get a good score on the GMAT, I am taking
# Calculus 1 and Introduction to Financial accounting through Berkeley extension. I have 100% in Calculus
# and 96% in Financial Accounting.  Only the final exams are remaining, and they are scheduled for mid-
# October.
#
# For my recommenders, I chose the people who know me best. I refrained from approaching my current
# supervisor, due to our relatively short relationship.
#
# Also, I included fixed per-diems, travel and hardship allowances and accommodation payments as bonus
# compensation when reporting my salary on the application.
#
# I truly hope for a second chance to re-immerse myself in academics and succeed at Fuqua, and to
# pursue my goals and achieve my full potential.
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Coverletters/Ibrahimi_Rami_CL_Master Card.pdf
# page text Dear Hiring Team at Mastercard,
#
# I am thrilled to apply for the Manager, Product Management – Security Solutions – AI
# (R-237371) position at Mastercard. With a diverse background in engineering, strategy, and
# operations across Jordan, the UAE, Turkey, and the United States, I bring a global perspective
# that aligns with Mastercard’s mission to advance secure and innovative payment solutions.
#
# Over the past 18 months, I have immersed myself in artiﬁcial intelligence and software
# engineering, driven by the realization that generative AI will transform the global economy.
# Recognizing this as a critical moment, I made the deliberate decision to upskill and reskill, not
# just to adapt, but to actively contribute to shaping this shift. Through an AI and Machine
# Learning Bootcamp at Columbia Engineering, I gained hands-on experience with tools like
# TensorFlow and PyTorch. I also pursued self-driven projects, such as developing an AI-
# powered interface that integrates multiple models and APIs, deepening my expertise in
# delivering secure, scalable, and innovative solutions.
#
# My career has consistently operated at the intersection of technology and strategy. At Google, I
# led machine-learning-driven initiatives across Asia and North America, achieving signiﬁcant
# operational cost savings. At Philip Morris International, I spearheaded supply chain
# transformations, including launching the company’s ﬁrst product export from Jordan to Africa.
# These roles honed my ability to align technical goals with strategic objectives while navigating
# complex cultural and regulatory landscapes.
#
# Growing up in a family business and later gaining experience across the CPG and tech
# industries, I developed a profound appreciation for the role of high-quality data in driving both
# security and innovation. Mastercard’s commitment to delivering secure, cutting-edge AI
# solutions resonates with me because I see its transformative potential—not just across
# industries, but within every facet of business operations. I am drawn to the opportunity to
# tackle complex challenges as unique puzzles, leveraging my technical and strategic expertise
# to design solutions that not only address immediate needs but also enable sustainable, long-
# term growth.
#
# This role excites me because it oﬀ        ers the chance to work at the cutting edge of AI and security,
# tackling challenges that have tangible, far-reaching impacts. Mastercard’s focus on developing
# innovative solutions to protect businesses and individuals aligns with my passion for solving
# complex, high-stakes problems. I’m motivated by the opportunity to collaborate with diverse
# teams, bring ideas to life, and contribute to building technology that not only drives progress
# but also instills trust and security in a rapidly evolving world.
#
# Thank you for considering my application. I look forward to the opportunity to discuss how my
# background, skills, and passion for secure AI solutions align with Mastercard’s mission and the
# goals of your team.
#
# Sincerely,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Coverletters/Ibrahimi_Rami_CL_Microsoft.pdf
# page text Dear Hiring Team,
#
# I’m excited to apply for the Principal Program Manager role on Microsoft’s AI Red Team. The
# opportunity to work on PyRIT and contribute to securing AI systems at the scale of Microsoft’s
# portfolio is exactly the kind of challenge I’ve been preparing for throughout my career.
#
# Over the past 18 months, I decided to transition into a more technical role in AI and machine
# learning, driven by a deep belief in the transformative potential of AI—a revolution that I see as
# reshaping industries and lives faster than any before it. During this time, I completed a
# bootcamp at Columbia Engineering, worked on self-driven projects like an AI-powered
# transcription tool with 20% improved accuracy, and advanced my expertise in frameworks
# such as TensorFlow, PyTorch, and adversarial ML techniques. This focused period of growth
# reﬂects my ongoing commitment to mastering the skills required to contribute meaningfully in
# this space, a journey I intend to deepen as my passion for this ﬁeld continues to evolve
#
# My career bridges technical expertise and program management. At Google, I led cross-
# functional teams to deploy machine-learning models that reduced costs by millions and
# optimized manufacturing processes. These experiences taught me how to deliver results in
# complex, fast-paced environments while coordinating eﬀ                orts across technical and operational
# domains. Beyond corporate roles, I’ve built full-stack AI applications, integrated APIs like
# OpenAI’s GPT, and contributed to real-world AI tools. These projects reinforced my ability to
# translate abstract ideas into impactful solutions.
#
# What excites me most about this role is the chance to shape and scale open-source tools like
# PyRIT, empowering a broader community to adopt AI red-teaming practices. The intersection
# of innovation, security, and collaboration is where I thrive, and I’m eager to contribute my
# technical and program management expertise to help drive Microsoft’s mission of building
# safer AI systems.
#
# The AI Red Team’s interdisciplinary approach—combining researchers, developers, and
# security experts—resonates deeply with me. I’ve worked in cross-functional environments
# throughout my career, and I know how to foster clarity and alignment while navigating
# ambiguity. Joining a team that proactively pushes boundaries to secure cutting-edge AI
# systems feels like a natural progression in my career.
#
# Thank you for considering my application. I look forward to the opportunity to discuss how my
# skills, experiences, and passion align with your team’s vision.
#
# Best regards,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Coverletters/Ibrahimi_Rami_Del.pdf
# page text Dear Hiring Team,
#
# I am excited to apply for the GenAI/Machine Learning Technical Project Manager position
# within Deloitte’s Human Capital Oﬀ         ering Portfolio. The opportunity to spearhead generative AI
# initiatives that enhance organizational performance and engagement aligns closely with my
# technical expertise, leadership experience, and passion for leveraging AI to solve real-world
# challenges.
#
# Over the past 18 months, I have transitioned into a more technical role in AI and machine
# learning, recognizing the transformative potential of this ﬁeld. During this time, I completed a
# certiﬁcation in AI and machine learning at Columbia Engineering, where I gained hands-on
# experience with frameworks like TensorFlow, PyTorch, and OpenAI’s GPT models. I have led
# self-driven projects, such as an AI-powered transcription tool with 20% improved accuracy
# and a full-stack AI-powered application integrating GPT models. These experiences reﬂect my
# ability to bridge technical and strategic domains to deliver impactful AI solutions.
#
# At Google, I managed cross-functional teams to deploy machine-learning models, achieving
# operational cost savings of over $10 million and optimizing processes at scale. These projects
# honed my skills in coordinating diverse teams, managing complex timelines, and delivering
# results in fast-paced environments. My recent experience includes leveraging Agile and Scrum
# methodologies to guide teams through every phase of project development, ensuring
# alignment with both technical roadmaps and business goals.
#
# What excites me most about this role is the opportunity to deliver cutting-edge generative AI
# projects while collaborating with cross-functional teams to align technical capabilities with
# tangible business value. My experience managing large-scale initiatives, and knowledge of
# cloud technologies (AWS, GCP, Azure), positions me to excel in this role. I am particularly
# drawn to Deloitte’s emphasis on creating people-centric solutions, as it resonates with my own
# approach to building tools that enhance user experience and deliver measurable impact.
#
# Beyond my technical and program management experience, I thrive in environments that
# demand adaptability, collaboration, and continuous improvement. Whether coaching junior
# team members, guiding teams through Agile transformations, or managing risks to ensure
# project success, I bring a results-oriented mindset and a commitment to fostering healthy,
# high-performing teams.
#
# Thank you for considering my application. I look forward to the opportunity to contribute to
# Deloitte’s mission of delivering innovative, human-centered AI solutions. I would welcome the
# chance to discuss how my skills and experiences align with your team’s needs.
#
# Best regards,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Coverletters/Ibrahimi_Rami_CL_Roblox.pdf
# page text Dear Hiring Team at Roblox,
#
# I am excited to apply for the Senior Product Manager role in the Creator organization at
# Roblox. With a multidisciplinary background in AI, machine learning, and platform
# development, combined with a passion for empowering creators and reimagining digital
# experiences, I am eager to contribute my expertise to your mission of connecting people
# through immersive 3D experiences.
#
# Recognizing the transformative potential of generative AI, I transitioned my career toward this
# ﬁeld, completing an AI and Machine Learning Bootcamp at Columbia Engineering. My journey
# has involved developing technical skills through hands-on projects, including:
#
# • Generative AI Interfaces: Built tools integrating multiple AI models and APIs, reﬁning my
#   understanding of system interoperability and enabling seamless user interactions.
#
# • Custom ML Models: Designed a speech-to-text transcription system that improved baseline
#   accuracy by 20%, leveraging ﬁne-tuning and domain-speciﬁc data.
#
# • AI for Content Creation: Explored the use of AI in automating the creation and enhancement
#   of digital assets, bridging technical innovation with user-centric design.
#
# My admiration for Roblox stems from your commitment to fostering creativity and innovation
# through an open, scalable platform. The Creator tools you oﬀ               er, combined with the integration
# of generative AI, set the stage for revolutionizing digital expression. I am particularly inspired by
# the vision of enabling “creation of anything, anywhere, by anyone”—a goal that resonates
# deeply with my work in democratizing AI-powered technologies for creators and developers
# alike.
#
# Throughout my career, I have cultivated the skills needed to thrive in dynamic, multi-sided
# platforms. At Google, I led cross-regional machine learning initiatives, achieving measurable
# operational eﬃ    ciencies while collaborating with engineering teams to deliver impactful
# solutions. At Philip Morris International, I managed complex projects that demanded strategic
# problem-solving and a user-ﬁrst mindset. These experiences have prepared me to shape and
# execute innovative product strategies aligned with Roblox’s goals.
#
# I am excited about the opportunity to lead the vision and roadmap for AI/ML-driven tools within
# the Creator organization. Collaborating with talented engineers, designers, and analysts to
# deliver tools that empower users and advance the platform’s capabilities would be an
# incredible challenge that I am ready to embrace.
#
# Thank you for considering my application. I look forward to the opportunity to discuss how my
# background and passion align with Roblox’s mission to redeﬁne human interaction in digital
# spaces.
#
# Sincerely,
# Rami Ibrahimi
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Coverletters/Ibrahimi_Rami_McKinsey.pdf
# page text                                                                                                    RAMI I. IBRAHIMI
#                                         2101 Arlington Blvd.#433 •                                                                                                                                         Charlottesville, VA 22903 •                                                                                    (405) 404-                                                                                   6614•
#                                                                                             IbrahimiR19@darden.virginia.edu
#
#
# September 16, 2018
#
# McKinsey&Company Recruiting Team
# McKinsey&Company
# Gate Precinct 4, Level 4
# Dubai, United Arab Emirates
#
# Dear McKinsey&Company Recruiting Team         ,
#
# My name is Rami Ibrahimi, and I am currently a first                                                            -year student at the Darden Graduate School of
# Business. I am writin         g to express my interest In the full-time associate position at McKinsey       . Having lived
# and worked in                                diverse functions in                                 Jordan, the UAE,           Turkey and the United States        ,I believe I would bring
# a uniquely                              modern, international perspective to the global team at McKinsey&Co.
#
# I have thoroughly enjoyed learning about McKinsey&Co                                                                throughout the recruiting process this fall           and
# prior. I was particularly impressed with the c                   ulture and community of exceptional people at the firm         .
# Fu rther more, the exposure to broad strategic decisionmaking within i                                                                                              ndustry transformational projects
# would allow me to enhance my strategic perspective while utilizing                                my experience in manufacturing and
# operations. Additionally, the strong focus on           training, development                                                                                     and innovation,and the plethora of
# opportunities for internal mobility within the firm         make it the ideal place whereI                                                                         can have a very well                                                                     -
# rounded and long term career through which I can have an impact on the industries I am most passionate
# about.
#
# Progressing rapidly through different roles and locations, my work experience at Philip Morris
# International includes joining                     the freshly acquired affiliate in Jordan as a member of a small team tasked
# with restructuring the new acquisition from the groundup                                                                                                                                                   . I have experienced rapid personal and
# professional growththroughout                               ,given the necessity to                    work in diverse areas. These experiences include
# leading a global                                        team for the                     launch           of the           first ever product export          at the Jordanian affiliate, and         building
# complex excel models for the long-                                                                         term budget cycle at the Turkish affiliate - the largest affiliate and the
# biggest CPG in Turkey. These aresome                                                   of the experiences that have provided me withthe global
# leadership, project management, technical, and other versatile skills          that would be essential                                                                        for a successful
# career in consulting and strategy. Most recently, I have completed                     my summer internship at Google in
# Mountain View, CA. where I got to work within the hardware operations team                                                             on live projects with the
# internal team and the co                            ntract manufacturer in support of next generation                                            Pixel phone launch.
#
# Outside of work, I strove to further developmy skills                                                                        . Learning how to code VB, Java, SQL, XML and
# other languages, pursuing training in project management, and ultimately electing to pursue an MBA, I
# have eventually identified that through a role in consulting, I can most utilize my skill                                                                                  -set and have the
# greatest impact. Generally                    , being part of the strategic planni                    ng process and leading transformational
# initiatives across cross         -functional teams is work that I would very excited about doing on a daily basis.
#
# I a m very excited at the possibility of interviewing for the        McKinsey&Co Associate          program.
#
# Thank you for your time and consideration, and I look forward to speaking with you in the future.
#
# Sincerely,
#
# Rami Ibrahimi
# MBA Candidate, Class of 2019
# Darden Graduate School of Business
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Coverletters/Ibrahimi_Rami_CL_UBS.pdf
# page text Dear Hiring Team at UBS,
#
# I am excited to apply for the Product Manager, GenAI Products position at UBS. With a diverse
# background in engineering, strategy, and operations across Jordan, the UAE, Turkey, and the
# United States, I bring a global perspective and a deep appreciation for how technology can
# drive innovation and transformation in ﬁnancial services.
#
# Over the past 18 months, I have dedicated myself to artiﬁcial intelligence and software
# engineering, recognizing that generative AI is poised to revolutionize industries worldwide. This
# realization led me to upskill and reskill deliberately, completing an AI and Machine Learning
# Bootcamp at Columbia Engineering, where I gained hands-on experience with frameworks like
# TensorFlow and PyTorch. I complemented this formal learning with self-driven projects,
# including the development of an AI-powered interface integrating multiple AI models and APIs.
# These experiences deepened my expertise and ignited my enthusiasm for harnessing GenAI to
# address real-world challenges with innovative and scalable solutions.
#
# Throughout my career, I have consistently operated at the intersection of technology and
# strategy. At Google, I led machine-learning-driven initiatives across Asia and North America,
# achieving substantial operational cost savings. At Philip Morris International, I spearheaded
# supply chain transformation projects, including launching the company’s ﬁrst product export
# from Jordan to Africa. These experiences taught me to navigate complex regulatory and
# cultural environments while aligning technical innovations with strategic objectives.
#
# As someone who grew up in a family-run business and later gained experience across the CPG
# and tech industries, I have developed a profound appreciation for how cutting-edge
# technologies can reshape traditional sectors like banking. UBS’s commitment to leveraging
# GenAI to enhance client experiences and operational eﬃ                ciency resonates with me. I am
# particularly drawn to the challenge of crafting GenAI solutions that are both innovative and
# secure, bringing fresh perspectives to a ﬁeld where precision and adaptability are paramount.
#
# I am motivated by the opportunity to work on complex problems that push the boundaries of AI
# applications while collaborating with diverse teams to drive meaningful outcomes. Joining UBS
# represents a chance to bring together my technical expertise and strategic insight to help
# shape the future of GenAI products in ﬁnancial services, creating solutions that empower
# clients and elevate the industry.
#
# Thank you for considering my application. I look forward to the opportunity to discuss how my
# background, skills, and vision align with UBS’s mission and the goals of your team.
#
# Sincerely,
# Rami Ibrahimi
# MBA, Class of 2019
# Darden School of Business, University of Virginia
# B.Sc. in Mechatronics Engineering, Class of 2013
# University of Jordan
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Resumes/Ibrahimi_Rami_120722.pdf
# Ignoring wrong pointing object 8 0 (offset 0)
# Ignoring wrong pointing object 10 0 (offset 0)
# Ignoring wrong pointing object 15 0 (offset 0)
# Ignoring wrong pointing object 17 0 (offset 0)
# Ignoring wrong pointing object 19 0 (offset 0)
# Ignoring wrong pointing object 21 0 (offset 0)
# Ignoring wrong pointing object 23 0 (offset 0)
# page text                                                                                              R     AMI            I.    I  BRAHIMI
#                       San Francisco               , C   A    94158        • (4    1 5  ) 8  0  6 -5906        • riibrahimi@gmail.com                            • linkedin.com/in/rami                        -ibrahimi
#
#  E DUCATION
#                                    University of Virginia Darden School of Business                                                                                                                           Charlottesville, VA
#                                    Candidate for Master of Business Administration, May 2019
#                                    •        GMAT: 720
#                                    •        Darden Foundation Scholarship
#                                    •        Clubs:         Consulting,             Technology, Finance, Adam Smith Society                                               , and      S  occer
#
#                                    University of Jordan                                                                                                                                                             Amman,              Jordan
#                                    Bachelor of Science in                        Mechatronics Engineering, Jan 2013
#                                    •        Volunteer l            ecturer for Assembly & Microprocessors and De                                                    sign of Embedded Systems                               classes
#
#  E XPERIENCE
# 201    8 -Present                  Google LLC
#                                    Product           Operations              T/   Program Manager                         –   Phones (          2019      -Present         )                                Mountain View, CA
#                                    •        Managed oversees third party team of data scientists to deliver machine learning predictive models
#                                             for return rates &                  manufacturing                 cell qualification resulting in reduction of 15% in qualification costs
#                                    •        Created and executed new process for management                                                         of OpEx product costs                         in tandem with cross                     -
#                                             regional team resulting in                           $3.5 million and $7                     million        in savings for              Pixel       2020 and            Pixel      20   21
#                                    •        Drove product                 headcount             resource management for                             8 Pixel devices from                      concept through end of life
#                                    •        Manage          d non       -device        costs for Wearables business unit                                   totaling $150 million                      a nnually
#                                    •        Led early engagement                          Product investigation and feature definition                                           for a new segment Pixel device
#
#                                    Hardware, Product Operations MBA Intern                                                    –   Phones           (Summer 2018)                                            Mountain              View, CA
#                                    •        Designed and implemented                                new       process         for Inventory Management Forum                                       for    n  ext   -gen flagship
#                                             Pixel phones               resulting in complete                      automation              of the process and                   80% reduction in                    work load
#                                    •        Established             standard          Key Part Release and Master Production S                                             chedule          model and             input       templates
#                                    •        Completely r              evamped            Clear to Build                management                process          leading to           strategic         SKU       -level visibility
#
# 2013     -2017                     Phil     ip Morris International
#                                    Operations Planning Analyst                                  (201     5  -2017)                                                                                                      Izmir, Turkey
#                                    •        Selected out of                50 candidates for leadership development assignment to the Turkish affiliate, the
#                                             cluster head for EEMA region                                  and the largest CPG in Turkey
#                                    •        Directed          cross      -functional            domestic and international                            project team              in successful resolution of a
#                                             defective company                     -wide data            mining         and reporting tool                   in support of 40 production line operations
#                                             representing              annual volume of                    70 b     illion sticks
#                                    •        Led cross functional effort across five                                      team      s to successfully launch                        the first        product export project
#                                             for    23 new products                   across        eight      new African markets                        representing 15%                     of annual          volume
#                                    •        Supervised             the operations team for                         the    revamp          of    seven       strategic products including Marlboro and
#                                             L&M          brands        achieving            100% hit rate for in                   -ma     rket   -sales timeline                requirement             s
#
#                                    Process Engineer (2014                           -2015)                                                                                                                          Amman, Jordan
#                                    •        Led two           five    -person teams on two production facility operations improvement projects setting                                                                                   four
#                                             new all        -time       records and achieving                       recognition for two                     key      performance indicators
#                                    •        Initiated         factory inventory management                                  and categorization                    process         for    spare parts and raw materials
#                                             resulting          in the reduction                local spare parts inventory                           by    $1 million representing                         40%       of total
#                                             inventory          ; received Philip Morris International Above and                                                   Beyond          the    Ca    ll of Duty award
#
#                                    Electrical Maintenance Engineer (2013                                             -2014)                                                                                         Amman, Jordan
#                                    •        D   esign     ed    and install          ed    of track and trace weight measurement system
#
#  A DDITIONAL               INFORMATION
#                                    •        Dual       Citizenship: United States & Jordan
#                                    •        Bilingual proficiency in English and Arabic,                                              and basic proficiency                       in Turkish
#                                    •        Soccer midfielder                    &    m   ountain biker             , int   erested in          post     -classical          history and            O   xford       U  nion      debate       s
#                                    •        PEARSON certified Smartphone developer
#                                    •        Accidentally appeared in the background of a romantic scene of a Turkish Soap Opera
# file path /Users/ramiibrahimi/Documents/testingaiexplain/base_folder/Resumes/Ibrahimi_Rami.pdf
# page text RAMI I. IBRAHIMI
# San Francisco, CA • (415) 806-5906 • riibrahimi@gmail.com • linkedin.com/in/rami-ibrahimi •github.com/Averroes90
# Certified AI professional with an engineering background and an MBA, transitioning from product operations to machine
# learning operations and engineering. Hands-on experience in building predictive models, big data manipulation, and
# managing cross-functional teams
#
#
# TECHNICAL      SKILLS
#      •    Programming Languages: Python, JavaScript, SQL, C
#      •    Machine Learning: TensorFlow, Keras, Scikit-learn, PyTorch
#      •    Data Science: Pandas, NumPy, Matplotlib, Jupyter
#      •    Cloud Platforms: AWS (SageMaker, EC2), Google Cloud
#      •    DevOps & Tools: Docker, Git, Kubernetes, Vue.js
#
# PROFESSIONAL       EXPERIENCE
# Google LLC                                                                                                                             2018-2023
# Product Operations T/ Program Manager – Phones (2019-2023)                                                                 Mountain View, CA
#      •    Managed overseas team of data scientists to deliver machine learning predictive models for return rates &
#           manufacturing cell qualification resulting in reduction of 15% in qualification costs
#      •    Created and executed new process for management of OpEx product costs in tandem with cross-regional team
#           resulting in $3.5 million and $7 million in savings for Pixel 2020 and Pixel 2021 respectively
#      •    Drove product headcount resource management for 8 Pixel devices from concept through end of life
#      •    Managed non-device costs for Wearables business unit totaling $150 million annually
#      •    Led early engagement Product investigation and feature definition for a new segment Pixel device
#
# Hardware, Product Operations MBA Intern – Phones (Summer 2018)                                                             Mountain View, CA
#      •    Designed and implemented new process for Inventory Management Forum for next-gen flagship Pixel devices
#           resulting in complete automation of the process and 80% reduction in work load
#      •    Established standard Key Part Release and Master Production Schedule model and input templates
#      •    Completely restructured Clear to Build management process leading to strategic SKU-level visibility
#
# Philip Morris International                                                                                                            2013-2017
# Operations Planning Analyst (2015-2017)                                                                                            Izmir, Turkey
#      •    Selected out of 50 candidates for leadership development assignment to the Turkish affiliate, the cluster head for
#           EMEA region and the largest CPG in Turkey
#      •    Directed cross-functional domestic and international project team in successful resolution of a defective company-
#           wide data mining and reporting tool in support of 40 production line operations representing annual volume of 70
#           billion sticks
#      •    Led cross-functional effort across five teams to successfully launch the first export project for 23 new products
#           across eight new African markets representing 15% of annual volume
#      •    Supervised the operations team for the revamp of seven strategic products including Marlboro and L&M brands
#           achieving 100% hit rate for in-market-sales timeline requirements
#
# Process Engineer (2014-2015)                                                                                                   Amman, Jordan
#      •    Led two five-person teams on two production facility operations improvement projects, setting four new all-time
#           records and achieving recognition for two key performance indicators
#      •    Initiated factory inventory management and categorization process for spare parts and raw materials resulting in
#           the reduction local inventory by $1 million representing 40% of total inventory; received Philip Morris
#           International Above and Beyond the Call of Duty award
#
# Electrical Engineer (2013-2014)                                                                                                Amman, Jordan
#      •    Designed and installed track and trace weight measurement system
#
#
#
#
#
#
#
#
#
#
#                                          Rami I. Ibrahimi | riibrahimi@gmail.com | Page 1 of 2
# page text EDUCATION
# Columbia University Engineering AI Bootcamp                                                                                     New York, NY
# Certificate in Artificial Intelligence and Machine Learning, June 2024
#      •    Key skills: Python, Pandas, TensorFlow, Keras, Scikit-learn, NLP, Computer Vision
#      •    Projects: Developed a sentiment analysis model using NLP techniques; built a convolutional neural network for
#           image classification; analyzed machine failure data using multivariate analysis to identify key contributors
#
# University of Virginia Darden School of Business                                                                           Charlottesville, VA
# Master of Business Administration, May 2019
#      •    GMAT: 720
#      •    Darden Foundation Scholarship: Awarded merit-based scholarship recognizing academic excellence
#      •    Clubs: Consulting, Technology, Finance, Adam Smith Society, and Soccer
#
# University of Jordan                                                                                                          Amman, Jordan
# Bachelor of Science in Mechatronics Engineering, Jan 2013
#      •    Key skills: Embedded Systems, Microcontroller Programming, Assembly Language, Robotics
#      •    Volunteering: lecturer for Assembly & Microprocessors and Design of Embedded Systems classes
#
# SELECTED TECHNICAL          PROJECTS
# Auto Transcribe and Translate (Mar 2024 - present)
# Python, NLP, Jupyter, spaCy, pydub, PyTorch, OpenAI API, Google STT API
#
#      •    Developed an advanced tool converting spoken language in videos into written subtitles in any desired language
#      •    Achieved a Word Error Rate (WER) of 5%, improving transcription accuracy by 20% over baseline models.
#      •    Leveraged Google’s Chirp models and OpenAI’s Whisper for broad language coverage and high accuracy,
#           implementing DTW (Dynamic Time Warping) for effective subtitle alignment and consolidation
#      •    Implemented backend AI prompting techniques to refine transcriptions, reducing errors by 15% and enhancing
#           clarity and readability.
#
# GPT Interface (Jun 2023 - present)
# Vue.js, Flask, FastAPI, Webpack,  Pydantic, SQLite, SQLAlchemy, Poetry, Redis, OpenAI API, Gemini API
#
#      •    Built a full-stack AI-powered application integrating GPT models using OpenAI and Gemini APIs.
#      •    Focused on self-education and skill development, mastering end-to-end development from frontend (Vue.js) to
#           backend (Flask, FastAPI, SQLAlchemy)
#      •    Implemented caching with Redis, reducing API response latency by 40% and decreasing server load by 30% for
#           efficient model response handling and scalability.
#
# Battery Management System (Jan 2023 - Jun 2023)
# Python, C, STM32, ADC, FRAM, Wi-Fi, Kalman Filter, Active Cell Balancing
#
#      •    Designed a BMS for a 10S3P battery pack utilizing Epoch 21700 cells with active cell balancing and advanced
#           protection mechanisms, increasing battery life by 20% and reducing cell imbalance by 25%.
#      •    Developed a hybrid memory management system using the MCU flash, FRAM, and an SD card to manage high-
#           frequency data logging and efficient communication to cloud servers
#      •    Optimized the system for real-time data handling, advanced cell protection, and wireless updates, improving
#           overall system efficiency by 30% and reducing maintenance time by 40%.
#
#
# ADDITIONAL      INFORMATION        & PROFESSIONAL        DEVELOPMENT
#      •    Dual Citizenship: United States & Jordan
#      •    Bilingual proficiency in English and Arabic, and basic proficiency in Turkish
#      •    Soccer midfielder & mountain biker, interested in post-classical history and Oxford Union debates
#      •    PEARSON certified Smartphone developer
#
#
#
#
#
#
#
#                                          Rami I. Ibrahimi | riibrahimi@gmail.com | Page 2 of 2

# %%
import pandas as pd

data_url = "csv/my_corpus.csv"
data = pd.read_csv(data_url)
data
# Out:
#                                         id  \
# 0                     Rami,_Darden_E1.docx
# 1          Rami_Ibrahimi_Fuqua_Essay_2.pdf
# 2                Rami_Ibrahimi_Fuqua25.pdf
# 3                  Rami,_Darden_Misc2.docx
# 4                   Rami,_Darden_Misc.docx
# 5   Rami_Ibrahimi_Fuqua_Optional_Essay.pdf
# 6         Rami,_Darden_optional_Essay.docx
# 7         Ibrahimi_Rami_CL_Master_Card.pdf
# 8           Ibrahimi_Rami_CL_Microsoft.pdf
# 9                    Ibrahimi_Rami_Del.pdf
# 10             Ibrahimi_Rami_CL_Roblox.pdf
# 11              Ibrahimi_Rami_McKinsey.pdf
# 12                Ibrahimi_Rami_CL_UBS.pdf
# 13               Ibrahimi_Rami_120722.docx
# 14                      Ibrahimi_Rami.docx
# 15                       Ibrahimi_Rami.pdf
#
#                                               content      doc_type  \
# 0   Shortly after my transition to the process eng...        Essays
# 1   Given my somewhat unusual personal and profess...        Essays
# 2    \n1- I was born in Jordan  and raised in Jord...        Essays
# 3   What is your short-term, post-MBA career goal ...        Essays
# 4   College Extracurriculars and Employment – 200 ...        Essays
# 5   College was without doubt the roughest time in...        Essays
# 6   Shortly after beginning my undergraduate study...        Essays
# 7   Dear Hiring Team at Mastercard,\nI am thrilled...  Coverletters
# 8   Dear Hiring Team,\nI’m excited to apply for th...  Coverletters
# 9   Dear Hiring Team,\nI am excited to apply for t...  Coverletters
# 10  Dear Hiring Team at Roblox,\nI am excited to a...  Coverletters
# 11  RAMI I. IBRAHIMI  \n2101 Arlington Blvd. #433 ...  Coverletters
# 12  Dear Hiring Team at UBS,\nI am excited to appl...  Coverletters
# 13  Rami I. Ibrahimi\nCharlottesville, VA 22903  (...       Resumes
# 14  Rami I. Ibrahimi\nSan Francisco, CA · (415) 80...       Resumes
# 15  RAMI I. IBRAHIMI San Francisco, CA • (415) 806...       Resumes
#
#    created_date
# 0    2025-03-13
# 1    2025-03-13
# 2    2025-03-13
# 3    2025-03-13
# 4    2025-03-13
# 5    2025-03-13
# 6    2025-03-13
# 7    2025-03-13
# 8    2025-03-13
# 9    2025-03-13
# 10   2025-03-13
# 11   2025-03-13
# 12   2025-03-13
# 13   2025-03-13
# 14   2025-03-13
# 15   2025-03-13

# %%
from aixplain.factories import CorpusFactory
from aixplain.enums import License
from schema import schema
import main  # to set api key

payload = CorpusFactory.create(
    name="my_corpus_name2",
    description="A corpus of my job-related docs.",
    license=License.MIT,
    content_path=data_url,
    schema=schema,
)
corpus = CorpusFactory.get(payload["asset_id"])
print("Onboarding status:", corpus.to_dict())
# Out:
#  Corpus onboarding progress:   0%|          | 0/4 [00:00<?, ?it/s]
#
#  Corpus onboarding progress:  25%|██▌       | 1/4 [00:00<00:02,  1.40it/s]
#
#  Corpus onboarding progress:  50%|█████     | 2/4 [00:01<00:01,  1.33it/s]
#
#  Corpus onboarding progress:  75%|███████▌  | 3/4 [00:02<00:00,  1.47it/s]
#
#  Corpus onboarding progress: 100%|██████████| 4/4 [00:02<00:00,  1.51it/s]
# INFO:root:Start service for GET Corpus  - https://platform-api.aixplain.com/sdk/corpora/67c8d398ea5768ac1fa27ef3/overview - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Corpus 67c8d398ea5768ac1fa27ef3 retrieved successfully.
# Onboarding status: {'id': '67c8d398ea5768ac1fa27ef3', 'name': 'my_corpus_name2', 'description': 'A corpus of my job-related docs.', 'supplier': <Supplier.AIXPLAIN: {'id': 1, 'name': 'aiXplain', 'code': 'aixplain'}>, 'version': '1.0', 'license': <License.MIT: '620ba3a83e2fa95c500b429d'>, 'privacy': <Privacy.PRIVATE: 'Private'>, 'cost': None, 'onboard_status': <OnboardStatus.ONBOARDING: 'onboarding'>, 'functions': [], 'tags': [], 'data': [<aixplain.modules.data.Data object at 0x113bc7aa0>, <aixplain.modules.data.Data object at 0x113bc8170>, <aixplain.modules.data.Data object at 0x113bc9400>, <aixplain.modules.data.Data object at 0x113bc8800>], 'length': None, 'kwargs': {}}

# %%
corpus = CorpusFactory.get(payload["asset_id"])
print("Onboarding status:", corpus.to_dict())
# Out:
# INFO:root:Start service for GET Corpus  - https://platform-api.aixplain.com/sdk/corpora/67c8d398ea5768ac1fa27ef3/overview - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Corpus 67c8d398ea5768ac1fa27ef3 retrieved successfully.
# Onboarding status: {'id': '67c8d398ea5768ac1fa27ef3', 'name': 'my_corpus_name2', 'description': 'A corpus of my job-related docs.', 'supplier': <Supplier.AIXPLAIN: {'id': 1, 'name': 'aiXplain', 'code': 'aixplain'}>, 'version': '1.0', 'license': <License.MIT: '620ba3a83e2fa95c500b429d'>, 'privacy': <Privacy.PRIVATE: 'Private'>, 'cost': None, 'onboard_status': <OnboardStatus.ONBOARDED: 'onboarded'>, 'functions': [], 'tags': [], 'data': [<aixplain.modules.data.Data object at 0x113bc8e00>, <aixplain.modules.data.Data object at 0x113bc8200>, <aixplain.modules.data.Data object at 0x113bc8f80>, <aixplain.modules.data.Data object at 0x113bc93d0>], 'length': 15, 'kwargs': {}}

# %%
from aixplain.factories import DatasetFactory, ModelFactory, FinetuneFactory
from aixplain.enums import Function, Language

model = ModelFactory.get("66eae6656eb56311f2595011")
model.__dict__
# Out:
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/66eae6656eb56311f2595011 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 66eae6656eb56311f2595011 instantiated.
# {'id': '66eae6656eb56311f2595011',
#  'name': 'aiXplain Search v2',
#  'description': 'The “Search” AI function swiftly processes your query, utilizing its advanced algorithms to accurately sift through vast documents and return a curated list of pertinent documents.',
#  'supplier': <Supplier.AIXPLAIN: {'id': 1, 'name': 'aiXplain', 'code': 'aixplain'}>,
#  'version': 'airv2',
#  'license': None,
#  'privacy': <Privacy.PRIVATE: 'Private'>,
#  'cost': {'price': 1e-06, 'unitType': 'CHAR', 'unitTypeScale': None},
#  'api_key': '2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6',
#  'additional_info': {'code': '',
#   'parameters': {'top_k': ['10']},
#   'inputs': [],
#   'temperature': None},
#  'url': 'https://models.aixplain.com/api/v1/execute',
#  'backend_url': 'https://platform-api.aixplain.com',
#  'function': <Function.SEARCH: 'search'>,
#  'is_subscribed': False,
#  'created_at': datetime.datetime(2024, 11, 19, 14, 45, 26, 653000, tzinfo=datetime.timezone.utc),
#  'input_params': {'text': {'name': 'Text',
#    'code': 'text',
#    'required': True,
#    'isFixed': False,
#    'dataType': 'text',
#    'dataSubType': 'text',
#    'multipleValues': False,
#    'defaultValues': []}},
#  'output_params': {'data': {'name': 'Text',
#    'code': 'data',
#    'defaultValue': [],
#    'dataType': 'text'}}}

# %%
from aixplain.factories import DatasetFactory

dataset = CorpusFactory.get(payload["asset_id"])
dataset.__dict__
# Out:
# INFO:root:Start service for GET Corpus  - https://platform-api.aixplain.com/sdk/corpora/67c8d398ea5768ac1fa27ef3/overview - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Corpus 67c8d398ea5768ac1fa27ef3 retrieved successfully.
# {'id': '67c8d398ea5768ac1fa27ef3',
#  'name': 'my_corpus_name2',
#  'description': 'A corpus of my job-related docs.',
#  'supplier': <Supplier.AIXPLAIN: {'id': 1, 'name': 'aiXplain', 'code': 'aixplain'}>,
#  'version': '1.0',
#  'license': <License.MIT: '620ba3a83e2fa95c500b429d'>,
#  'privacy': <Privacy.PRIVATE: 'Private'>,
#  'cost': None,
#  'onboard_status': <OnboardStatus.ONBOARDED: 'onboarded'>,
#  'functions': [],
#  'tags': [],
#  'data': [<aixplain.modules.data.Data at 0x113ba09e0>,
#   <aixplain.modules.data.Data at 0x113ba1a00>,
#   <aixplain.modules.data.Data at 0x113ba1310>,
#   <aixplain.modules.data.Data at 0x113ba10a0>],
#  'length': 15,
#  'kwargs': {}}

# %%
from aixplain.factories import DatasetFactory

dataset = DatasetFactory.get("67ca25e11f3c6278a2fcd757")
dataset.__dict__
# Out:
# INFO:root:Start service for GET Dataset  - https://platform-api.aixplain.com/sdk/datasets/67ca25e11f3c6278a2fcd757/overview - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Dataset 67ca25e11f3c6278a2fcd757 retrieved successfully.
# {'id': '67ca25e11f3c6278a2fcd757',
#  'name': 'content of job docs',
#  'description': 'the text content of the onboarded job documents',
#  'supplier': <Supplier.AIXPLAIN: {'id': 1, 'name': 'aiXplain', 'code': 'aixplain'}>,
#  'version': '1.0',
#  'license': <License.Unknown: '620ba3b73e2fa95c500b42a2'>,
#  'privacy': <Privacy.PRIVATE: 'Private'>,
#  'cost': None,
#  'onboard_status': <OnboardStatus.ONBOARDED: 'onboarded'>,
#  'function': <Function.TEXT_EMBEDDING: 'text-embedding'>,
#  'source_data': {'content': <aixplain.modules.data.Data at 0x113c23470>},
#  'target_data': {},
#  'hypotheses': {},
#  'metadata': {},
#  'tags': [],
#  'length': 15,
#  'kwargs': {}}

# %%
finetune_name = "My job sample docs 15 entries2"
finetune = FinetuneFactory.create(finetune_name, [dataset], model)
finetune.__dict__
# Out:
# INFO:root:Start service for POST Create FineTune - https://platform-api.aixplain.com/sdk/finetune/cost-estimation - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'} - {"datasets": [{"datasetId": "67ca25e11f3c6278a2fcd757", "trainPercentage": 100, "devPercentage": 0}], "sourceModelId": "66eae6656eb56311f2595011", "parameters": {}}
# INFO:root:Response for POST Create FineTune - Status {'trainingCost': {'total': 0.157905, 'dataCost': 0, 'supplierCost': 0.157905, 'overheadCost': 0, 'isDependingOnTrainingTime': False, 'willRefundIfLowerThanMax': True, 'totalVolume': 52635, 'max': 300, 'unitPrice': 3e-06, 'overheadCostIsPercentage': True}, 'inferenceCost': [{'unitPrice': 3e-06, 'unitType': 'CHAR', 'volume': 0}], 'hostingCost': {'currentMonthPrice': 0, 'monthlyPrice': 0, 'pricePerCycle': 0, 'supplierBillingCycle': 'MONTH', 'willRefundIfLowerThanMax': False}}
# {'id': '',
#  'name': 'My job sample docs 15 entries2',
#  'description': '',
#  'supplier': <Supplier.AIXPLAIN: {'id': 1, 'name': 'aiXplain', 'code': 'aixplain'}>,
#  'version': '1.0',
#  'license': None,
#  'privacy': <Privacy.PRIVATE: 'Private'>,
#  'cost': <aixplain.modules.finetune.cost.FinetuneCost at 0x113c179b0>,
#  'model': <Model: aiXplain Search v2 by aiXplain>,
#  'dataset_list': [<Dataset: content of job docs>],
#  'train_percentage': 100,
#  'dev_percentage': 0,
#  'prompt_template': None,
#  'hyperparameters': None,
#  'additional_info': {},
#  'backend_url': 'https://platform-api.aixplain.com',
#  'api_key': '2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6',
#  'aixplain_key': '2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6'}

# %%
finetune_model = finetune.start()
# Out:
# INFO:root:Start service for POST Start FineTune - https://platform-api.aixplain.com/sdk/finetune - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'} - {"name": "My job sample docs 15 entries2", "datasets": [{"datasetId": "67ca25e11f3c6278a2fcd757", "trainSamplesPercentage": 100, "devSamplesPercentage": 0}], "sourceModelId": "66eae6656eb56311f2595011", "parameters": {}}
# INFO:root:Response for POST Start FineTune - Name: My job sample docs 15 entries2 / Status {'statusCode': 422, 'message': 'err.name_already_exists'}
# ERROR:root:Start FineTune: Error with payload {"name": "My job sample docs 15 entries2", "datasets": [{"datasetId": "67ca25e11f3c6278a2fcd757", "trainSamplesPercentage": 100, "devSamplesPercentage": 0}], "sourceModelId": "66eae6656eb56311f2595011", "parameters": {}}: Status 422 - err.name_already_exists
# Traceback (most recent call last):
#   File "/Users/ramiibrahimi/Documents/testingaiexplain/.venv/lib/python3.12/site-packages/aixplain/modules/finetune/__init__.py", line 138, in start
#     return ModelFactory().get(resp["id"])
#                               ~~~~^^^^^^
# KeyError: 'id'

# %%
status = finetune_model.check_finetune_status()
status
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 status = finetune_model.check_finetune_status()
#       2 status
#
# AttributeError: 'NoneType' object has no attribute 'check_finetune_status'

# %%
import time

while status != "completed":
    status = finetune_model.check_finetune_status()
    print(f"Current status: {status}")
    time.sleep(10)
# Out:
# INFO:root:Start service for GET Check FineTune status Model  - https://platform-api.aixplain.com/sdk/finetune/67ca26621f3c6278a2fcd75a/ml-logs - {'x-api-key': '2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Response for GET Check FineTune status Model - Id 67ca26621f3c6278a2fcd75a / Status failed.
# Current status: FinetuneStatus(status=<AssetStatus.FAILED: 'failed'>, model_status=<AssetStatus.FAILED: 'failed'>, epoch=None, training_loss=None, validation_loss=None)
# INFO:root:Start service for GET Check FineTune status Model  - https://platform-api.aixplain.com/sdk/finetune/67ca26621f3c6278a2fcd75a/ml-logs - {'x-api-key': '2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Response for GET Check FineTune status Model - Id 67ca26621f3c6278a2fcd75a / Status failed.
# Current status: FinetuneStatus(status=<AssetStatus.FAILED: 'failed'>, model_status=<AssetStatus.FAILED: 'failed'>, epoch=None, training_loss=None, validation_loss=None)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 6
#       4 status = finetune_model.check_finetune_status()
#       5 print(f"Current status: {status}")
# ----> 6 time.sleep(10)
#
# KeyboardInterrupt:

# %%
from aixplain.factories import ModelFactory

finetune_model = ModelFactory.get("66f31d0acfca28e7e420fd79")
query = "Does vagus nerve contribute to the development of steatohepatitis and obesity in phosphatidylethanolamine N-methyltransferase deficient mice?"

response = finetune_model.run(query, parameters={"numResults": 10})
response
# Out:
# INFO:root:Start service for GET Model  - https://platform-api.aixplain.com/sdk/models/66f31d0acfca28e7e420fd79 - {'Authorization': 'Token 2fa34265d7ae3236f75962bef0cd4f4b5bb267b947354c80a60ed0ff40fd79e6', 'Content-Type': 'application/json'}
# INFO:root:Model Creation: Model 66f31d0acfca28e7e420fd79 instantiated.
# ERROR:root:Error in request: 461: Subscription-related error: Please ensure that your subscription is active and has not expired. Details: err.asset_not_found
# ModelResponse(status=FAILED, completed=True, error_message='Subscription-related error: Please ensure that your subscription is active and has not expired. Details: err.asset_not_found')
